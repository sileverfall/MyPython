# %%
import requests
import re

# %%
url = ['https://www.ptt.cc/bbs/Soft_Job/index'+''\d'+'.html']
    urls =[]
       for url in urls:
       res = requests.get(URL,verify = False)
# Out:
#   File "<ipython-input-16-362474920595>", line 1
#     url = ['https://www.ptt.cc/bbs/Soft_Job/index'+''\d'+'.html']
#                                                                  ^
# SyntaxError: unexpected character after line continuation character

# %%
URL = "https://www.ptt.cc/bbs/Soft_Job/index.html"
res = requests.get(URL,verify = False)
print(res.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Soft_Job 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Soft_Job/index.html"><span class="board-label">看板 </span>Soft_Job</a>
# ...

# %%
res.request.headers
# Out:
# {'User-Agent': 'python-requests/2.18.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
from bs4 import BeautifulSoup as bs
soup = bs(res.text,"lxml")

# %%
for entry in soup.select('.r-ent'):
    print (entry.select('.title')[0].text,entry.select('.date')[0].text,entry.select('.author')[0].text)
# Out:
# [請益] 機房op出路
#   7/06 dunk1201
#
# [請益] 南部不錯的APP製作廠商 (台南高雄屏東)
#   7/06 hallstatt
#
# 7.30年前的 相容IBMPC的中文輸入
#   7/06 ggg12345
#
# [請益] 開發ibm notes的天花板高嗎？
#   7/06 LUB5566
#
# [請益] 後端會希望做網頁的人能做到怎樣的地步呢
#   7/06 G4321
#
# [新聞] 平均年終20個月 群暉科技釋出150個職缺
#   7/06 sony577
#
# [請益] offer請益
#   7/06 SoulOfNag
#
# [請益] 該不該換工作
#   7/07 assai000
#
# [討論] 請問應徵時學歷
#   7/07 lihaomai
#
# [請益] DS智庫驅動 公司及資料英雄活動評價
#   7/07 yanwu0105
#
# Re: [討論] 關於自刪文章
#   7/07 ruthertw
#
# Re: [請益] 該不該換工作
#   7/07 qrtt1
#
# [請益] 關於軟體專案外包
#   7/07 cout
#
#
# 				(本文已被刪除) <yundom>
#
# 			  7/07 -
#
#
# 				(本文已被刪除) <ren8162>
#
# 			  7/07 -
#
# [公告] yundom ren8162 hireinmanila 警告
#   7/07 s89227
#
# Re: [討論] 關於自刪文章
#   7/07 descent
#
# [公告] 本板板規  2017/4/10更新
#   1/01 femlro
#
# [公告] 徵才不符板規或徵才自刪公司
#   1/19 femlro
#
# [情報] 訓練課程與付費APP與網站分享
#   4/04 femlro
#
# [情報] 社群活動與免費APP與網站分享
#   4/04 femlro
#
# [板務] 請板友提供板務建議
#   6/29 s89227

# %%
titles = soup.select('#main-container')[0].select('.title > a')

# %%
data = [row.text for row in titles]

# %%
data
# Out:
# ['[公告] Soft_Job 板試閱',
#  '搶頭香',
#  '[閒聊] 搶前五樓',
#  '恭喜開板 ^^',
#  '喔耶',
#  '[恭喜] 終於開板啦',
#  '恭賀開板',
#  '[閒聊] 恭賀開板',
#  '[閒聊] 賀開板',
#  '[閒聊] 恭賀開板',
#  '[討論] 促進交流增加人氣的自我介紹 [討論串]',
#  'Re: [請益] 非正統資工出身進大公司資訊相關RD的難度?',
#  '[閒聊] 恭喜開板',
#  'Re: [討論] 促進交流增加人氣的自我介紹 [討論串]',
#  'Re: [討論] 促進交流增加人氣的自我介紹 [討論串]',
#  'Re: [討論] 促進交流增加人氣的自我介紹 [討論串]',
#  '[閒聊] 恭喜開板',
#  '[閒聊] 恭喜開板',
#  '[閒聊] 恭喜開版',
#  '[閒聊] 恭喜開版']

# %%
# !pip3 install PTT
# Out:
# ...
#   Using cached ptt-0.3-py3-none-any.whl
# ...

# %%
import PTT
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-9cf3f5a582bd> in <module>()
# ----> 1 import PTT
#
# ModuleNotFoundError: No module named 'PTT'
