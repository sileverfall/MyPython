# %%
! pip3 install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.6/site-packages
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/site-packages (from requests)
# Requirement already satisfied: idna<2.6,>=2.5 in /usr/local/lib/python3.6/site-packages (from requests)
# Requirement already satisfied: urllib3<1.22,>=1.21.1 in /usr/local/lib/python3.6/site-packages (from requests)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/site-packages (from requests)

# %% [markdown]
# ## Get方法

# %%
import requests
res = requests.get("https://s.taobao.com/search?q=%E7%94%B7%E5%8F%8B%E8%A4%B2&type=p&tmhkh5=&spm=a21wu.241046-tw.a2227oh.d100&from=sea_1_searchbutton&catId=100")

# %%
print (res.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="renderer" content="webkit">
#     <meta name="data-spm" content="a230r">
#     <link rel="dns-prefetch" href="//g.alicdn.com">
#     <link rel="dns-prefetch" href="//assets.alicdn.com">
#     <link rel="dns-prefetch" href="//img.alicdn.com">
#     <link rel="dns-prefetch" href="//g-search1.alicdn.com">
#     <link rel="dns-prefetch" href="//g-search2.alicdn.com">
#     <link rel="dns-prefetch" href="//g-search3.alicdn.com">
#     <link rel="dns-prefetch" href="//g-search4.alicdn.com">
#     <link rel="dns-prefetch" href="//gtms01.alicdn.com">
#     <link rel="dns-prefetch" href="//gtms02.alicdn.com">
#     <link rel="dns-prefetch" href="//gtms03.alicdn.com">
#     <link rel="dns-prefetch" href="//gtms04.alicdn.com">
#     <meta name="description" content="淘宝搜索是最智能的商品搜索引擎，通过大数据的运营，准确的理解商品与用户，提供精准的个性化搜索体验。">
#             <meta name="keywords" content="男友褲,男友褲_淘宝网,男友褲_淘宝搜索">
#         <title>男友褲_淘宝搜索</title>
#
#     <script>
#         var p4p_btsinfo = "";
#         var g_config = {
#             appId: 3,
#             toolbar: false,
#             webww: true,
#             ap_mods: {
#                 jstracker:[ 0.0001 ]
#             }
#         };
#     </script>
#     <!-- S GLOBAL CSS -->
#     <link rel="stylesheet" href="//g.alicdn.com/tb/global/3.5.34/global-min.css">
#
#     <link rel="stylesheet" href="//g.alicdn.com/code/icon??tsrp/162/fest.css,tsrp/116/util.css">
#     <!-- E GLOBAL CSS --><!-- S GLOBAL JS -->
#     <script src="//g.alicdn.com/??kissy/k/1.4.15/seed-min.js,tb/global/3.5.34/global-min.js"></script>
#     <!-- E GLOBAL JS -->
#     <script src="//g.alicdn.com/??kissy/k/1.4.15/import-style-min.js,tb/tracker/1.0.19/index.js,/tb/tsrp/1.69.1/config.js"
#             charset="utf-8"></script>
#     <script src="//g.alicdn.com/searchInteraction/keyword-brand-pc/0.0.6/config.js"></script>
#     <script src="//g.alicdn.com/mm/staobao/1.5.8/index-min.js" charset="utf-8"></script>
#         <script>
#         Search.config({
#             base: '//g.alicdn.com/tb/tsrp/1.69.1/',
#             name: 'srp',
#             combine: true
#         });
#         window.givenByFE = window.givenByFE || {};
#     </script>
#
#     <script>
#
#     g_page_config = {"pageName":"mainsrp","mods":{"shopcombotip":{"status":"hide"},"phonenav":{"status":"hide"},"debugbar":{"status":"hide"},"shopcombo":{"status":"hide"},"itemlist":{"status":"show","data":{"postFeeText":"运费","trace":"msrp_auction","auctions":[{"p4p":1,"p4pSameHeight":true,"nid":"551661795755","category":"","pid":"","title":"九分裤男夏季休闲9分韩版修身薄款小脚青年哈伦百搭学生束脚裤潮","raw_title":"夏季时尚休闲九分裤男","pic_url":"//g-search1.alicdn.com/img/bao/uploaded/i4/imgextra/i3/1559006072276322162/TB2HFOBh9B0XKJjSZFsXXaxfpXa_!!0-saturn_solar.jpg","detail_url":"https://click.simba.taobao.com/cc_im?p\u003d%C4%D0%D3%D1%D1%9D\u0026s\u003d203358698\u0026k\u003d537\u0026e\u003dGLV6B3eM%2FIULsGGeNQMuR2%2FfPhVhhIJ7KsW1eUZmu3gOnH2E5alvesZn5yzl%2FMKG1BHL839rN1BV%2FtGecPQMkpBLvKob2if%2Fxb0uCku68bvzTZtXCfjWK49Rygz60TkG4AKYznuD77iLXF0pf6OoUE8WOm2ZJkDfgm614KhbXXEaYctBW7wSPPtro7IPz9zp1Pw3CDcTTTYjI%2F5yBc603fYA%2BGyp0FTbSifmhlU4uvhJTua73bG8i%2BvUFPSN5jD%2BkXUreu%2FMDqiNKm7TlL1N1prjxqWThjxFJeFaj9RBEGuOklqoxzlnMNXleD6oYlx1ZVddWa3glHp84%2BGhi9gZWwCjXNdsw95Y%2B3pgxsfbP7OjGKyNPTqZ3LMS2mBhpg6mTy61%2BHE42uvomunCYHO9CMyUxcD8EEC1AmSIvthLHSoeXJ%2Fml1XpkncPrDKePcoCA1NJhDehRvMHZsaCAIgwy%2FZcRQUilfkfUdG55f0pz%2Bl4BQlZIHfR%2FxCp8YvpxgzfQjl%2B%2BqUk4RAi36G13Z6VnA%3D%3D","view_price":"59.00","view_fee":"0.00","item_loc":"福建 泉州","view_sales":"52人付款","comment_count":"","user_id":"2946170967","nick":"susegbr旗舰店","shopcard":{"levelClasses":[],"isTmall":true,"delivery":[0,-1,79],"description":[0,-1,160],"service":[0,-1,122],"encryptedUserId":"UvCk0MCHuvmkLMWTT"},"icon":[{"title":"掌柜热卖宝贝","dom_class":"icon-service-remai","position":"1","show_type":"0","icon_category":"baobei","outer_text":"0","html":"","icon_key":"icon-service-remai","trace":"srpservice","traceIdx":0,"innerText":"掌柜热卖宝贝","url":"//re.taobao.com/search?keyword\u003d%C4%D0%D3%D1%D1%9D\u0026refpid\u003d420432_1006\u0026frcatid\u003d\u0026"},{"title":"尚天猫，就购了","dom_class":"icon-service-tianmao","position":"1","show_type":"0","icon_category":"baobei","outer_text":"0","html":"","icon_key":"icon-service-tianmao","trace":"srpservice","traceIdx":1,"innerText":"天猫宝贝"},{"title":"保险理赔","dom_class":"icon-service-baoxian","position":"99","show_type":"1","icon_category":"baobei","outer_text":"0","html":"","icon_key":"icon-service-baoxian","trace":"srpservice","traceIdx":2,"innerText":"分组-保险理赔","iconPopupComplex":{"popup_title":"保险理赔","subIcons":[{"dom_class":"icon-service-yunfeixian","icon_content":"卖家赠送退货运费险"}]}}],"isHideIM":true,"isHideNick":false,"comment_url":"https://click.simba.taobao.com/cc_im?p\u003d%C4%D0%D3%D1%D1%9D\u0026s\u003d203358698\u0026k\u003d537\u0026e\u003dGLV6B3eM%2FIULsGGeNQMuR2%2FfPhVhhIJ7KsW1eUZmu3gOnH2E5alvesZn5yzl%2FMKG1BHL839rN1BV%2FtGecPQMkpBLvKob2if%2Fxb0uCku68bvzTZtXCfjWK49Rygz60TkG4AKYznuD77iLXF0pf6OoUE8WOm2ZJkDfgm614KhbXXEaYctBW7wSPPtro7IPz9zp1Pw3CDcTTTYjI%2F5yBc603fYA%2BGyp0FTbSifmhlU4uvhJTua73bG8i%2BvUFPSN5jD%2BkXUreu%2FMDqiNKm7TlL1N1prjxqWThjxFJeFaj9RBEGuOklqoxzlnMNXleD6oYlx1ZVddWa3glHp84%2BGhi9gZWwCjXNdsw95Y%2B3pgxsfbP7OjGKyNPTqZ3LMS2mBhpg6mTy61%2BHE42uvomunCYHO9CMyUxcD8EEC1AmSIvthLHSoeXJ%2Fml1XpkncPrDKePcoCA1NJhDehRvMHZsaCAIgwy%2FZcRQUilfkfUdG55f0pz%2Bl4BQlZIHfR%2FxCp8YvpxgzfQjl%2B%2BqUk4RAi36G13Z6VnA%3D%3D\u0026on_comment\u003d1","shopLink":"https://click.simba.taobao.com/cc_im?p\u003d%C4%D0%D3%D1%D1%9D\u0026s\u003d203358698\u0026k\u003d505\u0026e\u003dUl09l46lR9sLsGGeNQMuR2%2FfPhVhhIJ7KsW1eUZmu3gOnH2E5alvesZn5yzl%2FMKG1BHL839rN1CxN%2Bw%2Fsj8KHZBLvKob2if%2Fxb0uCku68bvzTZtXCfjWK49Rygz60TkG4AKYznuD77iLXF0pf6OoUE8WOm2ZJkDfgm614KhbXXEaYctBW7wSPPtro7IPz9zp1Pw3CDcTTTYjI%2F5yBc603fYA%2BGyp0FTbSifmhlU4uvhJTua73bG8i%2BvUFPSN5jD%2BkXUreu%2FMDqiNKm7TlL1N1prjxqWThjxFJeFaj9RBEGuOklqoxzlnMNXleD6oYlx1ZVddWa3glHp84%2BGhi9gZWwCjXNdsw95Y%2B3pgxsfbP7NfPsqSHBhXFjxtWOMu2CwyCvGSShIb52qRpjBg6RHS8h0whnpE1qohSmy7CIhjcBR7wk8%2BXAxJpz1ybyAxt1RQyQ%2FJ65V4dDQfUHvFtH%2BCC6wqwcpJIfWjq%2F32lr6ysf1v3z4VYYSCew%3D%3D"},{"i2iTags":{"samestyle":{"url":""},"similar":{"url":"/search?type\u003dsimilar\u0026app\u003di2i\u0026rec_typ ...
#     g_srp_loadCss();
#     g_srp_init();
#                 window.givenByFE.tracerule= {"search_radio_all":"lf_aclog\u003dnull-null-0-0-0-0\u0026at_alitrackid\u003d${alitrackid}\u0026at_bucketid\u003d${bucketId}\u0026multi_bucket\u003d${multi_bucket}\u0026srppage\u003d${srppage}\u0026nick\u003d${nick}\u0026rn\u003d${rn}\u0026multivariate\u003d${multivariate}\u0026stats_click\u003dsearch_radio_all:1","spucombo_auction":"lf_aclog\u003dnull-null-null-|-null\u0026direct_cat\u003d${catdirect}\u0026lf_acfrom\u003d${if_tank}\u0026at_alitrackid\u003d${alitrackid}\u0026at_bucketid\u003d${bucketId}\u0026multi_bucket\u003d${multi_bucket}\u0026srppage\u003d${srppage}\u0026nick\u003d${nick}\u0026rn\u003d${rn}\u0026multivariate\u003d${multivariate}\u0026stats_click\u003d${data-traceclick}","srp_as_allcat":"lf_aclog\u003dnull-null-0-0-0-0\u0026at_bucketid\u003d${bucketId}\u0026multi_bucket\u003d${multi_bucket}\u0026srppage\u003d${srppage}\u0026nick\u003d${nick}\u0026rn\u003d${rn}\u0026multivariate\u003d${multivariate}\u0026stats_click\u003dsrp_as_allcat:1","toolbarHistory":"lf_aclog\u003dnull-null-${auctionReturnNum}-all|-0-null\u0026cat\u003d${catLevelOne}\u0026lf_acfrom\u003d${if_tank}\u0026at_alitrackid\u003d${alitrackid}\u0026at_bucketid\u003d${bucketId}\u0026multi_bucket\u003d${multi_bucket}\u0026srppage\u003d${srppage}\u0026nick\u003d${nick}\u0026rn\u003d${rn}\u0026multivariate\u003d${multivariate}\u0026stats_click\u003dviewhistory:1","btmMybought":"lf_aclog\u003dnull-null-null-${sort}|${sort2}-null\u0026direct_cat\u003d${catdirect}\u0026lf_acfrom\u003d${if_tank}\u0026at_alitrackid\u003d${alitrackid}\u0026at_bucketid\u003d${bucketId}\u0026multi_bucket\u003d${multi_bucket}\u0026srppage\u003d${srppage}\u0026nick\u003d${nick}\u0026rn\u003d${rn}\u0026multivariate\u003d${multivariate}\u0026stats_click\u003dpagetype:bottom;from_pos:${btmMyboughtFP[].#value}","combo_zk":"lf_aclog\u003dnull-null-${auctionReturnNum}-all|-0-null\u0026lf_acfrom\u003d${if_tank}\u0026at_alitrackid\u003d${alitrackid}\u0026at_bucketid\u003d${bucketId}\u0026multi_bucket\u003d${multi_bucket}\u0026srppage\u003d${srppage}\u0026nick\u003d${nick}\u0026rn\u003d${rn}\u0026multivariate\u003d${multivariate}\u0026stats_click\u003dpersonal_button%3Azk","srprate":"lf_aclog\u003d${auctionNids[].#index}-${auctionNids[].#value}-${auctionReturnNum}-${sort}|${sort2}-${ifDoufuAuction[].#value}-${auctionPrices[].#value}\u0026srprate\u003d1\u0026at_alitrackid\u003d${alitrackid}\u0026at_bucketid\u003d${bucketId}\u0026multi_bucket\u003d${multi_bucket}\u0026srppage\u003d${srppage}\u0026nick\u003d${nick}\u0026rn\u003d${rn}","listBtn":"lf_aclog\u003dnull-null-${auctionReturnNum}-${sort}|${sort2}-null\u0026direct_cat\u003d${catdirect}\u0026lf_acfrom\u003d${if_tank}\u0026at_alitrackid\u003d${alitrackid}\u0026at_bucketid\u003d${bucketId}\u0026multi_bucket\u003d${multi_bucket}\u0026srppage\u003d${srppage}\u0026nick\u003d${nick}\u0026rn\u003d${rn}\u0026multivariate\u003d${multivariate}\u0026stats_click\u003dbutton_click:list","festivalAuction":"lf_aclog\u003d200-${data-nid}-null-all|-0-null\u0026lf_acfrom\u003d${if_tank}\u0026at_alitrackid\u003d${alitrackid}\u0026at_bucketid\u003d${bucketId}\u0026multi_bucket\u003d${multi_bucket}\u0026srppage\u003d${srppage}\u0026nick\u003d${nick}\u0026rn\u003d${rn}\u0026stats_click\u003dchuizhi_tongyonglist:${data-floor}_${data-index};chuizhi_page:tongyong;sp_seller_type:${data-sp_seller_type}","v_carinfosave":"lf_aclog\u003dnull-null-null-|-null\u0026direct_cat\u003d${catdirect}\u0026lf_acfrom\u003d${if_tank}\u0026at_alitrackid\u003d${alitrackid}\u0026at_bucketid\u003d${bucketId}\u0026multi_bucket\u003d${multi_bucket}\u0026srppage\u003d${srppage}\u0026nick\u003d${nick}\u0026rn\u003d${rn}\u0026multivariate\u003d${multivariate}\u0026stats_click\u003d${chuizhi_page};${chuizhi_list};chuizhi_combo;carinfo:1","quicklook_picture":"lf_aclog\u003d0-${auctionNids[].#value}-${auctionReturnNum}-all|-0-null\u0026lf_acfrom\u003d${if_tank}\u0026at_alitrackid\u003d${alitrackid}\u0026at_bucketid\u003d${bucketId}\u0026mul ...
# </script>
#
#
#     <link rel="search" type="application/opensearchdescription+xml" title="淘宝搜索" href="/opensearch.xml">
# </head>
# <style>
#     .site-nav .my-taobao .menu-bd-panel a:nth-child(4) {
#         display: none;
#     }
# </style>
# <body data-spm="1"><script>
# with(document)with(body)with(insertBefore(createElement("script"),firstChild))setAttribute("exparams","category=&userid=&aplus&yunid=&&trid=0b83e08114991836854395295efddc&asid=AQAAAABFultZOS0QHgAAAADj9+L0v42XRQ==&sidx=",id="tb-beacon-aplus",src=(location>"https"?"//g":"//g")+".alicdn.com/alilog/mlog/aplus_v2.js")
# </script>
#
#
# <div id="page" class="srp-page">
#     <div id="J_SiteNav" class="site-nav">
#         <!-- 吊顶 -->
#         <div id="J_SiteNavBd" class="site-nav-bd">
#             <ul id="J_SiteNavBdL" class="site-nav-bd-l"></ul>
#             <ul id="J_SiteNavBdR" class="site-nav-bd-r"></ul>
#         </div>
#     </div>
#     <!-- --><!-- 全网顶通 --><!-- E GLOBAL HTML -->
#     <script>
#         TB.Global.blacklist = ['fn-cart'];
#         TB.Global.init();
#     </script>
#
#     <div id="main" class="srp-main">
#         <div class="srp-loading" style="text-align:center; margin: 100px auto 0; height:48px; width: 48px; background-image: url(data:image/gif;base64,...);"></div>
#     </div>
#
#     <!-- 页尾 -->
#     <div id="srp-footer">
#         <textarea id="srp-footer-tmpl" style="visibility:hidden">
# <div class="footer" data-spm="1997523009">
#
# <div class="footer-hd">
#   <p>
#     <span>
#       <a href="http://www.alibabagroup.com/cn/global/home">阿里巴巴集团</a></span>
#     <b>|</b>
#     <span>
#       <a href="//www.taobao.com">淘宝网</a></span>
#     <b>|</b>
#     <span>
#       <a href="//www.tmall.com">天猫</a></span>
#     <b>|</b>
#     <span>
#       <a href="//ju.taobao.com">聚划算</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.aliexpress.com">全球速卖通</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.alibaba.com/">阿里巴巴国际交易市场</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.1688.com">1688</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.alimama.com">阿里妈妈</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.fliggy.com/">飞猪</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.aliyun.com">阿里云计算</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.yunos.com">YunOS</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.aliqin.cn/">阿里通信</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.etao.com/">一淘</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.net.cn">万网</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.autonavi.com/">高德</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.uc.cn/">UC</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.umeng.com/">友盟</a></span>
#     <br>
#     <span>
#       <a href="http://www.xiami.com">虾米</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.alibabaplanet.com/">阿里星球</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.laiwang.com/">来往</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.dingtalk.com/?lwfrom=20150130160830727">钉钉</a></span>
#     <b>|</b>
#     <span>
#       <a href="https://www.alipay.com">支付宝</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.youku.com/">优酷</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.tudou.com/">土豆</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.alihealth.cn/">阿里健康</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.alibabapictures.com/simp/0-home.html">阿里影业</a></span>
#     <b>|</b>
#     <span>
#       <a href="http://www.alisports.com/cn/">阿里体育</a></span>
#     <b>|</b>
#     <span>
#       <a href="https://www.mybank.cn/">网商银行</a></span>
#   </p>
# </div>
# <div class="footer-bd">
#   <p>
#     <span>
#       <a href="//www.taobao.com/about">关于淘宝</a></span>
#     <span>
#       <a href="//www.taobao.com/about/partners.php">合作伙伴</a></span>
#     <span>
#       <a href="//pro.taobao.com">营销中心</a></span>
#     <span>
#       <a href="http://jubao.alibaba.com/internet/readme.htm?site=taobao">廉正举报</a></span>
#     <span>
#       <a href="//service.taobao.com/support/main/service_route.htm">联系客服</a></span>
#     <span>
#       <a href="//open.taobao.com">开放平台</a></span>
#     <span>
#       <a href="//www.taobao.com/about/join.php">诚征英才</a></span>
#     <span>
#       <a href="//consumerservice.taobao.com/contact-us">联系我们</a></span>
#     <span>
#       <a href="//www.taobao.com/sitemap.php">网站地图</a></span>
#     <span>
#       <a href="//www.taobao.com/go/chn/tb-fp/2014/law.php">法律声明及隐私权政策</a></span>
#     <span>
#       <a href="http://ipp.alibabagroup.com/">知识产权</a></span>
#     <b>|</b>
#     <em>&copy; 2003-2017 Taobao.com 版权所有</em></p>
#   <p>
#     <span>网络文化经营许可证：
#       <a href="//img.alicdn.com/tps/i2/TB1YFcPLpXXXXaiXFXXcaDpFFXX-803-473.png">浙网文[2013]0268-027号</a></span>
#     <b>|</b>
#     <span>增值电信业务经营许可证：
#       <a href="http://zcainfo.miitbeian.gov.cn/state/outPortal/loginPortal.action">浙B2-20080224</a></span>
#     <b>|</b>
#     <span>信息网络传播视听节目许可证：1109364号</span>
#     <b>|</b>
#     <span>互联网违法和不良信息举报电话:0571-81683755 blxx@list.alibaba-inc.com</span></p>
# </div>
# <div class="footer-ft">
#   <span>
#     <a style="background-position: 0px 0px;width:36px;background-image:url(//img.alicdn.com/tps/i1/T1FeW3XXNfXXXXXXXX-36-36.gif);" class="mod" href="http://www.pingpinganan.gov.cn/" target="_blank"></a>
#   </span>
#   <span>
#     <a style="background-position: 0px 0px;width:30px;" class="mod" href="http://idinfo.zjaic.gov.cn/bscx.do?spm=1.7274553.1997523009.28.alN7ce&amp;method=hddoc&amp;id=33018400000067" target="_blank"></a>
#   </span>
#   <span>
#     <a style="background-position: -40px 0px;width:33px;" class="mod" href="http://idinfo.zjaic.gov.cn/bscx.do?spm=1.7274553.1997523009.29.alN7ce&amp;method=hddoc&amp;id=33018400000067" target="_blank"></a>
#   </span>
#   <span>
#     <a style="background-position: -80px 0px;width:50px;" class="mod" href="http://www.theclimategroup.org.cn/about/friend?spm=1.7274553.1997523009.30.alN7ce" target="_blank"></a>
#   </span>
#   <span>
#     <a style="background-position: -140px 0px;width:83px;" class="mod" href="https://ss.knet.cn/verifyseal.dll?spm=1.7274553.1997523009.31.alN7ce&amp;&amp;sn=2010062300100001357&amp;pa=20100701" target="_blank"></a>
#   </span>
#   <span>
#     <a style="background-position: -240px 0px;width:94px;" class="mod" href="http://www.ppaaol.com/verifySite.do?spm=1.7274553.1997523009.32.alN7ce&amp;id=1051" target="_blank"></a>
#   </span>
#   <span>
#     <a style="background-position: -431px 0px;width:214px;" class="mod" href="http://www.12377.cn/" target="_blank"></a>
#   </span>
#   <span>
#     <a style="background-position: -650px 0px;width:105px;" class="mod" href="http://www.12377.cn/node_548446.htm" target="_blank"></a>
#   </span>
#   <span>
#     <a style="background-position: -345px 0px;width:82px;" class="mod" href="//img.alicdn.com/tps/i2/TB1YFcPLpXXXXaiXFXXcaDpFFXX-803-473.png" target="_blank"></a>
#   </span>
#   <span>
#     <a style="background-position: -761px 0px;width:97px;" class="mod" href="https://credit.szfw.org/CX20160715023573390688.html" target="_blank"></a>
#   </span>
#   <style>.footer .mod { background-image: url(https://img.alicdn.com/tps/TB1rMe2KVXXXXXpapXXXXXXXXXX-857-35.jpg); background-image: -webkit-image-set(https://img.alicdn.com/tps/TB1rMe2KVXXXXXpapXXXXXXXXXX-857-35.jpg 1x, https://img.alicdn.com/tps/TB1XY6eKVXXXXbfXFXXXXXXXXXX-1713-70.jpg 2x);}</style></div>
#   </div>
#         </textarea>
#     </div>
# </div>
#
#
# <!-- js 禁用提示 -->
# <noscript>
#     <style>
#         .srp-page {
#             display: none;
#         }
#
#         .js-disabled {
#             margin: 30px auto 0;
#             width: 990px;
#             height: 400px;
#             position: relative;
#         }
#
#         .js-disabled .logo {
#             position: absolute;
#             top: 0px;
#             left: 0;
#             width: 169px;
#             height: 42px
#         }
#
#         .js-disabled .bg {
#             width: 990px;
#             height: 400px;
#             background: url(//gtms03.alicdn.com/tps/i3/TB1x0j4FVXXXXbpXXXXvZjUHXXX-990-400.png) 0 0 no-repeat;
#         }
#
#         .js-disabled .text {
#             position: absolute;
#             top: 288px;
#             left: 475px;
#             color: #60636b;
#         }
#
#         .js-disabled .link {
#             color: #f40;
#         }
#
#         .js-disabled .bottom {
#             text-align: center;
#             color: #9c9c9c;
#         }
#     </style>
#
#     <div class="js-disabled">
#         <div class="bg"></div>
#         <a class="logo" href="//www.taobao.com"></a>
#
#         <p class="text">启用脚本才能显示当前页面, <a class="link"
#                                          href="//bangpai.taobao.com/group/thread/400769-7367089.htm#reply60023761"
#                                          target="_blank">点击启用</a></p>
#         <img src="/noscript.img" style="width: 0px;height: 0px;"/>
#
#         <p class="bottom">&copy; 2003-2017 Taobao.com 版权所有</p>
#     </div>
# </noscript>
#
#     <!-- hotfix from ems -->
# <style>
# .g_price strong{
#     font-family: arial;
#     letter-spacing: 0.8px;
# }
# .m-header .search .tab .arrow{
#     top: 13px;
# }
# </style>
# </body>
# </html>
# <!--<?php Yii::app()->wm->runWidget('debuginfo') ?>-->

# %%
res.text[:100]
# Out:
# '\r\n<!DOCTYPE html>\n<html lang="zh-CN">\n<head>\n    <meta charset="UTF-8">\n    <meta http-equiv="X-UA-C'

# %%
with open('taobao.html', 'w') as f:
    f.write(res.text)

# %%
with open('taobao.html', 'r') as f:
    print (f.read(100))
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Co

# %% [markdown]
# ## BS4

# %%
! pip3 install BeautifulSoup4
# Out:
# Collecting BeautifulSoup4
#   Using cached beautifulsoup4-4.6.0-py3-none-any.whl
# Installing collected packages: BeautifulSoup4
# Successfully installed BeautifulSoup4-4.6.0

# %%
from bs4 import BeautifulSoup

# %%
html_sample ='\
<html>\
<body>\
<h1 id="title">Hello World</h1>\
<a href ="#" class ="link"> This is link1 </a>\
<a href ="# link2" class ="link"> This is link2 </a>\
</body>\
</html>'

# %%
soup = BeautifulSoup(html_sample)
# Out:
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))

# %%
print (soup.text)
# Out:
# Hello World This is link1  This is link2

# %%
print (soup.contents)
# Out:
# [<html><head></head><body><h1 id="title">Hello World</h1><a class="link" href="#"> This is link1 </a><a class="link" href="# link2"> This is link2 </a></body></html>]

# %%
print (soup.select('h1')[0])
# Out:
# <h1 id="title">Hello World</h1>

# %%
print (soup.select('#title'))
# Out:
# [<h1 id="title">Hello World</h1>]

# %%
print (soup.select('.link'))
# Out:
# [<a class="link" href="#"> This is link1 </a>, <a class="link" href="# link2"> This is link2 </a>]

# %%
BeautifulSoup
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ## POST 方法

# %%
import requests

# %%
#先把post內容用字典包起來(用key-value方法)
payload ={
'StartStation:2f940836-cedc-41ef-8e28-c2336ac8fe68',
'EndStation:f2519629-5973-4d08-913b-479cce78a356',
'SearchDate:2017/07/05',
'SearchTime:06:00',
'SearchWay:DepartureInMandarin'
}

# %%
#加上網址列，再把包裝後的字典放入data
res = requests.post("https://www.thsrc.com.tw/tw/TimeTable/SearchResult",
                    data = payload)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in send(self, data)
#     985         try:
# --> 986             self.sock.sendall(data)
#     987         except TypeError:
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in sendall(self, data, flags)
#     964             while (count < amount):
# --> 965                 v = self.send(data[count:])
#     966                 count += v
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in send(self, data, flags)
#     934                     self.__class__)
# --> 935             return self._sslobj.write(data)
#     936         else:
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in write(self, data)
#     635         """
# --> 636         return self._sslobj.write(data)
#     637
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-15e5585c7cac> in <module>()
#       1 #加上網址列，再把包裝後的字典放入data
#       2 res = requests.post("https://www.thsrc.com.tw/tw/TimeTable/SearchResult",
# ----> 3                     data = payload)
#
# /usr/local/lib/python3.6/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     110     """
#     111
# --> 112     return request('post', url, data=data, json=json, **kwargs)
#     113
#     114
#
# /usr/local/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /usr/local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     500         }
#     501         send_kwargs.update(settings)
# --> 502         resp = self.send(prep, **send_kwargs)
#     503
#     504         return resp
#
# /usr/local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     610
#     611         # Send the request
# --> 612         r = adapter.send(request, **kwargs)
#     613
#     614         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /usr/local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     354             conn.request_chunked(method, url, **httplib_request_kw)
#     355         else:
# --> 356             conn.request(method, url, **httplib_request_kw)
#     357
#     358         # Reset the timeout for the recv() on the socket
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1063                     chunk = f'{len(chunk):X}\r\n'.encode('ascii') + chunk \
#    1064                         + b'\r\n'
# -> 1065                 self.send(chunk)
#    1066
#    1067             if encode_chunked and self._http_vsn == 11:
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in send(self, data)
#     988             if isinstance(data, collections.Iterable):
#     989                 for d in data:
# --> 990                     self.sock.sendall(d)
#     991             else:
#     992                 raise TypeError("data should be a bytes-like object "
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in sendall(self, data, flags)
#     963             count = 0
#     964             while (count < amount):
# --> 965                 v = self.send(data[count:])
#     966                 count += v
#     967         else:
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in send(self, data, flags)
#     933                     "non-zero flags not allowed in calls to send() on %s" %
#     934                     self.__class__)
# --> 935             return self._sslobj.write(data)
#     936         else:
#     937             return socket.send(self, data, flags)
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in write(self, data)
#     634         The 'data' argument must support the buffer interface.
#     635         """
# --> 636         return self._sslobj.write(data)
#     637
#     638     def getpeercert(self, binary_form=False):
#
# TypeError: a bytes-like object is required, not 'str'

# %%
print (res.text)
# Out:
# !function(){if(!(KISSY.UA.ie&&KISSY.UA.ie<8)){var r=/\w*.(?:pre.taobao.com|daily.taobao.net)/.test(location.href)?"/src/":"//g.alicdn.com/searchInteraction/keyword-brand-pc/0.0.6/";KISSY.config({packages:[{name:"keywordBrandPC",path:r,ignorePackageNameInUri:!0,debug:!0,combine:!1}]}),KISSY.config("modules",{"keywordBrandPC/_0":{requires:["keywordBrandPC/p/keyword-brand/index.css","json","node","overlay","keywordBrandPC/_1","cookie","tbc/mini-login/2.2.9/index"]},"keywordBrandPC/_1":{requires:["json"]},"keywordBrandPC/p/keyword-brand/index":{alias:"keywordBrandPC/_0"},"keywordBrandPC/p/keyword-brand/mtop":{alias:"keywordBrandPC/_1"}}),window.initKeywordBrandhb=function(r){r.status&&"show"===r.status&&r.data&&KISSY.use("keywordBrandPC/p/keyword-brand/",function(a,n){n.init(r.data)})}}}();

# %% [markdown]
# ## 老師的方法

# %%
import requests

# %%
payload = """StartStation:2f940836-cedc-41ef-8e28-c2336ac8fe68
EndStation:f2519629-5973-4d08-913b-479cce78a356
SearchDate:2017/07/05
SearchTime:06:00
SearchWay:DepartureInMandarin"""

# %%
def str2dict(data_str):
    data = {}
    for row in data_str.split('\n'):
        kv_list = row.split(":")
        data[kv_list[0]] = kv_list[1]
    return data

# %%
data = str2dict(payload)

# %%
str2dict("""StartStation:2f940836-cedc-41ef-8e28-c2336ac8fe68
EndStation:f2519629-5973-4d08-913b-479cce78a356
SearchDate:2017/07/05
SearchTime:06:00
SearchWay:DepartureInMandarin""")
# Out:
# {'EndStation': 'f2519629-5973-4d08-913b-479cce78a356',
#  'SearchDate': '2017/07/05',
#  'SearchTime': '06',
#  'SearchWay': 'DepartureInMandarin',
#  'StartStation': '2f940836-cedc-41ef-8e28-c2336ac8fe68'}

# %%
res = requests.post("https://www.thsrc.com.tw/tw/TimeTable/SearchResult",
                    data = data)

# %%
print (res.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-tw">
#
#
#
# <meta charset="utf-8" />
# <link rel="shortcut icon" href="/Content/favicon/favicon.ico" />
# <link rel="apple-touch-icon-precomposed" href="/Content/favicon/57_57.png" sizes="57x57" />
# <link rel="apple-touch-icon-precomposed" href="/Content/favicon/72_72.png" sizes="72x72" />
# <link rel="apple-touch-icon-precomposed" href="/Content/favicon/76_76.png" sizes="76x76" />
# <link rel="apple-touch-icon-precomposed" href="/Content/favicon/114_114.png" sizes="114x114" />
# <link rel="apple-touch-icon-precomposed" href="/Content/favicon/120_120.png" sizes="120x120" />
# <link rel="apple-touch-icon-precomposed" href="/Content/favicon/144_144.png" sizes="144x144" />
# <link rel="apple-touch-icon-precomposed" href="/Content/favicon/152_152.png" sizes="152x152" />
# <!--<meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=no, minimum-scale=1.0, maximum-scale=1.0" />-->
# <meta name="keywords" content="高鐵,快速,旅遊假期,遊玩">
# <meta name="description" content="台灣高鐵連結台灣南北主要城市，我們不只是交通運輸業，更是推動台灣­前進的服務業；我們代表的不僅只是速度，而是速度所帶來的現代生活新態度；我們以更文明的旅行體驗，成為你實現夢想的助力，台灣高鐵，實踐台灣新生活。">
# <meta name="author" content="mi70 uni-net" />
#
#
#     <meta http-equiv="cache-control" content="private">
#
#
# <!--Facebook SEO start-->
#
# <meta property="og:title" content="台灣高鐵" />
# <meta property="og:url" content="http://www.thsrc.com.tw/" />
# <meta property="og:image" content="http://www.thsrc.com.tw/Content/logo.jpg" />
# <!--Facebook SEO end-->
#
# <!--Google +1 start-->
# <meta itemprop="name" content="台灣高鐵" />
# <meta itemprop="description" content="台灣高鐵連結台灣南北主要城市，我們不只是交通運輸業，更是推動台灣­前進的服務業；我們代表的不僅只是速度，而是速度所帶來的現代生活新態度；我們以更文明的旅行體驗，成為你實現夢想的助力，台灣高鐵，實踐台灣新生活。" />
# <meta itemprop="image" content="http://www.thsrc.com.tw/Content/logo.jpg" />
# <!--Google +1 end-->
#
# <!--[if lt IE 9]>
# <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
# <script src="/Content/dist/html5shiv.js" type="text/javaScript"></script>
# <script src="/Content/dist/html5shiv-printshiv.js" type="text/javaScript"></script>
# <![endif]-->
# <!--[if IE 7]>
# <script src="//ie7-js.googlecode.com/svn/version/2.1(beta4)/IE9.js"></script>
# <![endif]-->
# <!--[if IE 8]>
# <script src="//ie7-js.googlecode.com/svn/version/2.1(beta4)/IE9.js"></script>
# <![endif]-->
# <!--[if IE 6]>
# <link href="/Content/css/pngFix.css"  rel="stylesheet" type="text/css" />
# <script src="/Content/iepngfix/iepngfix_tilebg.js" type="text/javaScript"></script>
# <![endif]-->
#
#
#
# <!-- Original CSS for the template -->
# <link href="/Content/css/css_reset.css" rel="stylesheet" type="text/css" />
#
# <!-------------------->
# <!-- CSS for jQuery -->
# <!-------------------->
# <link href="/Content/css/jquery-ui-1.8.5.custom.css" rel="stylesheet" type="text/css" />
# <link href="/Content/css/jquery.ui.datepicker.css"  rel="stylesheet" type="text/css" />
# <link href="/Content/Script/fancybox/jquery.fancybox-1.3.1.css" rel="stylesheet" type="text/css"  media="screen" />
#
#
# <script src="/Content/Script/jquery-1.8.3.min.js" type="text/javascript"></script>
# <script src="/Content/Script/jquery-ui-1.8.5.custom.min.js" type="text/javaScript"></script>
#
# <script src="/Content/Script/ui.datepicker-zh-TW.js" type="text/javaScript"></script>
#
# <script src="/Content/Script/jquery.ui.datepicker.js" type="text/javaScript"></script>
# <script src="/Content/Script/fancybox/jquery.mousewheel-3.0.2.pack.js" type="text/javaScript"></script>
# <script src="/Content/Script/fancybox/jquery.fancybox-1.3.1.js" type="text/javaScript"></script>
# <script src="/Content/Script/dateTool.js" type="text/javaScript"></script>
# <script src="/Content/Script/THSRC.Common.js" type="text/javaScript"></script>
# <script language="JavaScript" type="text/javascript">
#     if (top.location != self.location) {
#         location.href = "http://" + self.location.host + "/APPool/notice.html";
#     }
#     </script>
#
# <!-------------------->
# <!------ jQuery ------>
# <!-------------------->
#
# <script src="/Content/Script/jquery.validate.min.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.validate.extension.js" type="text/javaScript"></script>
# <script src="/Content/Script/date.js" type="text/javaScript"></script>
#
#
#
# <script src="/Content/Script/json2.js" type="text/javaScript"></script>
# <script src="/Content/Script/JSON4ms.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.tmpl.min.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.tmplPlus.min.js" type="text/javaScript"></script>
#
#
# <script src="/Content/Script/jquery.cookie.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.keyfilter.js" type="text/javaScript"></script>
#
# <script src="/Content/Script/jquery.easing.1.3.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.ui.core.js" type="text/javaScript"></script>
#
# <script src="/Content/Script/jquery.ui.mouse.js" type="text/javaScript"></script>
#
#
# <script src="/Content/Script/jquery.scrollTo-min.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.jqprint-0.3.js" type="text/javaScript"></script>
#
#
#
#
# <!------------------------------>
# <!-- Uninet Customize Library -->
# <!------------------------------>
# <script src="/Content/Script/check.js" type="text/javaScript"></script>
#
# <script src="/Content/Script/behaviour.js" type="text/javaScript"></script>
#
#
#
#
#
# <script src="/Content/Script/THSRC.Extends.js" type="text/javaScript"></script>
# <script src="/Content/Script/THSRC.Property.js" type="text/javaScript"></script>
# <script src="/Content/Script/THSRC.AjaxCheckBox.js" type="text/javaScript"></script>
# <script src="/Content/Script/THSRC.AjaxDropDownList.js" type="text/javaScript"></script>
# <script src="/Content/Script/FancyBox.js" type="text/javascript"></script>
# <script src="/Content/Script/nextPrevBtn.js" type="text/javascript"></script>
# <script src="/Content/Script/photoCenter.js" type="text/javascript"></script>
# <script src="/Content/Script/SocialMedia.ShareButton.js" type="text/javascript"></script>
#
# <head id="ctl00_Head1"><title>
#
#         台灣高鐵 Taiwan High Speed Rail - 時刻表與票價查詢
#
# </title></head>
#
# <link href="/Content/css/innerCommon.css"      rel="stylesheet" type="text/css">
#
# <link href="/Content/css/inner_all_common.css" rel="stylesheet" type="text/css">
# <link href="/Content/css/time_search.css"      rel="stylesheet" type="text/css">
#
# <link href="/Content/css/m_newStationLine.css"rel="stylesheet" type="text/css">
#
# <body>
#     <div class="wrapper">
#
#
# <header>
#             <h1><a href="/" title="TAIWAN HIGH SPEED RAIL" tabindex="1">台灣高鐵</a></h1>
#             <aside class="top_aside">
#
# <ul>
#     <li class="aaBtn"><a class="guildePoint" href="#" title="上方選單區" accesskey="U"><span style="color: white; margin: 0 8px 0 -8px;">:::</span><a href="/tw/SiteMap" title="網站導覽">網站導覽</a></a></li>
#     <li class="addLine"><a title='繁體中文'
#         href="/tw/Home/Index">
#         繁體中文
#     </a>
#     </li>
#     <li class="addLine">
#
#
#         <a title='日本語'
#         href="/jp/">
#         日本語</a>
#
#
#
#     </li>
#     <li class="addLine">
#
#
#         <a title='English'
#         href="/en/">
#         English</a>
#
#
#
#     </li>
# </ul>
# <form action="/tw/Home/Search" id="formWholeSiteSearch" method="post" name="formWholeSiteSearch">
#     <label for="searchBar"><span style="display:none;">全站查詢</span></label>
#     <input id="searchBar" name="searchBar" placeholder="請輸入查詢關鍵字" title="請輸入查詢關鍵字" type="text" value="" />
#     <input type="submit" id="searchBarSend" onkeypress="SubmitSearch();return false;" onclick="SubmitSearch();return false;" />
# </form>
# <script type="text/javascript">
#     function SubmitSearch() {
#         var keyword = $("#searchBar").val();
#         if (keyword != "") {
#             $("#formWholeSiteSearch").submit();
#         } else {
#             alert("請輸入搜尋內容");
#         }
#     }
# </script>
# <noscript>
# 請輸入搜尋內容
# </noscript>
#               <a href="https://www.facebook.com/thsrco" target="_blank" style="position:absolute; right:0px; top:34px;" title="連結粉絲專區[將另開新視窗]">
#     <img border="0" alt="粉絲專頁" src="/Content/images_cn/common/fb_thsrco.jpg"></a>
#             </aside>
#
#
#  <script type="text/javascript" src="/Content/Script/forListMenu.js"></script>
#   <script type="text/javascript" src="/Content/Script/jquery.bgiframe.js"></script>
#  <link href="/Content/css/common_list_menu.css" rel="stylesheet" type="text/css">
#  <link href="/Content/css/common_list_menu_en_jp.css" rel="stylesheet" type="text/css">
#
#
# <nav class="top_nav top_nav_tw">
# 	<ul>
# 	<li class="nav_hot" ><a href="/tw/SiteMap/#N" title = "優惠活動">優惠活動</a>
# 								<div class="dl height_304">
# 									<div class="first_list">
# 										<div class="has_photo_list"><img src="/event/index_img/nav_hot.jpg" width="200" height="120" alt="優惠活動" title = "優惠活動"></div>
# 										<div title =密集方便，高鐵提供您準點可靠的列車服務。 class="photo_list_word">密集方便，高鐵提供您準點可靠的列車服務。</div>
# 									</div>
# 									<div class="list_area list_area_tw">
# 								<div title ="購票優惠" class="dtnolink">購票優惠</div>
# <div class="dd">
# 							<a title = "早鳥優惠"  href="/tw/Article/ArticleContent/7039d17d-1463-4c14-ad93-4d491dedcad5" alt = "早鳥優惠"  >
# 							早鳥優惠
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "信用卡優惠專區"  href="/tw/Article/ArticleContent/566d6bff-4427-461d-8b88-b6c4868f75c9" alt = "信用卡優惠專區"  >
# 							信用卡優惠專區
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "學生暑期優惠"  href="/tw/Article/ArticleContent/0061e6f3-93ca-4161-9020-6f02ce4cce94" alt = "學生暑期優惠"  >
# 							學生暑期優惠
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "大學生優惠"  href="/tw/Article/ArticleContent/530e869c-479d-441a-a4b4-61a8166827e9" alt = "大學生優惠"  >
# 							大學生優惠
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "平日離峰96折"  href="/tw/Article/ArticleContent/e75eb64d-0cbf-42de-a7fb-dc43116be985" alt = "平日離峰96折"  >
# 							平日離峰96折
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "25人以上團體優惠"  href="/tw/Article/ArticleContent/89a14510-7982-4b5e-88af-074305bfefed" alt = "25人以上團體優惠"  >
# 							25人以上團體優惠
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "校外教學優惠"  href="/tw/Article/ArticleContent/ca09cf02-8f65-4f87-b25e-31cb9c0e187b" alt = "校外教學優惠"  >
# 							校外教學優惠
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "團體訂票"  href="/tw/Article/ArticleContent/41421730-b8ab-4fe3-b251-89e32cba8453" alt = "團體訂票"  >
# 							團體訂票
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "回數票優惠"  href="/tw/Article/ArticleContent/8f06ca76-ab2d-4b77-bc20-73218ce3b892" alt = "回數票優惠"  >
# 							回數票優惠
# 							</a>
# 							</div>
#
# 							</div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# 								<div class="dd">
# 							<a title = "定期票優惠"  href="/tw/Article/ArticleContent/b7b46e29-424c-4fc4-8ec7-0ab3031f2c9c" alt = "定期票優惠"  >
# 							定期票優惠
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "企業會員"  href="/tw/Article/ArticleContent/376238fd-2f6d-48f8-b070-9f2ea61b14b5" alt = "企業會員"  >
# 							企業會員
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "活動套票"  href="/tw/Article/ArticleContent/d794b386-96a7-445c-8a50-160862a037e9" alt = "活動套票"  >
# 							活動套票
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "高鐵假期[將另開新視窗 ]"  href="https://tholiday.thsrc.com.tw/" alt = "高鐵假期[將另開新視窗 ]" target="_blank" >
# 							高鐵假期<span style='display:none;'>[將另開新視窗 ]</span>
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "飯店聯票"  href="/tw/Article/ArticleContent/c2bae549-bc17-4373-a43a-3496780aa4ea" alt = "飯店聯票"  >
# 							飯店聯票
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "交通聯票"  href="/tw/Article/ArticleContent/5af4ceb8-4c6f-44ec-b02d-0c398c0ad917" alt = "交通聯票"  >
# 							交通聯票<em></em>
# 							</a>
# 							</div>
# <div title ="最新公告" class="dtnolink">最新公告</div>
# <div class="dd">
# 							<a title = "最新消息"  href="/tw/News/Index" alt = "最新消息"  >
# 							最新消息
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "列車運行狀況"  href="/tw/Operation/Index" alt = "列車運行狀況"  >
# 							列車運行狀況<em></em>
# 							</a>
# 							</div>
# <div title ="熱門活動" class="dtnolink">熱門活動</div>
#
# 							</div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# 								<div class="dd">
# 							<a title = "高鐵營隊(2017暑假)"  href="/tw/TCamp" alt = "高鐵營隊(2017暑假)"  >
# 							高鐵營隊(2017暑假)
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "活動合作"  href="/tw/Article/ArticleContent/99ba7783-c46e-4b68-849b-e9084e5a0e15" alt = "活動合作"  >
# 							活動合作
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "魔幻劇場親子列車"  href="/tw/Article/ArticleContent/7e969844-65df-46a6-9b78-b00f37d12ab8" alt = "魔幻劇場親子列車"  >
# 							魔幻劇場親子列車
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "「藝」起來高鐵"  href="/tw/Article/ArticleContent/d9eee6e4-3bc9-4c1b-8e5c-f471fd0b7539" alt = "「藝」起來高鐵"  >
# 							「藝」起來高鐵
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "真十感謝 美好未來[將另開新視窗 ]"  href="http://www.thsrc.com.tw/event/2017/10thAnniversary" alt = "真十感謝 美好未來[將另開新視窗 ]" target="_blank" >
# 							真十感謝 美好未來<span style='display:none;'>[將另開新視窗 ]</span>
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "高鐵探索館 暑期講座"  href="/tw/Article/ArticleContent/5cd921ee-e319-47a4-8677-dd5f352c2ad9" alt = "高鐵探索館 暑期講座"  >
# 							高鐵探索館 暑期講座<em></em>
# 							</a>
# 							</div>
#
# 							</div>
# <div class="list_line"></div>
#
# 								</div>
# 							</li>
# <li class="nav_ticket" ><a href="/tw/SiteMap/#T" title = "購票資訊">購票資訊</a>
# 								<div class="dl height_304">
# 									<div class="first_list">
# 										<div class="has_photo_list"><img src="/event/index_img/nav_ticket.jpg" width="200" height="120" alt="購票資訊" title = "購票資訊"></div>
# 										<div title =最新的購票優惠及列車資訊，快速掌握高鐵動態。 class="photo_list_word">最新的購票優惠及列車資訊，快速掌握高鐵動態。</div>
# 									</div>
# 									<div class="list_area list_area_tw">
# 								<div title ="票種說明" class="dtnolink">票種說明</div>
# <div class="dd">
# 							<a title = "票價產品一覽表"  href="/tw/Article/ArticleContent/caa6fac8-b875-4ad6-b1e6-96c2902d12a6" alt = "票價產品一覽表"  >
# 							票價產品一覽表<em></em>
# 							</a>
# 							</div>
# <div title ="如何購票" class="dtnolink">如何購票</div>
# <div class="dd">
# 							<a title = "網路訂票"  href="/tw/Article/ArticleContent/dea241a9-fe69-4e9d-b9a5-6caed6e486d6" alt = "網路訂票"  >
# 							網路訂票
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "「T-EX行動購票」App"  href="/tw/Article/ArticleContent/4d262503-84bc-4963-a58e-4ca1a6453ad3" alt = "「T-EX行動購票」App"  >
# 							「T-EX行動購票」App
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "便利商店購票"  href="/tw/Article/ArticleContent/baba745a-d802-440c-b762-3eef37b96b60" alt = "便利商店購票"  >
# 							便利商店購票
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "自動語音訂位服務"  href="/tw/Article/ArticleContent/7a96ad53-6efa-4c58-bb17-70c9f649b4e3" alt = "自動語音訂位服務"  >
# 							自動語音訂位服務
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "自動售票機購票"  href="/tw/Article/ArticleContent/6be4173c-91dc-4d06-ae3e-a19de420a237" alt = "自動售票機購票"  >
# 							自動售票機購票
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "團體訂票"  href="/tw/Article/ArticleContent/41421730-b8ab-4fe3-b251-89e32cba8453" alt = "團體訂票"  >
# 							團體訂票
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "車站窗口購票"  href="/tw/Article/ArticleContent/43d5e5e2-3777-46b9-bc8f-8b5b579b50ed" alt = "車站窗口購票"  >
# 							車站窗口購票
# 							</a>
# 							</div>
#
# 							</div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# 								<div class="dd">
# 							<a title = "悠遊聯名卡"  href="/tw/Article/ArticleContent/27bf64ed-5a99-4c0f-9021-dbe609998cdb" alt = "悠遊聯名卡"  >
# 							悠遊聯名卡
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "一卡通聯名卡"  href="/tw/Article/ArticleContent/ef3cff71-345c-4768-8d79-fdb75c956bbe" alt = "一卡通聯名卡"  >
# 							一卡通聯名卡
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "無障礙服務"  href="/tw/Article/ArticleContent/dba4ecd0-5ef0-45d2-aa64-bcecdf7d5fde" alt = "無障礙服務"  >
# 							無障礙服務<em></em>
# 							</a>
# 							</div>
# <div title ="快速查詢" class="dtnolink">快速查詢</div>
# <div class="dd">
# 							<a title = "2017年疏運日程表"  href="/tw/News/Detail/24fb760a-d9d8-4a05-9cd2-32f872dd3f8c/13" alt = "2017年疏運日程表"  >
# 							2017年疏運日程表
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "時刻表與票價查詢"  href="/tw/TimeTable/SearchResult" alt = "時刻表與票價查詢"  >
# 							時刻表與票價查詢<em></em>
# 							</a>
# 							</div>
# <div title ="電子票證搭乘紀錄查詢" class="dtnolink">電子票證搭乘紀錄查詢</div>
# <div class="dd">
# 							<a title = "T Express 搭乘紀錄[將另開新視窗 ]"  href="http://ptis.thsrc.com.tw/ptis/web_proof/texp_index.jsp" alt = "T Express 搭乘紀錄[將另開新視窗 ]" target="_blank" >
# 							T Express 搭乘紀錄<span style='display:none;'>[將另開新視窗 ]</span>
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "回數 / 定期票搭乘紀錄[將另開新視窗 ]"  href="http://ptis.thsrc.com.tw/ptis/web_proof/csc_travel.jsp" alt = "回數 / 定期票搭乘紀錄[將另開新視窗 ]" target="_blank" >
# 							回數 / 定期票搭乘紀錄<span style='display:none;'>[將另開新視窗 ]</span>
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "悠遊聯名卡搭乘紀錄[將另開新視窗 ]"  href="https://queryweb.tscc.com.tw/thsrc_web/" alt = "悠遊聯名卡搭乘紀錄[將另開新視窗 ]" target="_blank" >
# 							悠遊聯名卡搭乘紀錄<span style='display:none;'>[將另開新視窗 ]</span>
# 							</a>
# 							</div>
#
# 							</div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# 								<div class="dd">
# 							<a title = "一卡通聯名卡搭乘紀錄[將另開新視窗 ]"  href="https://www.i-pass.com.tw/ips/THSRC/" alt = "一卡通聯名卡搭乘紀錄[將另開新視窗 ]" target="_blank" >
# 							一卡通聯名卡搭乘紀錄<span style='display:none;'>[將另開新視窗 ]</span><span style='display:none;'>[將另開新視窗 ]</span><em></em>
# 							</a>
# 							</div>
# <div title ="企業會員" class="dtnolink">企業會員</div>
# <div class="dd">
# 							<a title = "加入企業會員"  href="/tw/Article/ArticleContent/376238fd-2f6d-48f8-b070-9f2ea61b14b5" alt = "加入企業會員"  >
# 							加入企業會員<em></em>
# 							</a>
# 							</div>
# <div title ="相關法規" class="dtnolink">相關法規</div>
# <div class="dd">
# 							<a title = "相關法規"  href="/tw/Article/ArticleContent/7de57796-db08-4d94-b183-bd62618859db" alt = "相關法規"  >
# 							相關法規<em></em>
# 							</a>
# 							</div>
#
# 							</div>
# <div class="list_line"></div>
#
# 								</div>
# 							</li>
# <li class="nav_info" ><a href="/tw/SiteMap/#C" title = "乘車指南">乘車指南</a>
# 								<div class="dl height_304">
# 									<div class="first_list">
# 										<div class="has_photo_list"><img src="/event/index_img/nav_info.jpg" width="200" height="120" alt="乘車指南" title = "乘車指南"></div>
# 										<div title =舒適的環境及便捷的交通轉乘，高鐵與您共創美好旅程。 class="photo_list_word">舒適的環境及便捷的交通轉乘，高鐵與您共創美好旅程。</div>
# 									</div>
# 									<div class="list_area list_area_tw">
# 								<div title ="車站資訊" class="dtnolink">車站資訊</div>
# <div class="dd">
# 							<a title = "南港站"  href="/tw/StationInfo/Prospect/2F940836-CEDC-41EF-8E28-C2336AC8FE68" alt = "南港站"  >
# 							南港站
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "台北站"  href="http://www.thsrc.com.tw/tw/StationInfo/prospect/977abb69-413a-4ccf-a109-0272c24fd490" alt = "台北站"  >
# 							台北站
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "板橋站"  href="/tw/StationInfo/Prospect/e6e26e66-7dc1-458f-b2f3-71ce65fdc95f" alt = "板橋站"  >
# 							板橋站
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "桃園站"  href="/tw/StationInfo/Prospect/fbd828d8-b1da-4b06-a3bd-680cdca4d2cd" alt = "桃園站"  >
# 							桃園站
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "新竹站"  href="/tw/StationInfo/Prospect/a7a04c89-900b-4798-95a3-c01c455622f4" alt = "新竹站"  >
# 							新竹站
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "苗栗站"  href="/tw/StationInfo/Prospect/E8FC2123-2AAF-46FF-AD79-51D4002A1EF3" alt = "苗栗站"  >
# 							苗栗站
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "台中站"  href="/tw/StationInfo/Prospect/3301e395-46b8-47aa-aa37-139e15708779" alt = "台中站"  >
# 							台中站
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "彰化站"  href="/tw/StationInfo/Prospect/38B8C40B-AEF0-4D66-B257-DA96EC51620E" alt = "彰化站"  >
# 							彰化站
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "雲林站"  href="/tw/StationInfo/Prospect/5F4C7BB0-C676-4E39-8D3C-F12FC188EE5F" alt = "雲林站"  >
# 							雲林站
# 							</a>
# 							</div>
#
# 							</div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# 								<div class="dd">
# 							<a title = "嘉義站"  href="/tw/StationInfo/Prospect/60831846-f0e4-47f6-9b5b-46323ebdcef7" alt = "嘉義站"  >
# 							嘉義站
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "台南站"  href="/tw/StationInfo/Prospect/9c5ac6ca-ec89-48f8-aab0-41b738cb1814" alt = "台南站"  >
# 							台南站
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "左營站"  href="/tw/StationInfo/Prospect/f2519629-5973-4d08-913b-479cce78a356" alt = "左營站"  >
# 							左營站<em></em>
# 							</a>
# 							</div>
# <div title ="轉乘服務" class="dtnolink">轉乘服務</div>
# <div class="dd">
# 							<a title = "轉乘服務總覽"  href="/tw/Article/ArticleContent/c2a8fd9d-ced6-43b1-9297-9eab4127b5ff" alt = "轉乘服務總覽"  >
# 							轉乘服務總覽<em></em>
# 							</a>
# 							</div>
# <div title ="服務與設施" class="dtnolink">服務與設施</div>
# <div class="dd">
# 							<a title = "服務與設施總覽"  href="/tw/Article/ArticleContent/9915abee-dc70-4ba3-9f6d-c425873c3475" alt = "服務與設施總覽"  >
# 							服務與設施總覽
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "無障礙服務"  href="http://www.thsrc.com.tw/tw/Article/ArticleContent/dba4ecd0-5ef0-45d2-aa64-bcecdf7d5fde" alt = "無障礙服務"  >
# 							無障礙服務
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "車廂介紹"  href="/tw/StationInfo/Accommondation" alt = "車廂介紹"  >
# 							車廂介紹
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "車廂服務介紹"  href="/tw/Article/ArticleContent/feb91116-8a73-46b7-a6b7-f115a3137ccf" alt = "車廂服務介紹"  >
# 							車廂服務介紹
# 							</a>
# 							</div>
#
# 							</div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# 								<div class="dd">
# 							<a title = "T Life 車上刊物"  href="/tw/Article/ArticleContent/2cc958af-c283-4efa-b6e6-22bb84ac5bab" alt = "T Life 車上刊物"  >
# 							T Life 車上刊物
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "多功能會議室"  href="/tw/Article/ArticleContent/347fa4fb-479d-4a90-b5aa-e0ba9b22ed41" alt = "多功能會議室"  >
# 							多功能會議室<em></em>
# 							</a>
# 							</div>
# <div title ="乘車安全" class="dtnolink">乘車安全</div>
# <div class="dd">
# 							<a title = "列車安全"  href="/tw/Article/ArticleContent/33741541-0f76-4397-a3f7-44367240a344" alt = "列車安全"  >
# 							列車安全
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "車站安全"  href="/tw/Article/ArticleContent/b47a688b-2115-4719-88bf-3b8b740d73e1" alt = "車站安全"  >
# 							車站安全
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "鐵路安全"  href="/tw/Article/ArticleContent/9780e036-5fdb-4c48-8732-1242beafafbd" alt = "鐵路安全"  >
# 							鐵路安全<em></em>
# 							</a>
# 							</div>
# <div title ="享樂購物趣" class="dtnolink">享樂購物趣</div>
# <div class="dd">
# 							<a title = "列車販售"  href="/tw/TShop/TrainShopping" alt = "列車販售"  >
# 							列車販售
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "紀念商品"  href="/tw/Souvenir" alt = "紀念商品"  >
# 							紀念商品
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "車站販售"  href="http://www.thsrc.com.tw/tw/TShop/FoodCourt/977abb69-413a-4ccf-a109-0272c24fd490" alt = "車站販售"  >
# 							車站販售<em></em>
# 							</a>
# 							</div>
#
# 							</div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# 								<div title ="注意事項" class="dtnolink">注意事項</div>
# <div class="dd">
# 							<a title = "乘車須知"  href="/tw/Article/ArticleContent/2f73bfbb-d9bb-400e-b806-f6c5ba539368" alt = "乘車須知"  >
# 							乘車須知
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "驗票閘門及通關"  href="/tw/Article/ArticleContent/4f77e9e6-f337-4af4-8f60-fbd6054e608f" alt = "驗票閘門及通關"  >
# 							驗票閘門及通關<em></em>
# 							</a>
# 							</div>
# <div title ="高鐵百科" class="dtnolink">高鐵百科</div>
# <div class="dd">
# 							<a title = "地震防護與應變[將另開新視窗 ]"  href="http://www.thsrc.com.tw/event/Encyclopedia/Earthquake/index.html" alt = "地震防護與應變[將另開新視窗 ]" target="_blank" >
# 							地震防護與應變<span style='display:none;'>[將另開新視窗 ]</span><span style='display:none;'>[將另開新視窗 ]</span><em></em>
# 							</a>
# 							</div>
#
# 							</div>
#
# 								</div>
# 							</li>
# <li class="nav_about" ><a href="/tw/Article/ArticleContent/841afa46-f7d7-4747-889c-b03469fdb455" title = "關於高鐵">關於高鐵</a>
# 								<div class="dl height_304">
# 									<div class="first_list">
# 										<div class="has_photo_list"><img src="/event/index_img/nav_about.jpg" width="200" height="120" alt="關於高鐵" title = "關於高鐵"></div>
# 										<div title =旅遊購物輕鬆滿足，高鐵生活好便利！ class="photo_list_word">旅遊購物輕鬆滿足，高鐵生活好便利！</div>
# 									</div>
# 									<div class="list_area list_area_tw">
# 								<div class="dt">
# 							<a title = "獲獎事蹟"  href="/tw/Article/ArticleContent/63d60a32-0600-4cd7-ac37-6ad8316b7f1e" alt = "獲獎事蹟"  >
# 							獲獎事蹟<em></em>
# 							</a>
# 							</div>
# <div title ="企業資訊" class="dtnolink">企業資訊</div>
# <div class="dd">
# 							<a title = "企業社會責任"  href="/tw/Article/ArticleContent/8d291a1a-90ba-4b0f-b4d5-db2a35d881f5" alt = "企業社會責任"  >
# 							企業社會責任
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "大事紀要"  href="/tw/Article/ArticleContent/b792e45d-5416-469b-82fd-ed383bef4691" alt = "大事紀要"  >
# 							大事紀要
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "企業識別"  href="/tw/Article/ArticleContent/605d1cb2-2d98-4d73-9586-7e8363ee44e3" alt = "企業識別"  >
# 							企業識別
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "環保工安與研發支出資訊"  href="/tw/Article/ArticleContent/34d8a763-9a98-4478-919c-6b88d07fecaa" alt = "環保工安與研發支出資訊"  >
# 							環保工安與研發支出資訊
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "高速鐵路運輸服務碳足跡"  href="/tw/Article/ArticleContent/5a1f4c72-b564-4706-bcdd-efbda93c3d93" alt = "高速鐵路運輸服務碳足跡"  >
# 							高速鐵路運輸服務碳足跡
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "高鐵專題報導"  href="/tw/Article/ArticleContent/d263299b-e2e0-4b13-be77-a7c82b2d2357" alt = "高鐵專題報導"  >
# 							高鐵專題報導<em></em>
# 							</a>
# 							</div>
# <div title ="營運現狀" class="dtnolink">營運現狀</div>
# <div class="dd">
# 							<a title = "營運年度概況"  href="/tw/Article/ArticleContent/1e07f685-045e-403c-bf92-88c2d86bf826" alt = "營運年度概況"  >
# 							營運年度概況<em></em>
# 							</a>
# 							</div>
#
# 							</div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# 								<div title ="政策法規" class="dtnolink">政策法規</div>
# <div class="dd">
# 							<a title = "線上購票交易注意事項"  href="/tw/Article/ArticleContent/291d80fe-080f-4442-90d0-9a9b82f119e5" alt = "線上購票交易注意事項"  >
# 							線上購票交易注意事項
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "個人資料保護專區"  href="/tw/Article/ArticleContent/d1fa3bcb-a016-47e2-88c6-7b7cbed00ed5" alt = "個人資料保護專區"  >
# 							個人資料保護專區
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "相關法規"  href="/tw/Article/ArticleContent/7de57796-db08-4d94-b183-bd62618859db" alt = "相關法規"  >
# 							相關法規<em></em>
# 							</a>
# 							</div>
# <div title ="合作夥伴" class="dtnolink">合作夥伴</div>
# <div class="dd">
# 							<a title = "業務申辦 "  href="/tw/Article/ArticleContent/4efcd63f-6d07-4363-8a52-26a4a4f462cb" alt = "業務申辦 "  >
# 							業務申辦 <em></em>
# 							</a>
# 							</div>
# <div class="dt">
# 							<a title = "招標資訊"  href="/tw/Tendering" alt = "招標資訊"  >
# 							招標資訊<em></em>
# 							</a>
# 							</div>
# <div title ="加入高鐵" class="dtnolink">加入高鐵</div>
# <div class="dd">
# 							<a title = "幸福高鐵"  href="/tw/Article/ArticleContent/91918831-5417-459a-9774-312f31a66ca2" alt = "幸福高鐵"  >
# 							幸福高鐵
# 							</a>
# 							</div>
#
# 							</div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# 								<div class="dd">
# 							<a title = "甄選流程"  href="/tw/Article/ArticleContent/923049a0-10dd-4c2f-927b-66e470c9c16e" alt = "甄選流程"  >
# 							甄選流程
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "我要應徵[將另開新視窗 ]"  href="http://ehrweb.104.com.tw/job.do?uno=16446274" alt = "我要應徵[將另開新視窗 ]" target="_blank" >
# 							我要應徵<span style='display:none;'>[將另開新視窗 ]</span><span style='display:none;'>[將另開新視窗 ]</span><em></em>
# 							</a>
# 							</div>
# <div class="dt">
# 							<a title = "高鐵探索館"  href="/tw/Article/ArticleContent/845f79cc-7a2b-496a-95ac-16810c19f8e0" alt = "高鐵探索館"  >
# 							高鐵探索館<em></em>
# 							</a>
# 							</div>
#
# 							</div>
# <div class="list_line"></div>
#
# 								</div>
# 							</li>
# <li class="nav_sponsor" ><a href="/tw//" title = "投資人關係">投資人關係</a>
# 								<div class="dl height_304">
# 									<div class="first_list">
# 										<div class="has_photo_list"><img src="/event/index_img/nav_sponsor.jpg" width="200" height="120" alt="投資人關係" title = "投資人關係"></div>
# 										<div title =與時間競速，與時代並進，高鐵期望與您一同展望更迅捷美好的未來。 class="photo_list_word">與時間競速，與時代並進，高鐵期望與您一同展望更迅捷美好的未來。</div>
# 									</div>
# 									<div class="list_area list_area_tw">
# 								<div title ="投資人關係" class="dtnolink">投資人關係</div>
# <div class="dd">
# 							<a title = "106年度股東常會訊息"  href="/tw/Article/ArticleContent/dc5d797c-f236-419a-976c-fe754597fc80" alt = "106年度股東常會訊息"  >
# 							106年度股東常會訊息
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "基本資料"  href="/tw/StockInfo/Index" alt = "基本資料"  >
# 							基本資料
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "組織系統圖"  href="/tw/Article/ArticleContent/07a19853-350d-42e4-b0c6-5bdd76c3ce7d" alt = "組織系統圖"  >
# 							組織系統圖
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "董事會及經營團隊"  href="/tw/Article/ArticleContent/eba2a49b-df9a-4955-9582-d3bfab0892d5" alt = "董事會及經營團隊"  >
# 							董事會及經營團隊
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "重大訊息"  href="http://www.thsrc.com.tw/tw/StockInfo/GreatNewsIndex" alt = "重大訊息"  >
# 							重大訊息
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "自結損益"  href="/tw/Article/ArticleContent/5aebf2ce-4186-463d-8a15-46234169e05b" alt = "自結損益"  >
# 							自結損益
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "文件下載"  href="/tw/Article/ArticleContent/d2933fd1-c223-46b0-9620-14a8501d6f51" alt = "文件下載"  >
# 							文件下載
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "法人說明會"  href="/tw/Article/ArticleContent/b1729e85-c1b4-498b-8354-a242178299bf" alt = "法人說明會"  >
# 							法人說明會<em></em>
# 							</a>
# 							</div>
# <div class="dt">
# 							<a title = "利害關係人"  href="/tw/Article/ArticleContent/699e4e91-3cdd-422c-8dc4-ed8747a11195" alt = "利害關係人"  >
# 							利害關係人<em></em>
# 							</a>
# 							</div>
#
# 							</div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# 								<div class="dt">
# 							<a title = "企業社會責任報告書"  href="/tw/Article/ArticleContent/8d291a1a-90ba-4b0f-b4d5-db2a35d881f5" alt = "企業社會責任報告書"  >
# 							企業社會責任報告書<em></em>
# 							</a>
# 							</div>
#
# 							</div>
# <div class="list_line"></div>
#
# 								</div>
# 							</li>
# <li class="nav_life" ><a href="/tw/Article/ArticleContent/383d9d45-698b-4e17-a84f-c7cb90b5adc5" title = "搭高鐵‧遊台灣">搭高鐵‧遊台灣</a>
# 								<div class="dl height_304">
# 									<div class="first_list">
# 										<div class="has_photo_list"><img src="/event/index_img/nav_life.jpg" width="200" height="120" alt="搭高鐵‧遊台灣" title = "搭高鐵‧遊台灣"></div>
# 										<div title =搭高鐵•遊台灣 體驗台灣在地美好！ class="photo_list_word">搭高鐵•遊台灣 體驗台灣在地美好！</div>
# 									</div>
# 									<div class="list_area list_area_tw">
# 								<div class="dt">
# 							<a title = "高鐵假期[將另開新視窗]"  href="https://tholiday.thsrc.com.tw/" alt = "高鐵假期[將另開新視窗]" target="_blank" >
# 							高鐵假期
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "夏季號[將另開新視窗 ]"  href="https://tholiday.thsrc.com.tw/agts_thw/list?themeUuid=0E23A736-3205-462E-A7C2-8A9A11406C49" alt = "夏季號[將另開新視窗 ]" target="_blank" >
# 							夏季號<span style='display:none;'>[將另開新視窗 ]</span>
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "超值一日豐富行[將另開新視窗 ]"  href="https://tholiday.thsrc.com.tw/agts_thw/list?themeUuid=6BA7B081-AF33-4570-9871-FB5983AA2E19" alt = "超值一日豐富行[將另開新視窗 ]" target="_blank" >
# 							超值一日豐富行<span style='display:none;'>[將另開新視窗 ]</span>
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "國家公園系列遊[將另開新視窗 ]"  href="https://tholiday.thsrc.com.tw/agts_thw/list?themeUuid=798E5384-D894-4C8F-9096-823AC1923584" alt = "國家公園系列遊[將另開新視窗 ]" target="_blank" >
# 							國家公園系列遊<span style='display:none;'>[將另開新視窗 ]</span>
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "搭雙鐵•遊集集[將另開新視窗 ]"  href="https://tholiday.thsrc.com.tw/agts_thw/list?themeUuid=6EFDB055-0A5C-4D8A-B4E9-4F49E04792F2" alt = "搭雙鐵•遊集集[將另開新視窗 ]" target="_blank" >
# 							搭雙鐵•遊集集<span style='display:none;'>[將另開新視窗 ]</span>
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "親子Fun假旅遊趣[將另開新視窗 ]"  href="https://tholiday.thsrc.com.tw/agts_thw/list?themeUuid=AF80FF3B-9535-449A-BBFD-122C7ED6BF2C" alt = "親子Fun假旅遊趣[將另開新視窗 ]" target="_blank" >
# 							親子Fun假旅遊趣<span style='display:none;'>[將另開新視窗 ]</span>
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "森林探險涼夏遊[將另開新視窗 ]"  href="http://tholiday.thsrc.com.tw/agts_thw/list?themeUuid=50EA66CB-AF8B-40A0-B3DC-F2601A0F0DC6" alt = "森林探險涼夏遊[將另開新視窗 ]" target="_blank" >
# 							森林探險涼夏遊<span style='display:none;'>[將另開新視窗 ]</span><span style='display:none;'>[將另開新視窗 ]</span><em></em>
# 							</a>
# 							</div>
# <div class="dt">
# 							<a title = "交通聯票"  href="/tw/Article/ArticleContent/5af4ceb8-4c6f-44ec-b02d-0c398c0ad917" alt = "交通聯票"  >
# 							交通聯票
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "高鐵＋高雄好玩卡"  href="/tw/Article/ArticleContent/cb7aecfb-80d6-4956-939d-ef2387ea142b" alt = "高鐵＋高雄好玩卡"  >
# 							高鐵＋高雄好玩卡
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "高鐵+高雄捷運"  href="/tw/Article/ArticleContent/842a6c80-c554-4bf3-810c-d026409045e7" alt = "高鐵+高雄捷運"  >
# 							高鐵+高雄捷運
# 							</a>
# 							</div>
#
# 							</div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# 								<div class="dd">
# 							<a title = "高鐵+台灣好行"  href="http://www.thsrc.com.tw/tw/Article/ArticleContent/5af4ceb8-4c6f-44ec-b02d-0c398c0ad917#theGo1" alt = "高鐵+台灣好行"  >
# 							高鐵+台灣好行
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "高鐵+航空公司"  href="http://www.thsrc.com.tw/tw/Article/ArticleContent/5af4ceb8-4c6f-44ec-b02d-0c398c0ad917#theGo9" alt = "高鐵+航空公司"  >
# 							高鐵+航空公司
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "高鐵＋北捷雙層巴士"  href="/tw/Article/ArticleContent/bbf55ee3-c17e-4e13-bbd0-6a387aafd2a6" alt = "高鐵＋北捷雙層巴士"  >
# 							高鐵＋北捷雙層巴士<em></em>
# 							</a>
# 							</div>
# <div class="dt">
# 							<a title = "飯店聯票"  href="/tw/Article/ArticleContent/c2bae549-bc17-4373-a43a-3496780aa4ea" alt = "飯店聯票"  >
# 							飯店聯票
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "北部飯店"  href="/tw/Article/ArticleContent/84b5f8e5-98b5-48b5-bc5f-9a24cfe6119a" alt = "北部飯店"  >
# 							北部飯店
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "中部飯店"  href="/tw/Article/ArticleContent/6fdec9c4-0da5-4a67-b38d-5c11d538b7c0" alt = "中部飯店"  >
# 							中部飯店
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "南部飯店"  href="/tw/Article/ArticleContent/d157819a-dd4e-4191-b60c-5645b02432d6" alt = "南部飯店"  >
# 							南部飯店
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "東部飯店"  href="/tw/Article/ArticleContent/ae14d887-26c3-4c6f-9811-d8a88c17abd9" alt = "東部飯店"  >
# 							東部飯店
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "豪華星級享樂遊"  href="/tw/Article/ArticleContent/bbb690c1-d388-4692-bc95-0d12a81b1b81" alt = "豪華星級享樂遊"  >
# 							豪華星級享樂遊
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "小資精省旅遊趣"  href="/tw/Article/ArticleContent/ccd52eb1-80ab-4895-ab94-f412f45e9dbf" alt = "小資精省旅遊趣"  >
# 							小資精省旅遊趣
# 							</a>
# 							</div>
#
# 							</div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# 								<div class="dd">
# 							<a title = "豔夏時光 大小朋友瘋出遊"  href="/tw/Article/ArticleContent/62de917a-7c01-430a-abe6-1807518e83b0" alt = "豔夏時光 大小朋友瘋出遊"  >
# 							豔夏時光 大小朋友瘋出遊
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "綠野仙蹤樂悠遊"  href="/tw/Article/ArticleContent/52ba1070-2ad5-4b00-9491-68de4915ceb8" alt = "綠野仙蹤樂悠遊"  >
# 							綠野仙蹤樂悠遊
# 							</a>
# 							</div>
# <div class="dd">
# 							<a title = "湖光水色輕旅行"  href="/tw/Article/ArticleContent/90b947cd-cca8-464e-9424-d89cad764727" alt = "湖光水色輕旅行"  >
# 							湖光水色輕旅行<em></em>
# 							</a>
# 							</div>
# <div class="dt">
# 							<a title = "搭高鐵．遊台灣"  href="/tw/Article/ArticleContent/383d9d45-698b-4e17-a84f-c7cb90b5adc5" alt = "搭高鐵．遊台灣"  >
# 							搭高鐵．遊台灣<em></em>
# 							</a>
# 							</div>
#
# 							</div>
# <div class="list_line"></div>
#
# 								</div>
# 							</li>
# <li class="top_24hours">
# 								<a href="https://irs.thsrc.com.tw/IMINT?locale=tw" alt = "24小時網路訂票[將另開新視窗]" title = "24小時網路訂票[將另開新視窗]" target="_blank">24小時網路訂票[將另開新視窗]</a>
#
# 	</ul>
# </nav>
#
# </header>
#
#         <div id="printcontent">
#
#
# <aside class="ticket_bread">
#
# <div class="ticket_bread_left">
#     <ul>
#
#                <li class="ticket_bread_one"><a href="#" class="aaBrick" title="主要內容區" accesskey="C"><span>:::</span></a><a title='首頁'  href="/">首頁</a></li>
#
#                     <li><a href="/tw/SiteMap/#T" title='購票資訊'>購票資訊</a></li>
#
#                     <li><a href="/tw" title='快速查詢'>快速查詢</a></li>
#
#                 <li><a class="current" href="javascript:;" title='時刻表與票價查詢' style="cursor:default">時刻表與票價查詢</a></li>
#
#     </ul>
#     <br />
# </div>
# <!--ticket_bread_left-->
#             <div class="ticket_bread_right">
#
# <!--Content_Start-->
#
#     <noscript style="
#     position: absolute;
#     top: 55px;
#     right: 0px;
#     line-height: 18px;
#     width: 500px;
#     z-index:100;
#     background:#FFF;
# " >
#     <p>友善列印SCRIPT，如您的瀏覽器不支援，請利用鍵盤按住Ctrl鍵 + P。 <br />
#      字級大小SCRIPT，如您的瀏覽器不支援，IE6請利用鍵盤按住ALT鍵 + V → X → (G)最大><br />
#      (L)較大(M)中(S)較小(A)小，來選擇適合您的文字大小，如為IE7或Firefoxy與Chrome瀏覽器則<br />
#      可利用鍵盤 Ctrl + (+)放大 (-)縮小來改變字型大小。</p>
#      </noscript>
#
#     <a class="print_this" href="javascript:;" title="列印本頁">列印本頁</a>
#
#     <!--Content_End-->
#             </div>
#
#             <script type="text/javascript">
#                 /*字體大小區-------------------------------------------------------------------------------------------*/
#                 $(document).ready(function () {
#                     $('.ticket_bread_right ol li').click(function () {
#                         $('.ticket_bread_right ol li').removeClass('current');
#                         $(this).addClass('current');
#                         switch ($(this).index()) {
#                             case 0:
#                                 $('.word_size').css('font-size', '18px');
#                                 break;
#                             case 1:
#                                 $('.word_size').css('font-size', '15px');
#                                 break;
#                             case 2:
#                                 $('.word_size').css('font-size', '12px');
#                                 break;
#
#                         }
#
#                     });
#                     $('.ticket_bread_right ol li').keypress(function () {
#                         $('.ticket_bread_right ol li').removeClass('current');
#                         $(this).addClass('current');
#                         switch ($(this).index()) {
#                             case 0:
#                                 $('.word_size').css('font-size', '18px');
#                                 break;
#                             case 1:
#                                 $('.word_size').css('font-size', '15px');
#                                 break;
#                             case 2:
#                                 $('.word_size').css('font-size', '12px');
#                                 break;
#
#                         }
#
#                     });
#                 });
#                 /*字體大小區 End-------------------------------------------------------------------------------------------*/
#             </script>
# </aside>
# <!--ticket_bread-->
# <!--print js-->
# <script src="/Content/Script/printFunction.js" type="text/javascript"></script>
# <!--print js-->
# <!--主要內容區導盲磚-->
#
# <section class="common_content">
#     <br/>
#     <h2 class="time_search_title" title = "時刻表與票價查詢">時刻表與票價查詢</h2>
#     <section class="time_check time_check_tw">
#         <h3 class="time_check_title time_check_title_tw" title = "請選擇查詢條件">請選擇查詢條件 </h3>
#         <section class="time_check_left time_check_left_tw">
#    		    <form action="/tw/TimeTable/SearchResult" id="formQuickTimeTableSearch" method="post" name="formQuickTimeTableSearch">
#     <fieldset class="start_time">
#
#         <label for="StartStation">出發站<em> : </em>
#         <select id="StartStation" name="StartStation"  style="width: 155px;" ><option value='' > 請選擇</option>
# <option value='2f940836-cedc-41ef-8e28-c2336ac8fe68' selected> 南港站</option>
# <option value='977abb69-413a-4ccf-a109-0272c24fd490' > 台北站</option>
# <option value='e6e26e66-7dc1-458f-b2f3-71ce65fdc95f' > 板橋站</option>
# <option value='fbd828d8-b1da-4b06-a3bd-680cdca4d2cd' > 桃園站</option>
# <option value='a7a04c89-900b-4798-95a3-c01c455622f4' > 新竹站</option>
# <option value='e8fc2123-2aaf-46ff-ad79-51d4002a1ef3' > 苗栗站</option>
# <option value='3301e395-46b8-47aa-aa37-139e15708779' > 台中站</option>
# <option value='38b8c40b-aef0-4d66-b257-da96ec51620e' > 彰化站</option>
# <option value='5f4c7bb0-c676-4e39-8d3c-f12fc188ee5f' > 雲林站</option>
# <option value='60831846-f0e4-47f6-9b5b-46323ebdcef7' > 嘉義站</option>
# <option value='9c5ac6ca-ec89-48f8-aab0-41b738cb1814' > 台南站</option>
# <option value='f2519629-5973-4d08-913b-479cce78a356' > 左營站</option>
# </select>
#
#     </fieldset>
#     <fieldset class="end_time end_time_tw">
#
#         <label for="EndStation">到達站<em> : </em></label>
#         <select id="EndStation" name="EndStation"  style="width: 155px;" ><option value='' > 請選擇</option>
# <option value='2f940836-cedc-41ef-8e28-c2336ac8fe68' > 南港站</option>
# <option value='977abb69-413a-4ccf-a109-0272c24fd490' > 台北站</option>
# <option value='e6e26e66-7dc1-458f-b2f3-71ce65fdc95f' > 板橋站</option>
# <option value='fbd828d8-b1da-4b06-a3bd-680cdca4d2cd' > 桃園站</option>
# <option value='a7a04c89-900b-4798-95a3-c01c455622f4' > 新竹站</option>
# <option value='e8fc2123-2aaf-46ff-ad79-51d4002a1ef3' > 苗栗站</option>
# <option value='3301e395-46b8-47aa-aa37-139e15708779' > 台中站</option>
# <option value='38b8c40b-aef0-4d66-b257-da96ec51620e' > 彰化站</option>
# <option value='5f4c7bb0-c676-4e39-8d3c-f12fc188ee5f' > 雲林站</option>
# <option value='60831846-f0e4-47f6-9b5b-46323ebdcef7' > 嘉義站</option>
# <option value='9c5ac6ca-ec89-48f8-aab0-41b738cb1814' > 台南站</option>
# <option value='f2519629-5973-4d08-913b-479cce78a356' selected> 左營站</option>
# </select>
#
#     </fieldset>
#     <fieldset class="date_for date_for_tw">
#
#         <label for="SearchDate">日 期<em> : </em></label>
#             <input class="datemodel" id="SearchDate" name="SearchDate" placeholder="西元年/月/日" size="12" type="textbox" value="2017/07/05" /><script>
# $(document).ready(function() {
# $("#SearchDate").datepicker("option", "minDate", new Date(2017, 7 - 1, 5));
# $("#SearchDate").datepicker("option", "maxDate", new Date(2017, 8 - 1, 1));
# });
# </script>
#
#     </fieldset>
#     <fieldset class="which_time which_time_tw">
#
#             <label for="SearchTime">時 間<em> : </em></label>
#             <select id="SearchTime" name="SearchTime" style="width: 100px;"><option value="">請選擇</option>
# <option value="06:00">06:00</option>
# <option value="06:30">06:30</option>
# <option value="07:00">07:00</option>
# <option value="07:30">07:30</option>
# <option value="08:00">08:00</option>
# <option value="08:30">08:30</option>
# <option value="09:00">09:00</option>
# <option value="09:30">09:30</option>
# <option value="10:00">10:00</option>
# <option value="10:30">10:30</option>
# <option value="11:00">11:00</option>
# <option value="11:30">11:30</option>
# <option value="12:00">12:00</option>
# <option value="12:30">12:30</option>
# <option value="13:00">13:00</option>
# <option value="13:30">13:30</option>
# <option value="14:00">14:00</option>
# <option value="14:30">14:30</option>
# <option value="15:00">15:00</option>
# <option value="15:30">15:30</option>
# <option value="16:00">16:00</option>
# <option value="16:30">16:30</option>
# <option value="17:00">17:00</option>
# <option value="17:30">17:30</option>
# <option value="18:00">18:00</option>
# <option value="18:30">18:30</option>
# <option value="19:00">19:00</option>
# <option value="19:30">19:30</option>
# <option value="20:00">20:00</option>
# <option value="20:30">20:30</option>
# <option value="21:00">21:00</option>
# <option value="21:30">21:30</option>
# <option value="22:00">22:00</option>
# <option value="22:30">22:30</option>
# <option value="23:00">23:00</option>
# <option value="23:30">23:30</option>
# </select>
#
#              <label for="SearchWay"></label>
#            <select id="SearchWay" name="SearchWay"  style="width: 60px;" ><option value='DepartureInMandarin' selected> 出發</option>
# <option value='ArrivalInMandarin' > 抵達</option>
# </select>
#
#             <input id="RestTime" name="RestTime" type="hidden" value="" />
#             <input id="EarlyOrLater" name="EarlyOrLater" type="hidden" value="" />
#     </fieldset>
#
#     <fieldset class="apply_sale">
#     <label >適用優惠<em> : </em></label>
#     <div class="apply_saleitems" >
#     <input type="checkbox" id="DiscountType" name="DiscountType" value="e1b4c4d9-98d7-4c8c-9834-e1d2528750f1"  /><label for="e1b4c4d9-98d7-4c8c-9834-e1d2528750f1">早鳥</label>
# <input type="checkbox" id="DiscountType" name="DiscountType" value="68d9fc7b-7330-44c2-962a-74bc47d2ee8a"  /><label for="68d9fc7b-7330-44c2-962a-74bc47d2ee8a">大學生</label>
# <input type="checkbox" id="DiscountType" name="DiscountType" value="4baae6e5-b42c-474b-a194-ff8f1783c7bb"  /><label for="4baae6e5-b42c-474b-a194-ff8f1783c7bb">25人團體</label>
# <input type="checkbox" id="DiscountType" name="DiscountType" value="40863ff1-a16c-4da1-8af7-c1f8991627f3"  /><label for="40863ff1-a16c-4da1-8af7-c1f8991627f3">校外教學</label>
# <input type="checkbox" id="DiscountType" name="DiscountType" value="6e5fe76b-a522-4f5c-b17a-26c8f395b87a"  /><label for="6e5fe76b-a522-4f5c-b17a-26c8f395b87a">平日離峰</label>
# <input type="checkbox" id="DiscountType" name="DiscountType" value="7b83e661-1ac2-4fb7-8a06-495158d73170"  /><label for="7b83e661-1ac2-4fb7-8a06-495158d73170">學生暑期</label>
#
#     </div>
#     <script>
#         var bol = $("input[type=checkbox][name=DiscountType]:checked").length >= 4;
#         $("input[type=checkbox][name=DiscountType]").not(":checked").attr("disabled", bol);
#         $("input[type=checkbox][name=DiscountType]").click(function () {
#             bol = $("input[type=checkbox][name=DiscountType]:checked").length >= 4;
#             $("input[type=checkbox][name=DiscountType]").not(":checked").attr("disabled", bol);
#         });
#     </script>
#     </fieldset>
#
#     <input class="time_search_btn time_search_btn_tw" type="submit" value="立即查詢" title = "立即查詢"  onkeypress="QuickSearchSubmit();return false;" onclick="QuickSearchSubmit();return false;" />
# </form>
# <script type="text/javascript">
#     $(document).ready(function () {
#
#
# //            $("#SearchDate").attr("readonly", "true");
#     });
#
#     function QuickSearchSubmit() {
#         var startStation = $("#StartStation").val();
#         var endStation = $("#EndStation").val();
#         var time = $("#SearchTime").val();
#
#         if (startStation == "" || endStation == "")
#             alert("請選擇出發 / 到達站");
#         else if (time == "")
#             alert("請選擇時間");
#         else if (startStation == endStation)
#             alert("起站與迄站不能設為相同");
#         else
#             $("#formQuickTimeTableSearch").submit();
#     }
#
#     function RestTrainSubmit(restTime, earlyOrLater) {
#         $("#RestTime").val(restTime);
#         $("#EarlyOrLater").val(earlyOrLater);
#         QuickSearchSubmit();
#     }
#
# </script>
#  <noscript>
#  請選擇出發 / 到達站
#  請選擇時間
#  起站與迄站不能設為相同
#  </noscript>
#
#         </section>
#
#
#
#
# <!--time_check_right-->
# <section class="time_check_right time_check_right_tw">
#     <h4 title = "時刻表下載">時刻表下載</h4>
#
#     <ul>
# ...
#                                             <td class='Width1'>&nbsp;</td>
#                                             <td>&nbsp;</td>
#                                           </tr>
#                                         </table>
#                                         <div class="touch_show">
#                                     <section class="touch_table_info touch_table_info_tw">
#                                     		<a class="touch_close" href="?ID=" title = "close">close</a>
#                                             <h3><strong>0613 列車 </strong>停靠說明 </h3>
#                                                <ul>
#                                                <li class="station05  current"><a href="javascript:;" title = "南港站">南港站</a><em>08:10</em></li>
# <li class="station10  current"><a href="javascript:;" title = "台北站">台北站</a><em>08:21</em></li>
# <li class="station15  current"><a href="javascript:;" title = "板橋站">板橋站</a><em>08:29</em></li>
# <li class="station20  current"><a href="javascript:;" title = "桃園站">桃園站</a><em>08:43</em></li>
# <li class="station25  current"><a href="javascript:;" title = "新竹站">新竹站</a><em>08:56</em></li>
# <li class="station30  "><a href="javascript:;" title = "苗栗站">苗栗站</a><em></em></li>
# <li class="station40  current"><a href="javascript:;" title = "台中站">台中站</a><em>09:25</em></li>
# <li class="station45  "><a href="javascript:;" title = "彰化站">彰化站</a><em></em></li>
# <li class="station50  "><a href="javascript:;" title = "雲林站">雲林站</a><em></em></li>
# <li class="station55  current"><a href="javascript:;" title = "嘉義站">嘉義站</a><em>09:50</em></li>
# <li class="station65  current"><a href="javascript:;" title = "台南站">台南站</a><em>10:07</em></li>
# <li class="station75  current"><a href="javascript:;" title = "左營站">左營站</a><em>10:20</em></li>
#
#                                                </ul>
#                                              <h4> </h4>
#                                     </section>
#                                  </div>
#
#                                     </td>
#                                   </tr>
# <tr>
#                                     <td class="toTouch" colspan="7">
#                                         <table class="touch_table"><tr>
#                                             <td  class="column1"><a href="?ID=" title = "0113">0113</a></td>
#                                             <td  class="column3">08:20</td>
#                                             <td  class="column4">10:05</td>
#                                             <td class="column2">01:45</td>
#                                             <td class='Width1'>&nbsp;</td>
#                                             <td>&nbsp;</td>
#                                           </tr>
#                                         </table>
#                                         <div class="touch_show">
#                                     <section class="touch_table_info touch_table_info_tw">
#                                     		<a class="touch_close" href="?ID=" title = "close">close</a>
#                                             <h3><strong>0113 列車 </strong>停靠說明 </h3>
#                                                <ul>
#                                                <li class="station05  current"><a href="javascript:;" title = "南港站">南港站</a><em>08:20</em></li>
# <li class="station10  current"><a href="javascript:;" title = "台北站">台北站</a><em>08:31</em></li>
# <li class="station15  current"><a href="javascript:;" title = "板橋站">板橋站</a><em>08:39</em></li>
# <li class="station20  "><a href="javascript:;" title = "桃園站">桃園站</a><em></em></li>
# <li class="station25  "><a href="javascript:;" title = "新竹站">新竹站</a><em></em></li>
# <li class="station30  "><a href="javascript:;" title = "苗栗站">苗栗站</a><em></em></li>
# <li class="station40  current"><a href="javascript:;" title = "台中站">台中站</a><em>09:20</em></li>
# <li class="station45  "><a href="javascript:;" title = "彰化站">彰化站</a><em></em></li>
# <li class="station50  "><a href="javascript:;" title = "雲林站">雲林站</a><em></em></li>
# <li class="station55  "><a href="javascript:;" title = "嘉義站">嘉義站</a><em></em></li>
# <li class="station65  "><a href="javascript:;" title = "台南站">台南站</a><em></em></li>
# <li class="station75  current"><a href="javascript:;" title = "左營站">左營站</a><em>10:05</em></li>
#
#                                                </ul>
#                                              <h4> </h4>
#                                     </section>
#                                  </div>
#
#                                     </td>
#                                   </tr>
# <tr>
#                                     <td class="toTouch" colspan="7">
#                                         <table class="touch_table"><tr>
#                                             <td  class="column1"><a href="?ID=" title = "0615">0615</a></td>
#                                             <td  class="column3">08:35</td>
#                                             <td  class="column4">10:45</td>
#                                             <td class="column2">02:10</td>
#                                             <td class='Width1'>&nbsp;</td>
#                                             <td>&nbsp;</td>
#                                           </tr>
#                                         </table>
#                                         <div class="touch_show">
#                                     <section class="touch_table_info touch_table_info_tw">
#                                     		<a class="touch_close" href="?ID=" title = "close">close</a>
#                                             <h3><strong>0615 列車 </strong>停靠說明 </h3>
#                                                <ul>
#                                                <li class="station05  current"><a href="javascript:;" title = "南港站">南港站</a><em>08:35</em></li>
# <li class="station10  current"><a href="javascript:;" title = "台北站">台北站</a><em>08:46</em></li>
# <li class="station15  current"><a href="javascript:;" title = "板橋站">板橋站</a><em>08:55</em></li>
# <li class="station20  current"><a href="javascript:;" title = "桃園站">桃園站</a><em>09:10</em></li>
# <li class="station25  current"><a href="javascript:;" title = "新竹站">新竹站</a><em>09:22</em></li>
# <li class="station30  "><a href="javascript:;" title = "苗栗站">苗栗站</a><em></em></li>
# <li class="station40  current"><a href="javascript:;" title = "台中站">台中站</a><em>09:48</em></li>
# <li class="station45  "><a href="javascript:;" title = "彰化站">彰化站</a><em></em></li>
# <li class="station50  "><a href="javascript:;" title = "雲林站">雲林站</a><em></em></li>
# <li class="station55  current"><a href="javascript:;" title = "嘉義站">嘉義站</a><em>10:14</em></li>
# <li class="station65  current"><a href="javascript:;" title = "台南站">台南站</a><em>10:33</em></li>
# <li class="station75  current"><a href="javascript:;" title = "左營站">左營站</a><em>10:45</em></li>
#
#                                                </ul>
#                                              <h4> </h4>
#                                     </section>
#                                  </div>
#
#                                     </td>
#                                   </tr>
#
#                                 </table>
# 				            </section><!--result_table-->
#
#
#
#             <div class="res_top"></div>
#             <div class="res_down"></div>
#              <nav class="res_next_prev">
#             	<a class="res_next_btn res_next_btn_tw" href="?ID=" onclick="RestTrainSubmit('08:50', '2');return false;" OnKeypress="this.onclick();return false;" title  = "較晚班次">較晚班次</a>
#
#              </nav>
#          </ul>
#
# </section><!--time_check_result-->
#
# <h3 class="kind_ticket kind_ticket_tw">車廂票價參考</h3>
# <section class="kind_ticket_list kind_ticket_list_tw">
#         <table class="word_size" style="table-layout:fixed">
#
# <tr><th class='c1' scope='col'>&nbsp;</th><th scope='row'>全票</th><th scope='row' style='width: 130px; white-space: nowrap;'>孩童票  敬老票愛心票價</th><th scope='row'>團體票</th><th scope='col'>9折</th><th scope='col'>8折</th><th scope='col'>65折</th></tr><tr><th class='c2' scope='col'>標準車廂</th><td>$1530</td><td>$765</td><td>$1450</td><td>$1375</td><td>$1220</td><td>$990</td></tr><tr><th class='c3' scope='col'>商務車廂</th><td>$2000</td><td>$1250</td><td>$1900</td><td>-</td><td>-</td><td>-</td></tr><tr><th class='c4' scope='col'>自由座車廂</th><td>$1480</td><td>$740</td><td>-</td><td>-</td><td>-</td><td>-</td></tr>
#         </table>
#
#     </section>
#
# <article class="search_word commonWord">
#     <h4 class="word_size" title = "公告事項說明">公告事項說明</h4>
#     <ul class="word_size">
#             <li title = "南港─台北、南港─板橋、台北─板橋區間恕不發售商務車廂車票及團體票。">南港─台北、南港─板橋、台北─板橋區間恕不發售商務車廂車票及團體票。</li>
#             <li title = "欲得知列車停靠站詳細說明，請點選上方之車次連結。">欲得知列車停靠站詳細說明，請點選上方之車次連結。</li>
#             <li title = "本系統僅提供時刻表及票價查詢功能，如欲直接訂位，請使用台灣高鐵網路訂位系統進行線上訂位及付款。">本系統僅提供時刻表及票價查詢功能，如欲直接訂位，請使用台灣高鐵網路訂位系統進行線上訂位及付款。</li>
#             <li title = "本時刻表所列各次列車為開車時刻，唯於終點站為到達時刻。">本時刻表所列各次列車為開車時刻，唯於終點站為到達時刻。</li>
#     </ul>
# </article>
# <article class="search_word2 commonWord">
#     <h4 class="word_size" title = "票價優惠說明">票價優惠說明</h4>
#     <ul class="word_size">
#         <li title = "早鳥優惠車票，自乘車日(含)前28日起開始限量發售，最晚發售至乘車日(含)前 5 日截止。">早鳥優惠車票，自乘車日(含)前28日起開始限量發售，最晚發售至乘車日(含)前 5 日截止。</li>
#         <li title = "本查詢顯示之早鳥適用優惠為該車次最低早鳥折扣。愈早訂位者，愈有機會訂得早鳥 65 折優惠車票。早鳥 65 折銷售完畢即改發售早鳥 8 折，早鳥 8 折銷售完畢即改發售早鳥 9 折，早鳥 9 折銷售完畢即提前截止並改發售原價車票。">本查詢顯示之早鳥適用優惠為該車次最低早鳥折扣。愈早訂位者，愈有機會訂得早鳥 65 折優惠車票。早鳥 65 折銷售完畢即改發售早鳥 8 折，早鳥 8 折銷售完畢即改發售早鳥 9 折，早鳥 9 折銷售完畢即提前截止並改發售原價車票。</li>
#         <li title = "以上票價為折扣後之價格。">以上票價為折扣後之價格。</li>
#         <li title = "以上列車時刻及票價僅供參考，資訊若有更動，以各車站現場公布為準。">以上列車時刻及票價僅供參考，資訊若有更動，以各車站現場公布為準。</li>
#     </ul>
# </article>
#     <article class="siteMapTop"></article>
# </section>
# <div style="height:20px;" class="footer_list_btn"></div>
#
#
#         </div>
#
# <!--WebsiteFooter_Start-->
# <footer>
#     <!--文章分享區塊-->
#
#     <!--文章分享區塊 end-->
#     <div class="just_line"></div>
#     <div style="height:10px;"></div>
# <div class="footer_top">
#         	  <article class="phone_area">
#
#                 <strong class="footerH2Title" title = "客服專線 : 4066-3000 ">客服專線 : 4066-3000 </strong>
#         	    <ol>
#         	      <li class="phone_01" title = "苗栗：4266-3000">苗栗：4266-3000 </li>
#         	      <li class="phone_02" title = "台東、金門：4666-3000">台東、金門：4666-3000 </li>
#         	      <li class="phone_03" title = "馬祖及行動電話：02-4066-3000">馬祖及行動電話：02-4066-3000 </li>
#                     <li class="phone_04" title = "服務時間：06:00~24:00">服務時間：06:00~24:00 </li>
#        	        </ol>
#        	      </article><!--phone_area-->
#        	    <article class="reserve_area">
#
#                 <strong class="footerH2Title" title = "語音訂位 : 4066-0000 ">語音訂位 : 4066-0000 </strong>
#         	    <ol>
#         	      <li class="phone_01" title = "苗栗：4266-0000">苗栗：4266-0000 </li>
#         	      <li class="phone_02" title = "台東、金門：4666-0000">台東、金門：4666-0000 </li>
#         	      <li class="phone_03" title = "馬祖及行動電話：02-4066-0000">馬祖及行動電話：02-4066-0000 </li>
#                   <li class="phone_04" title = "服務時間：00:00~24:00">服務時間：00:00~24:00 </li>
#        	      </ol>
#        	      </article><!--reserve_area-->
#        	    <article class="service_area">
#         	    <ul>
#                     <li class="service_area_line" title = "常見問題"><a href="/tw/FAQ" title="常見問題">常見問題</a></li>
#                     <li class="service_area_line5" title = "遺失物查詢"><a href="/tw/LostAndFound" title="遺失物查詢">遺失物查詢</a></li>
#                     <li class="service_area_line" title = "招標資訊"><a href="/tw/Tendering" title="招標資訊">招標資訊</a></li>
#                     <li class="service_area_line" title = "獲獎事蹟"><a href="/tw/Article/ArticleContent/63d60a32-0600-4cd7-ac37-6ad8316b7f1e" title="獲獎事蹟">獲獎事蹟</a></li>
#         	        <li title = "企業社會責任"><a href="http://www2.thsrc.com.tw/Content/UploadFiles/CorporateResponsibility.pdf" target="_blank" title = "企業社會責任[將另開新視窗 ]">企業社會責任<span style="display:none;">[將另開新視窗 ]</span></a></li>
#
#        	      </ul>
#        	      <ul>
#                   <li><a href="/tw/Article/ArticleContent/d1fa3bcb-a016-47e2-88c6-7b7cbed00ed5" title = "個人資料保護政策及顧客個人資料保護權益事項">個人資料保護政策及顧客個人資料保護權益事項</a></li>
#        	        </ul>
#        	      <ul>
#                   <li class="service_area_line3"><a href="/tw/Article/ArticleContent/b9dcb8ea-02ab-4726-b71d-335904dbd86b" title = "智慧財產權及免責條款宣告">智慧財產權及免責條款宣告</a></li>
#         	      <li class="service_area_line4"><a href="/tw/Article/ArticleContent/291d80fe-080f-4442-90d0-9a9b82f119e5" title = "交易注意事項">交易注意事項</a></li>
#         	      <li title = "聯絡我們"><a href="https://www.thsrc.com.tw/tw/ContactUs" title="聯絡我們">聯絡我們</a></li>
#        	      </ul>
#
#        	      </article><!--service_area-->
#       	  </div><!--footer_top-->
#
#
#
#           <div class="footerH5">
# 	        <span>以上皆為付費電話，依一般市話及行動電話費率標準計費。</span></div>
#
#            <article style="width:488px;float:left">
#
#
#
#                <div class="footerH6">
#                <div><span>台灣高速鐵路股份有限公司 版權所有 </span>© Taiwan High Speed Rail Corporation. All Rights Reserved.</div>
#                </div>
#           </article>
#
#           <article style="width: 149px;float: right;margin-top: 6px;margin-right: 10px;">
#              <img src="/Content/images/bethere_THSRC.png" alt="真實接觸 be there" title="真實接觸 be there">
#           </article>
#       </footer>
#       <!--WebsiteFooter_End-->
#     </div>
#
# 	<script type="text/javascript" src="/Content/Script/time_search.js"></script>
#
#
#
# <script type="text/javascript">
#
#     var _gaq = _gaq || [];
#     var pStr = location.pathname;
#     if ( pStr.indexOf("/en/") != -1 )
#     {
#         _gaq.push(['_setAccount', 'UA-9967381-19']);
#     }
#     else if (pStr.indexOf("/jp/") != -1)
#     {
#         _gaq.push(['_setAccount', 'UA-9967381-20']);
#     }
#     else
#         _gaq.push(['_setAccount', 'UA-9967381-1']);
#
#     //_gaq.push(['_setAccount', 'UA-9967381-1']);
#     _gaq.push(['_trackPageview']);
#
#     (function () {
#         var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#         ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#         var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#     })();
#
# </script>
# </body>
# </html>

# %% [markdown]
# ## BS4

# %%
# !pip3 install lxml
# Out:
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/site-packages

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(res.text, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="zh-tw">
# <head><meta charset="utf-8"/>
# <link href="/Content/favicon/favicon.ico" rel="shortcut icon"/>
# <link href="/Content/favicon/57_57.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="/Content/favicon/72_72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="/Content/favicon/76_76.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="/Content/favicon/114_114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="/Content/favicon/120_120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="/Content/favicon/144_144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="/Content/favicon/152_152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <!--<meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=no, minimum-scale=1.0, maximum-scale=1.0" />-->
# <meta content="高鐵,快速,旅遊假期,遊玩" name="keywords"/>
# <meta content="台灣高鐵連結台灣南北主要城市，我們不只是交通運輸業，更是推動台灣­前進的服務業；我們代表的不僅只是速度，而是速度所帶來的現代生活新態度；我們以更文明的旅行體驗，成為你實現夢想的助力，台灣高鐵，實踐台灣新生活。" name="description"/>
# <meta content="mi70 uni-net" name="author"/>
# <meta content="private" http-equiv="cache-control"/>
# <!--Facebook SEO start-->
# <meta content="台灣高鐵" property="og:title"/>
# <meta content="http://www.thsrc.com.tw/" property="og:url"/>
# <meta content="http://www.thsrc.com.tw/Content/logo.jpg" property="og:image"/>
# <!--Facebook SEO end-->
# <!--Google +1 start-->
# <meta content="台灣高鐵" itemprop="name"/>
# <meta content="台灣高鐵連結台灣南北主要城市，我們不只是交通運輸業，更是推動台灣­前進的服務業；我們代表的不僅只是速度，而是速度所帶來的現代生活新態度；我們以更文明的旅行體驗，成為你實現夢想的助力，台灣高鐵，實踐台灣新生活。" itemprop="description"/>
# <meta content="http://www.thsrc.com.tw/Content/logo.jpg" itemprop="image"/>
# <!--Google +1 end-->
# <!--[if lt IE 9]>
# <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
# <script src="/Content/dist/html5shiv.js" type="text/javaScript"></script>
# <script src="/Content/dist/html5shiv-printshiv.js" type="text/javaScript"></script>
# <![endif]-->
# <!--[if IE 7]>
# <script src="//ie7-js.googlecode.com/svn/version/2.1(beta4)/IE9.js"></script>
# <![endif]-->
# <!--[if IE 8]>
# <script src="//ie7-js.googlecode.com/svn/version/2.1(beta4)/IE9.js"></script>
# <![endif]-->
# <!--[if IE 6]>
# <link href="/Content/css/pngFix.css"  rel="stylesheet" type="text/css" />
# <script src="/Content/iepngfix/iepngfix_tilebg.js" type="text/javaScript"></script>
# <![endif]-->
# <!-- Original CSS for the template -->
# <link href="/Content/css/css_reset.css" rel="stylesheet" type="text/css"/>
# <!-------------------->
# <!-- CSS for jQuery -->
# <!-------------------->
# <link href="/Content/css/jquery-ui-1.8.5.custom.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/css/jquery.ui.datepicker.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/Script/fancybox/jquery.fancybox-1.3.1.css" media="screen" rel="stylesheet" type="text/css"/>
# <script src="/Content/Script/jquery-1.8.3.min.js" type="text/javascript"></script>
# <script src="/Content/Script/jquery-ui-1.8.5.custom.min.js" type="text/javaScript"></script>
# <script src="/Content/Script/ui.datepicker-zh-TW.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.ui.datepicker.js" type="text/javaScript"></script>
# <script src="/Content/Script/fancybox/jquery.mousewheel-3.0.2.pack.js" type="text/javaScript"></script>
# <script src="/Content/Script/fancybox/jquery.fancybox-1.3.1.js" type="text/javaScript"></script>
# <script src="/Content/Script/dateTool.js" type="text/javaScript"></script>
# <script src="/Content/Script/THSRC.Common.js" type="text/javaScript"></script>
# <script language="JavaScript" type="text/javascript">
#     if (top.location != self.location) {
#         location.href = "http://" + self.location.host + "/APPool/notice.html";
#     }
#     </script>
# <!-------------------->
# <!------ jQuery ------>
# <!-------------------->
# <script src="/Content/Script/jquery.validate.min.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.validate.extension.js" type="text/javaScript"></script>
# <script src="/Content/Script/date.js" type="text/javaScript"></script>
# <script src="/Content/Script/json2.js" type="text/javaScript"></script>
# <script src="/Content/Script/JSON4ms.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.tmpl.min.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.tmplPlus.min.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.cookie.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.keyfilter.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.easing.1.3.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.ui.core.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.ui.mouse.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.scrollTo-min.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.jqprint-0.3.js" type="text/javaScript"></script>
# <!------------------------------>
# <!-- Uninet Customize Library -->
# <!------------------------------>
# <script src="/Content/Script/check.js" type="text/javaScript"></script>
# <script src="/Content/Script/behaviour.js" type="text/javaScript"></script>
# <script src="/Content/Script/THSRC.Extends.js" type="text/javaScript"></script>
# <script src="/Content/Script/THSRC.Property.js" type="text/javaScript"></script>
# <script src="/Content/Script/THSRC.AjaxCheckBox.js" type="text/javaScript"></script>
# <script src="/Content/Script/THSRC.AjaxDropDownList.js" type="text/javaScript"></script>
# <script src="/Content/Script/FancyBox.js" type="text/javascript"></script>
# <script src="/Content/Script/nextPrevBtn.js" type="text/javascript"></script>
# <script src="/Content/Script/photoCenter.js" type="text/javascript"></script>
# <script src="/Content/Script/SocialMedia.ShareButton.js" type="text/javascript"></script>
# <title>
#
#         台灣高鐵 Taiwan High Speed Rail - 時刻表與票價查詢
#
# </title>
# <link href="/Content/css/innerCommon.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/css/inner_all_common.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/css/time_search.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/css/m_newStationLine.css" rel="stylesheet" type="text/css"/>
# </head><body>
# <div class="wrapper">
# <header>
# <h1><a href="/" tabindex="1" title="TAIWAN HIGH SPEED RAIL">台灣高鐵</a></h1>
# <aside class="top_aside">
# <ul>
# <li class="aaBtn"><a accesskey="U" class="guildePoint" href="#" title="上方選單區"><span style="color: white; margin: 0 8px 0 -8px;">:::</span></a><a href="/tw/SiteMap" title="網站導覽">網站導覽</a></li>
# <li class="addLine"><a href="/tw/Home/Index" title="繁體中文">
#         繁體中文
#     </a>
# </li>
# <li class="addLine">
# <a href="/jp/" title="日本語">
#         日本語</a>
# </li>
# <li class="addLine">
# <a href="/en/" title="English">
#         English</a>
# </li>
# </ul>
# <form action="/tw/Home/Search" id="formWholeSiteSearch" method="post" name="formWholeSiteSearch">
# <label for="searchBar"><span style="display:none;">全站查詢</span></label>
# <input id="searchBar" name="searchBar" placeholder="請輸入查詢關鍵字" title="請輸入查詢關鍵字" type="text" value=""/>
# <input id="searchBarSend" onclick="SubmitSearch();return false;" onkeypress="SubmitSearch();return false;" type="submit"/>
# </form>
# <script type="text/javascript">
#     function SubmitSearch() {
#         var keyword = $("#searchBar").val();
#         if (keyword != "") {
#             $("#formWholeSiteSearch").submit();
#         } else {
#             alert("請輸入搜尋內容");
#         }
#     }
# </script>
# <noscript>
# 請輸入搜尋內容
# </noscript>
# <a href="https://www.facebook.com/thsrco" style="position:absolute; right:0px; top:34px;" target="_blank" title="連結粉絲專區[將另開新視窗]">
# <img alt="粉絲專頁" border="0" src="/Content/images_cn/common/fb_thsrco.jpg"/></a>
# </aside>
# <script src="/Content/Script/forListMenu.js" type="text/javascript"></script>
# <script src="/Content/Script/jquery.bgiframe.js" type="text/javascript"></script>
# <link href="/Content/css/common_list_menu.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/css/common_list_menu_en_jp.css" rel="stylesheet" type="text/css"/>
# <nav class="top_nav top_nav_tw">
# <ul>
# <li class="nav_hot"><a href="/tw/SiteMap/#N" title="優惠活動">優惠活動</a>
# <div class="dl height_304">
# <div class="first_list">
# <div class="has_photo_list"><img alt="優惠活動" height="120" src="/event/index_img/nav_hot.jpg" title="優惠活動" width="200"/></div>
# <div class="photo_list_word" title="密集方便，高鐵提供您準點可靠的列車服務。">密集方便，高鐵提供您準點可靠的列車服務。</div>
# </div>
# <div class="list_area list_area_tw">
# <div class="dtnolink" title="購票優惠">購票優惠</div>
# <div class="dd">
# <a alt="早鳥優惠" href="/tw/Article/ArticleContent/7039d17d-1463-4c14-ad93-4d491dedcad5" title="早鳥優惠">
# 							早鳥優惠
# 							</a>
# </div>
# <div class="dd">
# <a alt="信用卡優惠專區" href="/tw/Article/ArticleContent/566d6bff-4427-461d-8b88-b6c4868f75c9" title="信用卡優惠專區">
# 							信用卡優惠專區
# 							</a>
# </div>
# <div class="dd">
# <a alt="學生暑期優惠" href="/tw/Article/ArticleContent/0061e6f3-93ca-4161-9020-6f02ce4cce94" title="學生暑期優惠">
# 							學生暑期優惠
# 							</a>
# </div>
# <div class="dd">
# <a alt="大學生優惠" href="/tw/Article/ArticleContent/530e869c-479d-441a-a4b4-61a8166827e9" title="大學生優惠">
# 							大學生優惠
# 							</a>
# </div>
# <div class="dd">
# <a alt="平日離峰96折" href="/tw/Article/ArticleContent/e75eb64d-0cbf-42de-a7fb-dc43116be985" title="平日離峰96折">
# 							平日離峰96折
# 							</a>
# </div>
# <div class="dd">
# <a alt="25人以上團體優惠" href="/tw/Article/ArticleContent/89a14510-7982-4b5e-88af-074305bfefed" title="25人以上團體優惠">
# 							25人以上團體優惠
# 							</a>
# </div>
# <div class="dd">
# <a alt="校外教學優惠" href="/tw/Article/ArticleContent/ca09cf02-8f65-4f87-b25e-31cb9c0e187b" title="校外教學優惠">
# 							校外教學優惠
# 							</a>
# </div>
# <div class="dd">
# <a alt="團體訂票" href="/tw/Article/ArticleContent/41421730-b8ab-4fe3-b251-89e32cba8453" title="團體訂票">
# 							團體訂票
# 							</a>
# </div>
# <div class="dd">
# <a alt="回數票優惠" href="/tw/Article/ArticleContent/8f06ca76-ab2d-4b77-bc20-73218ce3b892" title="回數票優惠">
# 							回數票優惠
# 							</a>
# </div>
# </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# <div class="dd">
# <a alt="定期票優惠" href="/tw/Article/ArticleContent/b7b46e29-424c-4fc4-8ec7-0ab3031f2c9c" title="定期票優惠">
# 							定期票優惠
# 							</a>
# </div>
# <div class="dd">
# <a alt="企業會員" href="/tw/Article/ArticleContent/376238fd-2f6d-48f8-b070-9f2ea61b14b5" title="企業會員">
# 							企業會員
# 							</a>
# </div>
# <div class="dd">
# <a alt="活動套票" href="/tw/Article/ArticleContent/d794b386-96a7-445c-8a50-160862a037e9" title="活動套票">
# 							活動套票
# 							</a>
# </div>
# <div class="dd">
# <a alt="高鐵假期[將另開新視窗 ]" href="https://tholiday.thsrc.com.tw/" target="_blank" title="高鐵假期[將另開新視窗 ]">
# 							高鐵假期<span style="display:none;">[將另開新視窗 ]</span>
# </a>
# </div>
# <div class="dd">
# <a alt="飯店聯票" href="/tw/Article/ArticleContent/c2bae549-bc17-4373-a43a-3496780aa4ea" title="飯店聯票">
# 							飯店聯票
# 							</a>
# </div>
# <div class="dd">
# <a alt="交通聯票" href="/tw/Article/ArticleContent/5af4ceb8-4c6f-44ec-b02d-0c398c0ad917" title="交通聯票">
# 							交通聯票<em></em>
# </a>
# </div>
# <div class="dtnolink" title="最新公告">最新公告</div>
# <div class="dd">
# <a alt="最新消息" href="/tw/News/Index" title="最新消息">
# 							最新消息
# 							</a>
# </div>
# <div class="dd">
# <a alt="列車運行狀況" href="/tw/Operation/Index" title="列車運行狀況">
# 							列車運行狀況<em></em>
# </a>
# </div>
# <div class="dtnolink" title="熱門活動">熱門活動</div>
# </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# <div class="dd">
# <a alt="高鐵營隊(2017暑假)" href="/tw/TCamp" title="高鐵營隊(2017暑假)">
# 							高鐵營隊(2017暑假)
# 							</a>
# </div>
# <div class="dd">
# <a alt="活動合作" href="/tw/Article/ArticleContent/99ba7783-c46e-4b68-849b-e9084e5a0e15" title="活動合作">
# 							活動合作
# 							</a>
# </div>
# <div class="dd">
# <a alt="魔幻劇場親子列車" href="/tw/Article/ArticleContent/7e969844-65df-46a6-9b78-b00f37d12ab8" title="魔幻劇場親子列車">
# 							魔幻劇場親子列車
# 							</a>
# </div>
# <div class="dd">
# <a alt="「藝」起來高鐵" href="/tw/Article/ArticleContent/d9eee6e4-3bc9-4c1b-8e5c-f471fd0b7539" title="「藝」起來高鐵">
# 							「藝」起來高鐵
# 							</a>
# </div>
# <div class="dd">
# <a alt="真十感謝 美好未來[將另開新視窗 ]" href="http://www.thsrc.com.tw/event/2017/10thAnniversary" target="_blank" title="真十感謝 美好未來[將另開新視窗 ]">
# 							真十感謝 美好未來<span style="display:none;">[將另開新視窗 ]</span>
# </a>
# </div>
# <div class="dd">
# <a alt="高鐵探索館 暑期講座" href="/tw/Article/ArticleContent/5cd921ee-e319-47a4-8677-dd5f352c2ad9" title="高鐵探索館 暑期講座">
# 							高鐵探索館 暑期講座<em></em>
# </a>
# </div>
# </div>
# <div class="list_line"></div>
# </div>
# </li>
# <li class="nav_ticket"><a href="/tw/SiteMap/#T" title="購票資訊">購票資訊</a>
# <div class="dl height_304">
# <div class="first_list">
# <div class="has_photo_list"><img alt="購票資訊" height="120" src="/event/index_img/nav_ticket.jpg" title="購票資訊" width="200"/></div>
# <div class="photo_list_word" title="最新的購票優惠及列車資訊，快速掌握高鐵動態。">最新的購票優惠及列車資訊，快速掌握高鐵動態。</div>
# </div>
# <div class="list_area list_area_tw">
# <div class="dtnolink" title="票種說明">票種說明</div>
# <div class="dd">
# <a alt="票價產品一覽表" href="/tw/Article/ArticleContent/caa6fac8-b875-4ad6-b1e6-96c2902d12a6" title="票價產品一覽表">
# 							票價產品一覽表<em></em>
# </a>
# </div>
# <div class="dtnolink" title="如何購票">如何購票</div>
# <div class="dd">
# <a alt="網路訂票" href="/tw/Article/ArticleContent/dea241a9-fe69-4e9d-b9a5-6caed6e486d6" title="網路訂票">
# 							網路訂票
# 							</a>
# </div>
# <div class="dd">
# <a alt="「T-EX行動購票」App" href="/tw/Article/ArticleContent/4d262503-84bc-4963-a58e-4ca1a6453ad3" title="「T-EX行動購票」App">
# 							「T-EX行動購票」App
# 							</a>
# </div>
# <div class="dd">
# <a alt="便利商店購票" href="/tw/Article/ArticleContent/baba745a-d802-440c-b762-3eef37b96b60" title="便利商店購票">
# 							便利商店購票
# 							</a>
# </div>
# <div class="dd">
# <a alt="自動語音訂位服務" href="/tw/Article/ArticleContent/7a96ad53-6efa-4c58-bb17-70c9f649b4e3" title="自動語音訂位服務">
# 							自動語音訂位服務
# 							</a>
# </div>
# <div class="dd">
# <a alt="自動售票機購票" href="/tw/Article/ArticleContent/6be4173c-91dc-4d06-ae3e-a19de420a237" title="自動售票機購票">
# 							自動售票機購票
# 							</a>
# </div>
# <div class="dd">
# <a alt="團體訂票" href="/tw/Article/ArticleContent/41421730-b8ab-4fe3-b251-89e32cba8453" title="團體訂票">
# 							團體訂票
# 							</a>
# </div>
# <div class="dd">
# <a alt="車站窗口購票" href="/tw/Article/ArticleContent/43d5e5e2-3777-46b9-bc8f-8b5b579b50ed" title="車站窗口購票">
# 							車站窗口購票
# 							</a>
# </div>
# </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# <div class="dd">
# <a alt="悠遊聯名卡" href="/tw/Article/ArticleContent/27bf64ed-5a99-4c0f-9021-dbe609998cdb" title="悠遊聯名卡">
# 							悠遊聯名卡
# 							</a>
# </div>
# <div class="dd">
# <a alt="一卡通聯名卡" href="/tw/Article/ArticleContent/ef3cff71-345c-4768-8d79-fdb75c956bbe" title="一卡通聯名卡">
# 							一卡通聯名卡
# 							</a>
# </div>
# <div class="dd">
# <a alt="無障礙服務" href="/tw/Article/ArticleContent/dba4ecd0-5ef0-45d2-aa64-bcecdf7d5fde" title="無障礙服務">
# 							無障礙服務<em></em>
# </a>
# </div>
# <div class="dtnolink" title="快速查詢">快速查詢</div>
# <div class="dd">
# <a alt="2017年疏運日程表" href="/tw/News/Detail/24fb760a-d9d8-4a05-9cd2-32f872dd3f8c/13" title="2017年疏運日程表">
# 							2017年疏運日程表
# 							</a>
# </div>
# <div class="dd">
# <a alt="時刻表與票價查詢" href="/tw/TimeTable/SearchResult" title="時刻表與票價查詢">
# 							時刻表與票價查詢<em></em>
# </a>
# </div>
# <div class="dtnolink" title="電子票證搭乘紀錄查詢">電子票證搭乘紀錄查詢</div>
# <div class="dd">
# <a alt="T Express 搭乘紀錄[將另開新視窗 ]" href="http://ptis.thsrc.com.tw/ptis/web_proof/texp_index.jsp" target="_blank" title="T Express 搭乘紀錄[將另開新視窗 ]">
# 							T Express 搭乘紀錄<span style="display:none;">[將另開新視窗 ]</span>
# </a>
# </div>
# <div class="dd">
# <a alt="回數 / 定期票搭乘紀錄[將另開新視窗 ]" href="http://ptis.thsrc.com.tw/ptis/web_proof/csc_travel.jsp" target="_blank" title="回數 / 定期票搭乘紀錄[將另開新視窗 ]">
# 							回數 / 定期票搭乘紀錄<span style="display:none;">[將另開新視窗 ]</span>
# </a>
# </div>
# <div class="dd">
# <a alt="悠遊聯名卡搭乘紀錄[將另開新視窗 ]" href="https://queryweb.tscc.com.tw/thsrc_web/" target="_blank" title="悠遊聯名卡搭乘紀錄[將另開新視窗 ]">
# 							悠遊聯名卡搭乘紀錄<span style="display:none;">[將另開新視窗 ]</span>
# </a>
# </div>
# </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# <div class="dd">
# <a alt="一卡通聯名卡搭乘紀錄[將另開新視窗 ]" href="https://www.i-pass.com.tw/ips/THSRC/" target="_blank" title="一卡通聯名卡搭乘紀錄[將另開新視窗 ]">
# 							一卡通聯名卡搭乘紀錄<span style="display:none;">[將另開新視窗 ]</span><span style="display:none;">[將另開新視窗 ]</span><em></em>
# </a>
# </div>
# <div class="dtnolink" title="企業會員">企業會員</div>
# <div class="dd">
# <a alt="加入企業會員" href="/tw/Article/ArticleContent/376238fd-2f6d-48f8-b070-9f2ea61b14b5" title="加入企業會員">
# 							加入企業會員<em></em>
# </a>
# </div>
# <div class="dtnolink" title="相關法規">相關法規</div>
# <div class="dd">
# <a alt="相關法規" href="/tw/Article/ArticleContent/7de57796-db08-4d94-b183-bd62618859db" title="相關法規">
# 							相關法規<em></em>
# </a>
# </div>
# </div>
# <div class="list_line"></div>
# </div>
# </li>
# <li class="nav_info"><a href="/tw/SiteMap/#C" title="乘車指南">乘車指南</a>
# <div class="dl height_304">
# <div class="first_list">
# <div class="has_photo_list"><img alt="乘車指南" height="120" src="/event/index_img/nav_info.jpg" title="乘車指南" width="200"/></div>
# <div class="photo_list_word" title="舒適的環境及便捷的交通轉乘，高鐵與您共創美好旅程。">舒適的環境及便捷的交通轉乘，高鐵與您共創美好旅程。</div>
# </div>
# <div class="list_area list_area_tw">
# <div class="dtnolink" title="車站資訊">車站資訊</div>
# <div class="dd">
# <a alt="南港站" href="/tw/StationInfo/Prospect/2F940836-CEDC-41EF-8E28-C2336AC8FE68" title="南港站">
# 							南港站
# 							</a>
# </div>
# <div class="dd">
# <a alt="台北站" href="http://www.thsrc.com.tw/tw/StationInfo/prospect/977abb69-413a-4ccf-a109-0272c24fd490" title="台北站">
# 							台北站
# 							</a>
# </div>
# <div class="dd">
# <a alt="板橋站" href="/tw/StationInfo/Prospect/e6e26e66-7dc1-458f-b2f3-71ce65fdc95f" title="板橋站">
# 							板橋站
# 							</a>
# </div>
# <div class="dd">
# <a alt="桃園站" href="/tw/StationInfo/Prospect/fbd828d8-b1da-4b06-a3bd-680cdca4d2cd" title="桃園站">
# 							桃園站
# 							</a>
# </div>
# <div class="dd">
# <a alt="新竹站" href="/tw/StationInfo/Prospect/a7a04c89-900b-4798-95a3-c01c455622f4" title="新竹站">
# 							新竹站
# 							</a>
# </div>
# <div class="dd">
# <a alt="苗栗站" href="/tw/StationInfo/Prospect/E8FC2123-2AAF-46FF-AD79-51D4002A1EF3" title="苗栗站">
# 							苗栗站
# 							</a>
# </div>
# <div class="dd">
# <a alt="台中站" href="/tw/StationInfo/Prospect/3301e395-46b8-47aa-aa37-139e15708779" title="台中站">
# 							台中站
# 							</a>
# </div>
# <div class="dd">
# <a alt="彰化站" href="/tw/StationInfo/Prospect/38B8C40B-AEF0-4D66-B257-DA96EC51620E" title="彰化站">
# 							彰化站
# 							</a>
# </div>
# <div class="dd">
# <a alt="雲林站" href="/tw/StationInfo/Prospect/5F4C7BB0-C676-4E39-8D3C-F12FC188EE5F" title="雲林站">
# 							雲林站
# 							</a>
# </div>
# </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# <div class="dd">
# <a alt="嘉義站" href="/tw/StationInfo/Prospect/60831846-f0e4-47f6-9b5b-46323ebdcef7" title="嘉義站">
# 							嘉義站
# 							</a>
# </div>
# <div class="dd">
# <a alt="台南站" href="/tw/StationInfo/Prospect/9c5ac6ca-ec89-48f8-aab0-41b738cb1814" title="台南站">
# 							台南站
# 							</a>
# </div>
# <div class="dd">
# <a alt="左營站" href="/tw/StationInfo/Prospect/f2519629-5973-4d08-913b-479cce78a356" title="左營站">
# 							左營站<em></em>
# </a>
# </div>
# <div class="dtnolink" title="轉乘服務">轉乘服務</div>
# <div class="dd">
# <a alt="轉乘服務總覽" href="/tw/Article/ArticleContent/c2a8fd9d-ced6-43b1-9297-9eab4127b5ff" title="轉乘服務總覽">
# 							轉乘服務總覽<em></em>
# </a>
# </div>
# <div class="dtnolink" title="服務與設施">服務與設施</div>
# <div class="dd">
# <a alt="服務與設施總覽" href="/tw/Article/ArticleContent/9915abee-dc70-4ba3-9f6d-c425873c3475" title="服務與設施總覽">
# 							服務與設施總覽
# 							</a>
# </div>
# <div class="dd">
# <a alt="無障礙服務" href="http://www.thsrc.com.tw/tw/Article/ArticleContent/dba4ecd0-5ef0-45d2-aa64-bcecdf7d5fde" title="無障礙服務">
# 							無障礙服務
# 							</a>
# </div>
# <div class="dd">
# <a alt="車廂介紹" href="/tw/StationInfo/Accommondation" title="車廂介紹">
# 							車廂介紹
# 							</a>
# </div>
# <div class="dd">
# <a alt="車廂服務介紹" href="/tw/Article/ArticleContent/feb91116-8a73-46b7-a6b7-f115a3137ccf" title="車廂服務介紹">
# 							車廂服務介紹
# 							</a>
# </div>
# </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# <div class="dd">
# <a alt="T Life 車上刊物" href="/tw/Article/ArticleContent/2cc958af-c283-4efa-b6e6-22bb84ac5bab" title="T Life 車上刊物">
# 							T Life 車上刊物
# 							</a>
# </div>
# <div class="dd">
# <a alt="多功能會議室" href="/tw/Article/ArticleContent/347fa4fb-479d-4a90-b5aa-e0ba9b22ed41" title="多功能會議室">
# 							多功能會議室<em></em>
# </a>
# </div>
# <div class="dtnolink" title="乘車安全">乘車安全</div>
# <div class="dd">
# <a alt="列車安全" href="/tw/Article/ArticleContent/33741541-0f76-4397-a3f7-44367240a344" title="列車安全">
# 							列車安全
# 							</a>
# </div>
# <div class="dd">
# <a alt="車站安全" href="/tw/Article/ArticleContent/b47a688b-2115-4719-88bf-3b8b740d73e1" title="車站安全">
# 							車站安全
# 							</a>
# </div>
# <div class="dd">
# <a alt="鐵路安全" href="/tw/Article/ArticleContent/9780e036-5fdb-4c48-8732-1242beafafbd" title="鐵路安全">
# 							鐵路安全<em></em>
# </a>
# </div>
# <div class="dtnolink" title="享樂購物趣">享樂購物趣</div>
# <div class="dd">
# <a alt="列車販售" href="/tw/TShop/TrainShopping" title="列車販售">
# 							列車販售
# 							</a>
# </div>
# <div class="dd">
# <a alt="紀念商品" href="/tw/Souvenir" title="紀念商品">
# 							紀念商品
# 							</a>
# </div>
# <div class="dd">
# <a alt="車站販售" href="http://www.thsrc.com.tw/tw/TShop/FoodCourt/977abb69-413a-4ccf-a109-0272c24fd490" title="車站販售">
# 							車站販售<em></em>
# </a>
# </div>
# </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# <div class="dtnolink" title="注意事項">注意事項</div>
# <div class="dd">
# <a alt="乘車須知" href="/tw/Article/ArticleContent/2f73bfbb-d9bb-400e-b806-f6c5ba539368" title="乘車須知">
# 							乘車須知
# 							</a>
# </div>
# <div class="dd">
# <a alt="驗票閘門及通關" href="/tw/Article/ArticleContent/4f77e9e6-f337-4af4-8f60-fbd6054e608f" title="驗票閘門及通關">
# 							驗票閘門及通關<em></em>
# </a>
# </div>
# <div class="dtnolink" title="高鐵百科">高鐵百科</div>
# <div class="dd">
# <a alt="地震防護與應變[將另開新視窗 ]" href="http://www.thsrc.com.tw/event/Encyclopedia/Earthquake/index.html" target="_blank" title="地震防護與應變[將另開新視窗 ]">
# 							地震防護與應變<span style="display:none;">[將另開新視窗 ]</span><span style="display:none;">[將另開新視窗 ]</span><em></em>
# </a>
# </div>
# </div>
# </div>
# </li>
# <li class="nav_about"><a href="/tw/Article/ArticleContent/841afa46-f7d7-4747-889c-b03469fdb455" title="關於高鐵">關於高鐵</a>
# <div class="dl height_304">
# <div class="first_list">
# <div class="has_photo_list"><img alt="關於高鐵" height="120" src="/event/index_img/nav_about.jpg" title="關於高鐵" width="200"/></div>
# <div class="photo_list_word" title="旅遊購物輕鬆滿足，高鐵生活好便利！">旅遊購物輕鬆滿足，高鐵生活好便利！</div>
# </div>
# <div class="list_area list_area_tw">
# <div class="dt">
# <a alt="獲獎事蹟" href="/tw/Article/ArticleContent/63d60a32-0600-4cd7-ac37-6ad8316b7f1e" title="獲獎事蹟">
# 							獲獎事蹟<em></em>
# </a>
# </div>
# <div class="dtnolink" title="企業資訊">企業資訊</div>
# <div class="dd">
# <a alt="企業社會責任" href="/tw/Article/ArticleContent/8d291a1a-90ba-4b0f-b4d5-db2a35d881f5" title="企業社會責任">
# 							企業社會責任
# 							</a>
# </div>
# <div class="dd">
# <a alt="大事紀要" href="/tw/Article/ArticleContent/b792e45d-5416-469b-82fd-ed383bef4691" title="大事紀要">
# 							大事紀要
# 							</a>
# </div>
# <div class="dd">
# <a alt="企業識別" href="/tw/Article/ArticleContent/605d1cb2-2d98-4d73-9586-7e8363ee44e3" title="企業識別">
# 							企業識別
# 							</a>
# </div>
# <div class="dd">
# <a alt="環保工安與研發支出資訊" href="/tw/Article/ArticleContent/34d8a763-9a98-4478-919c-6b88d07fecaa" title="環保工安與研發支出資訊">
# 							環保工安與研發支出資訊
# 							</a>
# </div>
# <div class="dd">
# <a alt="高速鐵路運輸服務碳足跡" href="/tw/Article/ArticleContent/5a1f4c72-b564-4706-bcdd-efbda93c3d93" title="高速鐵路運輸服務碳足跡">
# 							高速鐵路運輸服務碳足跡
# 							</a>
# </div>
# <div class="dd">
# <a alt="高鐵專題報導" href="/tw/Article/ArticleContent/d263299b-e2e0-4b13-be77-a7c82b2d2357" title="高鐵專題報導">
# 							高鐵專題報導<em></em>
# </a>
# </div>
# <div class="dtnolink" title="營運現狀">營運現狀</div>
# <div class="dd">
# <a alt="營運年度概況" href="/tw/Article/ArticleContent/1e07f685-045e-403c-bf92-88c2d86bf826" title="營運年度概況">
# 							營運年度概況<em></em>
# </a>
# </div>
# </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# <div class="dtnolink" title="政策法規">政策法規</div>
# <div class="dd">
# <a alt="線上購票交易注意事項" href="/tw/Article/ArticleContent/291d80fe-080f-4442-90d0-9a9b82f119e5" title="線上購票交易注意事項">
# 							線上購票交易注意事項
# 							</a>
# </div>
# <div class="dd">
# <a alt="個人資料保護專區" href="/tw/Article/ArticleContent/d1fa3bcb-a016-47e2-88c6-7b7cbed00ed5" title="個人資料保護專區">
# 							個人資料保護專區
# 							</a>
# </div>
# <div class="dd">
# <a alt="相關法規" href="/tw/Article/ArticleContent/7de57796-db08-4d94-b183-bd62618859db" title="相關法規">
# 							相關法規<em></em>
# </a>
# </div>
# <div class="dtnolink" title="合作夥伴">合作夥伴</div>
# <div class="dd">
# <a alt="業務申辦 " href="/tw/Article/ArticleContent/4efcd63f-6d07-4363-8a52-26a4a4f462cb" title="業務申辦 ">
# 							業務申辦 <em></em>
# </a>
# </div>
# <div class="dt">
# <a alt="招標資訊" href="/tw/Tendering" title="招標資訊">
# 							招標資訊<em></em>
# </a>
# </div>
# <div class="dtnolink" title="加入高鐵">加入高鐵</div>
# <div class="dd">
# <a alt="幸福高鐵" href="/tw/Article/ArticleContent/91918831-5417-459a-9774-312f31a66ca2" title="幸福高鐵">
# 							幸福高鐵
# 							</a>
# </div>
# </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# <div class="dd">
# <a alt="甄選流程" href="/tw/Article/ArticleContent/923049a0-10dd-4c2f-927b-66e470c9c16e" title="甄選流程">
# 							甄選流程
# 							</a>
# </div>
# <div class="dd">
# <a alt="我要應徵[將另開新視窗 ]" href="http://ehrweb.104.com.tw/job.do?uno=16446274" target="_blank" title="我要應徵[將另開新視窗 ]">
# 							我要應徵<span style="display:none;">[將另開新視窗 ]</span><span style="display:none;">[將另開新視窗 ]</span><em></em>
# </a>
# </div>
# <div class="dt">
# <a alt="高鐵探索館" href="/tw/Article/ArticleContent/845f79cc-7a2b-496a-95ac-16810c19f8e0" title="高鐵探索館">
# 							高鐵探索館<em></em>
# </a>
# </div>
# </div>
# <div class="list_line"></div>
# </div>
# </li>
# <li class="nav_sponsor"><a href="/tw//" title="投資人關係">投資人關係</a>
# <div class="dl height_304">
# <div class="first_list">
# <div class="has_photo_list"><img alt="投資人關係" height="120" src="/event/index_img/nav_sponsor.jpg" title="投資人關係" width="200"/></div>
# <div class="photo_list_word" title="與時間競速，與時代並進，高鐵期望與您一同展望更迅捷美好的未來。">與時間競速，與時代並進，高鐵期望與您一同展望更迅捷美好的未來。</div>
# </div>
# <div class="list_area list_area_tw">
# <div class="dtnolink" title="投資人關係">投資人關係</div>
# <div class="dd">
# <a alt="106年度股東常會訊息" href="/tw/Article/ArticleContent/dc5d797c-f236-419a-976c-fe754597fc80" title="106年度股東常會訊息">
# 							106年度股東常會訊息
# 							</a>
# </div>
# <div class="dd">
# <a alt="基本資料" href="/tw/StockInfo/Index" title="基本資料">
# 							基本資料
# 							</a>
# </div>
# <div class="dd">
# <a alt="組織系統圖" href="/tw/Article/ArticleContent/07a19853-350d-42e4-b0c6-5bdd76c3ce7d" title="組織系統圖">
# 							組織系統圖
# 							</a>
# </div>
# <div class="dd">
# <a alt="董事會及經營團隊" href="/tw/Article/ArticleContent/eba2a49b-df9a-4955-9582-d3bfab0892d5" title="董事會及經營團隊">
# 							董事會及經營團隊
# 							</a>
# </div>
# <div class="dd">
# <a alt="重大訊息" href="http://www.thsrc.com.tw/tw/StockInfo/GreatNewsIndex" title="重大訊息">
# 							重大訊息
# 							</a>
# </div>
# <div class="dd">
# <a alt="自結損益" href="/tw/Article/ArticleContent/5aebf2ce-4186-463d-8a15-46234169e05b" title="自結損益">
# 							自結損益
# 							</a>
# </div>
# <div class="dd">
# <a alt="文件下載" href="/tw/Article/ArticleContent/d2933fd1-c223-46b0-9620-14a8501d6f51" title="文件下載">
# 							文件下載
# 							</a>
# </div>
# <div class="dd">
# <a alt="法人說明會" href="/tw/Article/ArticleContent/b1729e85-c1b4-498b-8354-a242178299bf" title="法人說明會">
# 							法人說明會<em></em>
# </a>
# </div>
# <div class="dt">
# <a alt="利害關係人" href="/tw/Article/ArticleContent/699e4e91-3cdd-422c-8dc4-ed8747a11195" title="利害關係人">
# 							利害關係人<em></em>
# </a>
# </div>
# </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# <div class="dt">
# <a alt="企業社會責任報告書" href="/tw/Article/ArticleContent/8d291a1a-90ba-4b0f-b4d5-db2a35d881f5" title="企業社會責任報告書">
# 							企業社會責任報告書<em></em>
# </a>
# </div>
# </div>
# <div class="list_line"></div>
# </div>
# </li>
# <li class="nav_life"><a href="/tw/Article/ArticleContent/383d9d45-698b-4e17-a84f-c7cb90b5adc5" title="搭高鐵‧遊台灣">搭高鐵‧遊台灣</a>
# <div class="dl height_304">
# <div class="first_list">
# <div class="has_photo_list"><img alt="搭高鐵‧遊台灣" height="120" src="/event/index_img/nav_life.jpg" title="搭高鐵‧遊台灣" width="200"/></div>
# <div class="photo_list_word" title="搭高鐵•遊台灣">搭高鐵•遊台灣 體驗台灣在地美好！</div>
# </div>
# <div class="list_area list_area_tw">
# <div class="dt">
# <a alt="高鐵假期[將另開新視窗]" href="https://tholiday.thsrc.com.tw/" target="_blank" title="高鐵假期[將另開新視窗]">
# 							高鐵假期
# 							</a>
# </div>
# <div class="dd">
# <a alt="夏季號[將另開新視窗 ]" href="https://tholiday.thsrc.com.tw/agts_thw/list?themeUuid=0E23A736-3205-462E-A7C2-8A9A11406C49" target="_blank" title="夏季號[將另開新視窗 ]">
# 							夏季號<span style="display:none;">[將另開新視窗 ]</span>
# </a>
# </div>
# <div class="dd">
# <a alt="超值一日豐富行[將另開新視窗 ]" href="https://tholiday.thsrc.com.tw/agts_thw/list?themeUuid=6BA7B081-AF33-4570-9871-FB5983AA2E19" target="_blank" title="超值一日豐富行[將另開新視窗 ]">
# 							超值一日豐富行<span style="display:none;">[將另開新視窗 ]</span>
# </a>
# </div>
# <div class="dd">
# <a alt="國家公園系列遊[將另開新視窗 ]" href="https://tholiday.thsrc.com.tw/agts_thw/list?themeUuid=798E5384-D894-4C8F-9096-823AC1923584" target="_blank" title="國家公園系列遊[將另開新視窗 ]">
# 							國家公園系列遊<span style="display:none;">[將另開新視窗 ]</span>
# </a>
# </div>
# <div class="dd">
# <a alt="搭雙鐵•遊集集[將另開新視窗 ]" href="https://tholiday.thsrc.com.tw/agts_thw/list?themeUuid=6EFDB055-0A5C-4D8A-B4E9-4F49E04792F2" target="_blank" title="搭雙鐵•遊集集[將另開新視窗 ]">
# 							搭雙鐵•遊集集<span style="display:none;">[將另開新視窗 ]</span>
# </a>
# </div>
# <div class="dd">
# <a alt="親子Fun假旅遊趣[將另開新視窗 ]" href="https://tholiday.thsrc.com.tw/agts_thw/list?themeUuid=AF80FF3B-9535-449A-BBFD-122C7ED6BF2C" target="_blank" title="親子Fun假旅遊趣[將另開新視窗 ]">
# 							親子Fun假旅遊趣<span style="display:none;">[將另開新視窗 ]</span>
# </a>
# </div>
# <div class="dd">
# <a alt="森林探險涼夏遊[將另開新視窗 ]" href="http://tholiday.thsrc.com.tw/agts_thw/list?themeUuid=50EA66CB-AF8B-40A0-B3DC-F2601A0F0DC6" target="_blank" title="森林探險涼夏遊[將另開新視窗 ]">
# 							森林探險涼夏遊<span style="display:none;">[將另開新視窗 ]</span><span style="display:none;">[將另開新視窗 ]</span><em></em>
# </a>
# </div>
# <div class="dt">
# <a alt="交通聯票" href="/tw/Article/ArticleContent/5af4ceb8-4c6f-44ec-b02d-0c398c0ad917" title="交通聯票">
# 							交通聯票
# 							</a>
# </div>
# <div class="dd">
# <a alt="高鐵＋高雄好玩卡" href="/tw/Article/ArticleContent/cb7aecfb-80d6-4956-939d-ef2387ea142b" title="高鐵＋高雄好玩卡">
# 							高鐵＋高雄好玩卡
# 							</a>
# </div>
# <div class="dd">
# <a alt="高鐵+高雄捷運" href="/tw/Article/ArticleContent/842a6c80-c554-4bf3-810c-d026409045e7" title="高鐵+高雄捷運">
# 							高鐵+高雄捷運
# 							</a>
# </div>
# </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# <div class="dd">
# <a alt="高鐵+台灣好行" href="http://www.thsrc.com.tw/tw/Article/ArticleContent/5af4ceb8-4c6f-44ec-b02d-0c398c0ad917#theGo1" title="高鐵+台灣好行">
# 							高鐵+台灣好行
# 							</a>
# </div>
# <div class="dd">
# <a alt="高鐵+航空公司" href="http://www.thsrc.com.tw/tw/Article/ArticleContent/5af4ceb8-4c6f-44ec-b02d-0c398c0ad917#theGo9" title="高鐵+航空公司">
# 							高鐵+航空公司
# 							</a>
# </div>
# <div class="dd">
# <a alt="高鐵＋北捷雙層巴士" href="/tw/Article/ArticleContent/bbf55ee3-c17e-4e13-bbd0-6a387aafd2a6" title="高鐵＋北捷雙層巴士">
# 							高鐵＋北捷雙層巴士<em></em>
# </a>
# </div>
# <div class="dt">
# <a alt="飯店聯票" href="/tw/Article/ArticleContent/c2bae549-bc17-4373-a43a-3496780aa4ea" title="飯店聯票">
# 							飯店聯票
# 							</a>
# </div>
# <div class="dd">
# <a alt="北部飯店" href="/tw/Article/ArticleContent/84b5f8e5-98b5-48b5-bc5f-9a24cfe6119a" title="北部飯店">
# 							北部飯店
# 							</a>
# </div>
# <div class="dd">
# <a alt="中部飯店" href="/tw/Article/ArticleContent/6fdec9c4-0da5-4a67-b38d-5c11d538b7c0" title="中部飯店">
# 							中部飯店
# 							</a>
# </div>
# <div class="dd">
# <a alt="南部飯店" href="/tw/Article/ArticleContent/d157819a-dd4e-4191-b60c-5645b02432d6" title="南部飯店">
# 							南部飯店
# 							</a>
# </div>
# <div class="dd">
# <a alt="東部飯店" href="/tw/Article/ArticleContent/ae14d887-26c3-4c6f-9811-d8a88c17abd9" title="東部飯店">
# 							東部飯店
# 							</a>
# </div>
# <div class="dd">
# <a alt="豪華星級享樂遊" href="/tw/Article/ArticleContent/bbb690c1-d388-4692-bc95-0d12a81b1b81" title="豪華星級享樂遊">
# 							豪華星級享樂遊
# 							</a>
# </div>
# <div class="dd">
# <a alt="小資精省旅遊趣" href="/tw/Article/ArticleContent/ccd52eb1-80ab-4895-ab94-f412f45e9dbf" title="小資精省旅遊趣">
# 							小資精省旅遊趣
# 							</a>
# </div>
# </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
# <div class="dd">
# <a alt="豔夏時光 大小朋友瘋出遊" href="/tw/Article/ArticleContent/62de917a-7c01-430a-abe6-1807518e83b0" title="豔夏時光 大小朋友瘋出遊">
# 							豔夏時光 大小朋友瘋出遊
# 							</a>
# </div>
# <div class="dd">
# <a alt="綠野仙蹤樂悠遊" href="/tw/Article/ArticleContent/52ba1070-2ad5-4b00-9491-68de4915ceb8" title="綠野仙蹤樂悠遊">
# 							綠野仙蹤樂悠遊
# 							</a>
# </div>
# <div class="dd">
# <a alt="湖光水色輕旅行" href="/tw/Article/ArticleContent/90b947cd-cca8-464e-9424-d89cad764727" title="湖光水色輕旅行">
# 							湖光水色輕旅行<em></em>
# </a>
# </div>
# <div class="dt">
# <a alt="搭高鐵．遊台灣" href="/tw/Article/ArticleContent/383d9d45-698b-4e17-a84f-c7cb90b5adc5" title="搭高鐵．遊台灣">
# 							搭高鐵．遊台灣<em></em>
# </a>
# </div>
# </div>
# <div class="list_line"></div>
# </div>
# </li>
# <li class="top_24hours">
# <a alt="24小時網路訂票[將另開新視窗]" href="https://irs.thsrc.com.tw/IMINT?locale=tw" target="_blank" title="24小時網路訂票[將另開新視窗]">24小時網路訂票[將另開新視窗]</a>
# </li></ul>
# </nav>
# </header>
# <div id="printcontent">
# <aside class="ticket_bread">
# <div class="ticket_bread_left">
# <ul>
# <li class="ticket_bread_one"><a accesskey="C" class="aaBrick" href="#" title="主要內容區"><span>:::</span></a><a href="/" title="首頁">首頁</a></li>
# <li><a href="/tw/SiteMap/#T" title="購票資訊">購票資訊</a></li>
# <li><a href="/tw" title="快速查詢">快速查詢</a></li>
# <li><a class="current" href="javascript:;" style="cursor:default" title="時刻表與票價查詢">時刻表與票價查詢</a></li>
# </ul>
# <br/>
# </div>
# <!--ticket_bread_left-->
# <div class="ticket_bread_right">
# <!--Content_Start-->
# <noscript style="
#     position: absolute;
#     top: 55px;
#     right: 0px;
#     line-height: 18px;
#     width: 500px;
#     z-index:100;
#     background:#FFF;
# ">
# <p>友善列印SCRIPT，如您的瀏覽器不支援，請利用鍵盤按住Ctrl鍵 + P。 <br/>
#      字級大小SCRIPT，如您的瀏覽器不支援，IE6請利用鍵盤按住ALT鍵 + V → X → (G)最大&gt;<br/>
#      (L)較大(M)中(S)較小(A)小，來選擇適合您的文字大小，如為IE7或Firefoxy與Chrome瀏覽器則<br/>
#      可利用鍵盤 Ctrl + (+)放大 (-)縮小來改變字型大小。</p>
# </noscript>
# <a class="print_this" href="javascript:;" title="列印本頁">列印本頁</a>
# <!--Content_End-->
# </div>
# <script type="text/javascript">
#                 /*字體大小區-------------------------------------------------------------------------------------------*/
#                 $(document).ready(function () {
#                     $('.ticket_bread_right ol li').click(function () {
#                         $('.ticket_bread_right ol li').removeClass('current');
#                         $(this).addClass('current');
#                         switch ($(this).index()) {
#                             case 0:
#                                 $('.word_size').css('font-size', '18px');
#                                 break;
#                             case 1:
#                                 $('.word_size').css('font-size', '15px');
#                                 break;
#                             case 2:
#                                 $('.word_size').css('font-size', '12px');
#                                 break;
#
#                         }
#
#                     });
#                     $('.ticket_bread_right ol li').keypress(function () {
#                         $('.ticket_bread_right ol li').removeClass('current');
#                         $(this).addClass('current');
#                         switch ($(this).index()) {
#                             case 0:
#                                 $('.word_size').css('font-size', '18px');
#                                 break;
#                             case 1:
#                                 $('.word_size').css('font-size', '15px');
#                                 break;
#                             case 2:
#                                 $('.word_size').css('font-size', '12px');
#                                 break;
#
#                         }
#
#                     });
#                 });
#                 /*字體大小區 End-------------------------------------------------------------------------------------------*/
#             </script>
# </aside>
# <!--ticket_bread-->
# <!--print js-->
# <script src="/Content/Script/printFunction.js" type="text/javascript"></script>
# <!--print js-->
# <!--主要內容區導盲磚-->
# <section class="common_content">
# <br/>
# <h2 class="time_search_title" title="時刻表與票價查詢">時刻表與票價查詢</h2>
# <section class="time_check time_check_tw">
# <h3 class="time_check_title time_check_title_tw" title="請選擇查詢條件">請選擇查詢條件 </h3>
# <section class="time_check_left time_check_left_tw">
# <form action="/tw/TimeTable/SearchResult" id="formQuickTimeTableSearch" method="post" name="formQuickTimeTableSearch">
# <fieldset class="start_time">
# <label for="StartStation">出發站<em> : </em>
# <select id="StartStation" name="StartStation" style="width: 155px;"><option value=""> 請選擇</option>
# <option selected="" value="2f940836-cedc-41ef-8e28-c2336ac8fe68"> 南港站</option>
# <option value="977abb69-413a-4ccf-a109-0272c24fd490"> 台北站</option>
# <option value="e6e26e66-7dc1-458f-b2f3-71ce65fdc95f"> 板橋站</option>
# <option value="fbd828d8-b1da-4b06-a3bd-680cdca4d2cd"> 桃園站</option>
# <option value="a7a04c89-900b-4798-95a3-c01c455622f4"> 新竹站</option>
# <option value="e8fc2123-2aaf-46ff-ad79-51d4002a1ef3"> 苗栗站</option>
# <option value="3301e395-46b8-47aa-aa37-139e15708779"> 台中站</option>
# <option value="38b8c40b-aef0-4d66-b257-da96ec51620e"> 彰化站</option>
# <option value="5f4c7bb0-c676-4e39-8d3c-f12fc188ee5f"> 雲林站</option>
# <option value="60831846-f0e4-47f6-9b5b-46323ebdcef7"> 嘉義站</option>
# <option value="9c5ac6ca-ec89-48f8-aab0-41b738cb1814"> 台南站</option>
# <option value="f2519629-5973-4d08-913b-479cce78a356"> 左營站</option>
# </select>
# </label></fieldset>
# <fieldset class="end_time end_time_tw">
# <label for="EndStation">到達站<em> : </em></label>
# <select id="EndStation" name="EndStation" style="width: 155px;"><option value=""> 請選擇</option>
# <option value="2f940836-cedc-41ef-8e28-c2336ac8fe68"> 南港站</option>
# <option value="977abb69-413a-4ccf-a109-0272c24fd490"> 台北站</option>
# <option value="e6e26e66-7dc1-458f-b2f3-71ce65fdc95f"> 板橋站</option>
# <option value="fbd828d8-b1da-4b06-a3bd-680cdca4d2cd"> 桃園站</option>
# <option value="a7a04c89-900b-4798-95a3-c01c455622f4"> 新竹站</option>
# <option value="e8fc2123-2aaf-46ff-ad79-51d4002a1ef3"> 苗栗站</option>
# <option value="3301e395-46b8-47aa-aa37-139e15708779"> 台中站</option>
# <option value="38b8c40b-aef0-4d66-b257-da96ec51620e"> 彰化站</option>
# <option value="5f4c7bb0-c676-4e39-8d3c-f12fc188ee5f"> 雲林站</option>
# <option value="60831846-f0e4-47f6-9b5b-46323ebdcef7"> 嘉義站</option>
# <option value="9c5ac6ca-ec89-48f8-aab0-41b738cb1814"> 台南站</option>
# <option selected="" value="f2519629-5973-4d08-913b-479cce78a356"> 左營站</option>
# </select>
# </fieldset>
# <fieldset class="date_for date_for_tw">
# <label for="SearchDate">日 期<em> : </em></label>
# <input class="datemodel" id="SearchDate" name="SearchDate" placeholder="西元年/月/日" size="12" type="textbox" value="2017/07/05"/><script>
# $(document).ready(function() {
# $("#SearchDate").datepicker("option", "minDate", new Date(2017, 7 - 1, 5));
# $("#SearchDate").datepicker("option", "maxDate", new Date(2017, 8 - 1, 1));
# });
# </script>
# </fieldset>
# <fieldset class="which_time which_time_tw">
# <label for="SearchTime">時 間<em> : </em></label>
# <select id="SearchTime" name="SearchTime" style="width: 100px;"><option value="">請選擇</option>
# <option value="06:00">06:00</option>
# <option value="06:30">06:30</option>
# <option value="07:00">07:00</option>
# <option value="07:30">07:30</option>
# <option value="08:00">08:00</option>
# <option value="08:30">08:30</option>
# <option value="09:00">09:00</option>
# <option value="09:30">09:30</option>
# <option value="10:00">10:00</option>
# <option value="10:30">10:30</option>
# <option value="11:00">11:00</option>
# <option value="11:30">11:30</option>
# <option value="12:00">12:00</option>
# <option value="12:30">12:30</option>
# <option value="13:00">13:00</option>
# <option value="13:30">13:30</option>
# <option value="14:00">14:00</option>
# <option value="14:30">14:30</option>
# <option value="15:00">15:00</option>
# <option value="15:30">15:30</option>
# <option value="16:00">16:00</option>
# <option value="16:30">16:30</option>
# <option value="17:00">17:00</option>
# <option value="17:30">17:30</option>
# <option value="18:00">18:00</option>
# <option value="18:30">18:30</option>
# <option value="19:00">19:00</option>
# <option value="19:30">19:30</option>
# <option value="20:00">20:00</option>
# <option value="20:30">20:30</option>
# <option value="21:00">21:00</option>
# <option value="21:30">21:30</option>
# <option value="22:00">22:00</option>
# <option value="22:30">22:30</option>
# <option value="23:00">23:00</option>
# <option value="23:30">23:30</option>
# </select>
# <label for="SearchWay"></label>
# <select id="SearchWay" name="SearchWay" style="width: 60px;"><option selected="" value="DepartureInMandarin"> 出發</option>
# <option value="ArrivalInMandarin"> 抵達</option>
# </select>
# <input id="RestTime" name="RestTime" type="hidden" value=""/>
# <input id="EarlyOrLater" name="EarlyOrLater" type="hidden" value=""/>
# </fieldset>
# <fieldset class="apply_sale">
# <label>適用優惠<em> : </em></label>
# <div class="apply_saleitems">
# <input id="DiscountType" name="DiscountType" type="checkbox" value="e1b4c4d9-98d7-4c8c-9834-e1d2528750f1"/><label for="e1b4c4d9-98d7-4c8c-9834-e1d2528750f1">早鳥</label>
# <input id="DiscountType" name="DiscountType" type="checkbox" value="68d9fc7b-7330-44c2-962a-74bc47d2ee8a"/><label for="68d9fc7b-7330-44c2-962a-74bc47d2ee8a">大學生</label>
# <input id="DiscountType" name="DiscountType" type="checkbox" value="4baae6e5-b42c-474b-a194-ff8f1783c7bb"/><label for="4baae6e5-b42c-474b-a194-ff8f1783c7bb">25人團體</label>
# <input id="DiscountType" name="DiscountType" type="checkbox" value="40863ff1-a16c-4da1-8af7-c1f8991627f3"/><label for="40863ff1-a16c-4da1-8af7-c1f8991627f3">校外教學</label>
# <input id="DiscountType" name="DiscountType" type="checkbox" value="6e5fe76b-a522-4f5c-b17a-26c8f395b87a"/><label for="6e5fe76b-a522-4f5c-b17a-26c8f395b87a">平日離峰</label>
# <input id="DiscountType" name="DiscountType" type="checkbox" value="7b83e661-1ac2-4fb7-8a06-495158d73170"/><label for="7b83e661-1ac2-4fb7-8a06-495158d73170">學生暑期</label>
# </div>
# <script>
#         var bol = $("input[type=checkbox][name=DiscountType]:checked").length >= 4;
#         $("input[type=checkbox][name=DiscountType]").not(":checked").attr("disabled", bol);
#         $("input[type=checkbox][name=DiscountType]").click(function () {
#             bol = $("input[type=checkbox][name=DiscountType]:checked").length >= 4;
#             $("input[type=checkbox][name=DiscountType]").not(":checked").attr("disabled", bol);
#         });
#     </script>
# </fieldset>
# <input class="time_search_btn time_search_btn_tw" onclick="QuickSearchSubmit();return false;" onkeypress="QuickSearchSubmit();return false;" title="立即查詢" type="submit" value="立即查詢"/>
# </form>
# <script type="text/javascript">
#     $(document).ready(function () {
#
#
# //            $("#SearchDate").attr("readonly", "true");
#     });
#
#     function QuickSearchSubmit() {
#         var startStation = $("#StartStation").val();
#         var endStation = $("#EndStation").val();
#         var time = $("#SearchTime").val();
#
#         if (startStation == "" || endStation == "")
#             alert("請選擇出發 / 到達站");
#         else if (time == "")
#             alert("請選擇時間");
#         else if (startStation == endStation)
#             alert("起站與迄站不能設為相同");
#         else
#             $("#formQuickTimeTableSearch").submit();
#     }
#
#     function RestTrainSubmit(restTime, earlyOrLater) {
#         $("#RestTime").val(restTime);
#         $("#EarlyOrLater").val(earlyOrLater);
#         QuickSearchSubmit();
#     }
#
# </script>
# <noscript>
#  請選擇出發 / 到達站
#  請選擇時間
#  起站與迄站不能設為相同
#  </noscript>
# </section>
# <!--time_check_right-->
# <section class="time_check_right time_check_right_tw">
# <h4 title="時刻表下載">時刻表下載</h4>
# <ul>
# <li><a download="2017/7/1 起適用時刻表" href="/UploadFiles/TicketFile/aaaed025-1f36-4a54-afa5-31b642847142.pdf" onclick="JumpToOtherPage('/UploadFiles/TicketFile/aaaed025-1f36-4a54-afa5-31b642847142.pdf', '1');return false;" onkeypress="JumpToOtherPage('/UploadFiles/TicketFile/aaaed025-1f36-4a54-afa5-31b642847142.pdf', '1');return false;" target="_blank" title="2017/7/1 起適用時刻表[將另開新視窗](2017/7/1 起適用時刻表.pdf)">2017/7/1 起適用時刻表</a></li>
# <li><a download="2017/4/28~6/30 適用時刻表" href="/UploadFiles/TicketFile/1dd47e19-7ff5-485d-9b99-d9eea5ea77a8.pdf" onclick="JumpToOtherPage('/UploadFiles/TicketFile/1dd47e19-7ff5-485d-9b99-d9eea5ea77a8.pdf', '1');return false;" onkeypress="JumpToOtherPage('/UploadFiles/TicketFile/1dd47e19-7ff5-485d-9b99-d9eea5ea77a8.pdf', '1');return false;" target="_blank" title="2017/4/28~6/30 適用時刻表[將另開新視窗](2017/4/28~6/30 適用時刻表.pdf)">2017/4/28~6/30 適用時刻表</a></li>
# </ul>
# </section>
# <div class="clearfix"></div>
# </section>
# <section class="time_check_result time_check_result_tw">
# <h2>Search Result</h2>
# <ul>
# <aside class="result_top result_top_tw">
# <h3>
# <strong class="front">南港站</strong>
# <strong>左營站</strong>
# </h3>
# <h4>2017/07/05(周三)</h4>
# <p>06 出發</p>
# <a class="check_N_S" href="/tw/TimeTable/DailyTimeTable/20170705" onclick="JumpToOtherPage('/tw/TimeTable/DailyTimeTable/20170705', '1');return false;" onkeypress="this.onclick();return false;" target="_blank" title="檢視2017/07/05時刻表（含南下/北上車次)[將另開新視窗 ]">檢視 2017/07/05 時刻表（含南下/北上車次) </a></aside><section class="result_table">
# <table>
# <tr>
# <th colspan="4" scope="col">車次資訊</th>
# <th colspan="1" scope="col">適用優惠</th>
# <th rowspan="2" scope="col">備註</th>
# </tr>
# <tr>
# <th class="column1" scope="col">車次</th>
# <th class="column3" scope="col">出發時間</th>
# <th class="column4" scope="col">抵達時間</th>
# <th class="column2" scope="col">行車時間</th>
# <th class="Width1" scope="col">早鳥</th>
# </tr>
# <tr>
# <td class="toTouch" colspan="7">
# <table class="touch_table"><tr>
# <td class="column1"><a href="?ID=" title="0803">0803</a></td>
# <td class="column3">06:15</td>
# <td class="column4">08:40</td>
# <td class="column2">02:25</td>
# <td class="Width1"> </td>
# <td> </td>
# </tr>
# </table>
# <div class="touch_show">
# <section class="touch_table_info touch_table_info_tw">
# <a class="touch_close" href="?ID=" title="close">close</a>
# <h3><strong>0803 列車 </strong>停靠說明 </h3>
# <ul>
# <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>06:15</em></li>
# <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>06:26</em></li>
# <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>06:34</em></li>
# <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>06:49</em></li>
# <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>07:02</em></li>
# <li class="station30 current"><a href="javascript:;" title="苗栗站">苗栗站</a><em>07:13</em></li>
# <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>07:32</em></li>
# <li class="station45 current"><a href="javascript:;" title="彰化站">彰化站</a><em>07:45</em></li>
# <li class="station50 current"><a href="javascript:;" title="雲林站">雲林站</a><em>07:56</em></li>
# <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>08:10</em></li>
# <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>08:28</em></li>
# <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>08:40</em></li>
# </ul>
# <h4> </h4>
# </section>
# </div>
# </td>
# </tr>
# <tr>
# <td class="toTouch" colspan="7">
# <table class="touch_table"><tr>
# <td class="column1"><a href="?ID=" title="0603">0603</a></td>
# <td class="column3">06:40</td>
# <td class="column4">08:50</td>
# <td class="column2">02:10</td>
# <td class="Width1"> </td>
# <td> </td>
# </tr>
# </table>
# <div class="touch_show">
# <section class="touch_table_info touch_table_info_tw">
# <a class="touch_close" href="?ID=" title="close">close</a>
# <h3><strong>0603 列車 </strong>停靠說明 </h3>
# <ul>
# ...
# <h3><strong>0205 列車 </strong>停靠說明 </h3>
# <ul>
# <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>07:40</em></li>
# <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>07:51</em></li>
# <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>07:59</em></li>
# <li class="station20 "><a href="javascript:;" title="桃園站">桃園站</a><em></em></li>
# <li class="station25 "><a href="javascript:;" title="新竹站">新竹站</a><em></em></li>
# <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
# <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>08:40</em></li>
# <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
# <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
# <li class="station55 "><a href="javascript:;" title="嘉義站">嘉義站</a><em></em></li>
# <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>09:18</em></li>
# <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>09:30</em></li>
# </ul>
# <h4> </h4>
# </section>
# </div>
# </td>
# </tr>
# <tr>
# <td class="toTouch" colspan="7">
# <table class="touch_table"><tr>
# <td class="column1"><a href="?ID=" title="0809">0809</a></td>
# <td class="column3">08:00</td>
# <td class="column4">10:25</td>
# <td class="column2">02:25</td>
# <td class="Width1"> </td>
# <td> </td>
# </tr>
# </table>
# <div class="touch_show">
# <section class="touch_table_info touch_table_info_tw">
# <a class="touch_close" href="?ID=" title="close">close</a>
# <h3><strong>0809 列車 </strong>停靠說明 </h3>
# <ul>
# <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>08:00</em></li>
# <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>08:11</em></li>
# <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>08:19</em></li>
# <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>08:34</em></li>
# <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>08:47</em></li>
# <li class="station30 current"><a href="javascript:;" title="苗栗站">苗栗站</a><em>08:58</em></li>
# <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>09:17</em></li>
# <li class="station45 current"><a href="javascript:;" title="彰化站">彰化站</a><em>09:30</em></li>
# <li class="station50 current"><a href="javascript:;" title="雲林站">雲林站</a><em>09:41</em></li>
# <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>09:55</em></li>
# <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>10:13</em></li>
# <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>10:25</em></li>
# </ul>
# <h4> </h4>
# </section>
# </div>
# </td>
# </tr>
# <tr>
# <td class="toTouch" colspan="7">
# <table class="touch_table"><tr>
# <td class="column1"><a href="?ID=" title="0613">0613</a></td>
# <td class="column3">08:10</td>
# <td class="column4">10:20</td>
# <td class="column2">02:10</td>
# <td class="Width1"> </td>
# <td> </td>
# </tr>
# </table>
# <div class="touch_show">
# <section class="touch_table_info touch_table_info_tw">
# <a class="touch_close" href="?ID=" title="close">close</a>
# <h3><strong>0613 列車 </strong>停靠說明 </h3>
# <ul>
# <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>08:10</em></li>
# <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>08:21</em></li>
# <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>08:29</em></li>
# <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>08:43</em></li>
# <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>08:56</em></li>
# <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
# <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>09:25</em></li>
# <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
# <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
# <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>09:50</em></li>
# <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>10:07</em></li>
# <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>10:20</em></li>
# </ul>
# <h4> </h4>
# </section>
# </div>
# </td>
# </tr>
# <tr>
# <td class="toTouch" colspan="7">
# <table class="touch_table"><tr>
# <td class="column1"><a href="?ID=" title="0113">0113</a></td>
# <td class="column3">08:20</td>
# <td class="column4">10:05</td>
# <td class="column2">01:45</td>
# <td class="Width1"> </td>
# <td> </td>
# </tr>
# </table>
# <div class="touch_show">
# <section class="touch_table_info touch_table_info_tw">
# <a class="touch_close" href="?ID=" title="close">close</a>
# <h3><strong>0113 列車 </strong>停靠說明 </h3>
# <ul>
# <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>08:20</em></li>
# <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>08:31</em></li>
# <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>08:39</em></li>
# <li class="station20 "><a href="javascript:;" title="桃園站">桃園站</a><em></em></li>
# <li class="station25 "><a href="javascript:;" title="新竹站">新竹站</a><em></em></li>
# <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
# <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>09:20</em></li>
# <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
# <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
# <li class="station55 "><a href="javascript:;" title="嘉義站">嘉義站</a><em></em></li>
# <li class="station65 "><a href="javascript:;" title="台南站">台南站</a><em></em></li>
# <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>10:05</em></li>
# </ul>
# <h4> </h4>
# </section>
# </div>
# </td>
# </tr>
# <tr>
# <td class="toTouch" colspan="7">
# <table class="touch_table"><tr>
# <td class="column1"><a href="?ID=" title="0615">0615</a></td>
# <td class="column3">08:35</td>
# <td class="column4">10:45</td>
# <td class="column2">02:10</td>
# <td class="Width1"> </td>
# <td> </td>
# </tr>
# </table>
# <div class="touch_show">
# <section class="touch_table_info touch_table_info_tw">
# <a class="touch_close" href="?ID=" title="close">close</a>
# <h3><strong>0615 列車 </strong>停靠說明 </h3>
# <ul>
# <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>08:35</em></li>
# <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>08:46</em></li>
# <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>08:55</em></li>
# <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>09:10</em></li>
# <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>09:22</em></li>
# <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
# <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>09:48</em></li>
# <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
# <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
# <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>10:14</em></li>
# <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>10:33</em></li>
# <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>10:45</em></li>
# </ul>
# <h4> </h4>
# </section>
# </div>
# </td>
# </tr>
# </table>
# </section><!--result_table-->
# <div class="res_top"></div>
# <div class="res_down"></div>
# <nav class="res_next_prev">
# <a class="res_next_btn res_next_btn_tw" href="?ID=" onclick="RestTrainSubmit('08:50', '2');return false;" onkeypress="this.onclick();return false;" title="較晚班次">較晚班次</a>
# </nav>
# </ul>
# </section><!--time_check_result-->
# <h3 class="kind_ticket kind_ticket_tw">車廂票價參考</h3>
# <section class="kind_ticket_list kind_ticket_list_tw">
# <table class="word_size" style="table-layout:fixed">
# <tr><th class="c1" scope="col"> </th><th scope="row">全票</th><th scope="row" style="width: 130px; white-space: nowrap;">孩童票  敬老票愛心票價</th><th scope="row">團體票</th><th scope="col">9折</th><th scope="col">8折</th><th scope="col">65折</th></tr><tr><th class="c2" scope="col">標準車廂</th><td>$1530</td><td>$765</td><td>$1450</td><td>$1375</td><td>$1220</td><td>$990</td></tr><tr><th class="c3" scope="col">商務車廂</th><td>$2000</td><td>$1250</td><td>$1900</td><td>-</td><td>-</td><td>-</td></tr><tr><th class="c4" scope="col">自由座車廂</th><td>$1480</td><td>$740</td><td>-</td><td>-</td><td>-</td><td>-</td></tr>
# </table>
# </section>
# <article class="search_word commonWord">
# <h4 class="word_size" title="公告事項說明">公告事項說明</h4>
# <ul class="word_size">
# <li title="南港─台北、南港─板橋、台北─板橋區間恕不發售商務車廂車票及團體票。">南港─台北、南港─板橋、台北─板橋區間恕不發售商務車廂車票及團體票。</li>
# <li title="欲得知列車停靠站詳細說明，請點選上方之車次連結。">欲得知列車停靠站詳細說明，請點選上方之車次連結。</li>
# <li title="本系統僅提供時刻表及票價查詢功能，如欲直接訂位，請使用台灣高鐵網路訂位系統進行線上訂位及付款。">本系統僅提供時刻表及票價查詢功能，如欲直接訂位，請使用台灣高鐵網路訂位系統進行線上訂位及付款。</li>
# <li title="本時刻表所列各次列車為開車時刻，唯於終點站為到達時刻。">本時刻表所列各次列車為開車時刻，唯於終點站為到達時刻。</li>
# </ul>
# </article>
# <article class="search_word2 commonWord">
# <h4 class="word_size" title="票價優惠說明">票價優惠說明</h4>
# <ul class="word_size">
# <li title="早鳥優惠車票，自乘車日(含)前28日起開始限量發售，最晚發售至乘車日(含)前 5 日截止。">早鳥優惠車票，自乘車日(含)前28日起開始限量發售，最晚發售至乘車日(含)前 5 日截止。</li>
# <li title="本查詢顯示之早鳥適用優惠為該車次最低早鳥折扣。愈早訂位者，愈有機會訂得早鳥 65 折優惠車票。早鳥 65 折銷售完畢即改發售早鳥 8 折，早鳥 8 折銷售完畢即改發售早鳥 9 折，早鳥 9 折銷售完畢即提前截止並改發售原價車票。">本查詢顯示之早鳥適用優惠為該車次最低早鳥折扣。愈早訂位者，愈有機會訂得早鳥 65 折優惠車票。早鳥 65 折銷售完畢即改發售早鳥 8 折，早鳥 8 折銷售完畢即改發售早鳥 9 折，早鳥 9 折銷售完畢即提前截止並改發售原價車票。</li>
# <li title="以上票價為折扣後之價格。">以上票價為折扣後之價格。</li>
# <li title="以上列車時刻及票價僅供參考，資訊若有更動，以各車站現場公布為準。">以上列車時刻及票價僅供參考，資訊若有更動，以各車站現場公布為準。</li>
# </ul>
# </article>
# <article class="siteMapTop"></article>
# </section>
# <div class="footer_list_btn" style="height:20px;"></div>
# </div>
# <!--WebsiteFooter_Start-->
# <footer>
# <!--文章分享區塊-->
# <!--文章分享區塊 end-->
# <div class="just_line"></div>
# <div style="height:10px;"></div>
# <div class="footer_top">
# <article class="phone_area">
# <strong class="footerH2Title" title="客服專線 : 4066-3000 ">客服專線 : 4066-3000 </strong>
# <ol>
# <li class="phone_01" title="苗栗：4266-3000">苗栗：4266-3000 </li>
# <li class="phone_02" title="台東、金門：4666-3000">台東、金門：4666-3000 </li>
# <li class="phone_03" title="馬祖及行動電話：02-4066-3000">馬祖及行動電話：02-4066-3000 </li>
# <li class="phone_04" title="服務時間：06:00~24:00">服務時間：06:00~24:00 </li>
# </ol>
# </article><!--phone_area-->
# <article class="reserve_area">
# <strong class="footerH2Title" title="語音訂位 : 4066-0000 ">語音訂位 : 4066-0000 </strong>
# <ol>
# <li class="phone_01" title="苗栗：4266-0000">苗栗：4266-0000 </li>
# <li class="phone_02" title="台東、金門：4666-0000">台東、金門：4666-0000 </li>
# <li class="phone_03" title="馬祖及行動電話：02-4066-0000">馬祖及行動電話：02-4066-0000 </li>
# <li class="phone_04" title="服務時間：00:00~24:00">服務時間：00:00~24:00 </li>
# </ol>
# </article><!--reserve_area-->
# <article class="service_area">
# <ul>
# <li class="service_area_line" title="常見問題"><a href="/tw/FAQ" title="常見問題">常見問題</a></li>
# <li class="service_area_line5" title="遺失物查詢"><a href="/tw/LostAndFound" title="遺失物查詢">遺失物查詢</a></li>
# <li class="service_area_line" title="招標資訊"><a href="/tw/Tendering" title="招標資訊">招標資訊</a></li>
# <li class="service_area_line" title="獲獎事蹟"><a href="/tw/Article/ArticleContent/63d60a32-0600-4cd7-ac37-6ad8316b7f1e" title="獲獎事蹟">獲獎事蹟</a></li>
# <li title="企業社會責任"><a href="http://www2.thsrc.com.tw/Content/UploadFiles/CorporateResponsibility.pdf" target="_blank" title="企業社會責任[將另開新視窗 ]">企業社會責任<span style="display:none;">[將另開新視窗 ]</span></a></li>
# </ul>
# <ul>
# <li><a href="/tw/Article/ArticleContent/d1fa3bcb-a016-47e2-88c6-7b7cbed00ed5" title="個人資料保護政策及顧客個人資料保護權益事項">個人資料保護政策及顧客個人資料保護權益事項</a></li>
# </ul>
# <ul>
# <li class="service_area_line3"><a href="/tw/Article/ArticleContent/b9dcb8ea-02ab-4726-b71d-335904dbd86b" title="智慧財產權及免責條款宣告">智慧財產權及免責條款宣告</a></li>
# <li class="service_area_line4"><a href="/tw/Article/ArticleContent/291d80fe-080f-4442-90d0-9a9b82f119e5" title="交易注意事項">交易注意事項</a></li>
# <li title="聯絡我們"><a href="https://www.thsrc.com.tw/tw/ContactUs" title="聯絡我們">聯絡我們</a></li>
# </ul>
# </article><!--service_area-->
# </div><!--footer_top-->
# <div class="footerH5">
# <span>以上皆為付費電話，依一般市話及行動電話費率標準計費。</span></div>
# <article style="width:488px;float:left">
# <div class="footerH6">
# <div><span>台灣高速鐵路股份有限公司 版權所有 </span>© Taiwan High Speed Rail Corporation. All Rights Reserved.</div>
# </div>
# </article>
# <article style="width: 149px;float: right;margin-top: 6px;margin-right: 10px;">
# <img alt="真實接觸 be there" src="/Content/images/bethere_THSRC.png" title="真實接觸 be there"/>
# </article>
# </footer>
# <!--WebsiteFooter_End-->
# </div>
# <script src="/Content/Script/time_search.js" type="text/javascript"></script>
# <script type="text/javascript">
#
#     var _gaq = _gaq || [];
#     var pStr = location.pathname;
#     if ( pStr.indexOf("/en/") != -1 )
#     {
#         _gaq.push(['_setAccount', 'UA-9967381-19']);
#     }
#     else if (pStr.indexOf("/jp/") != -1)
#     {
#         _gaq.push(['_setAccount', 'UA-9967381-20']);
#     }
#     else
#         _gaq.push(['_setAccount', 'UA-9967381-1']);
#
#     //_gaq.push(['_setAccount', 'UA-9967381-1']);
#     _gaq.push(['_trackPageview']);
#
#     (function () {
#         var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#         ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#         var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#     })();
#
# </script>
# </body>
# </html>

# %%
soup.select('table')
# Out:
# [<table>
#  <tr>
#  <th colspan="4" scope="col">車次資訊</th>
#  <th colspan="1" scope="col">適用優惠</th>
#  <th rowspan="2" scope="col">備註</th>
#  </tr>
#  <tr>
#  <th class="column1" scope="col">車次</th>
#  <th class="column3" scope="col">出發時間</th>
#  <th class="column4" scope="col">抵達時間</th>
#  <th class="column2" scope="col">行車時間</th>
#  <th class="Width1" scope="col">早鳥</th>
#  </tr>
#  <tr>
#  <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0803">0803</a></td>
#  <td class="column3">06:15</td>
#  <td class="column4">08:40</td>
#  <td class="column2">02:25</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0803 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>06:15</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>06:26</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>06:34</em></li>
#  <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>06:49</em></li>
#  <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>07:02</em></li>
#  <li class="station30 current"><a href="javascript:;" title="苗栗站">苗栗站</a><em>07:13</em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>07:32</em></li>
#  <li class="station45 current"><a href="javascript:;" title="彰化站">彰化站</a><em>07:45</em></li>
#  <li class="station50 current"><a href="javascript:;" title="雲林站">雲林站</a><em>07:56</em></li>
#  <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>08:10</em></li>
#  <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>08:28</em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>08:40</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>
#  </tr>
#  <tr>
#  <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0603">0603</a></td>
#  <td class="column3">06:40</td>
#  <td class="column4">08:50</td>
#  <td class="column2">02:10</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0603 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>06:40</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>06:51</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>07:00</em></li>
#  <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>07:15</em></li>
#  <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>07:27</em></li>
#  <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>07:53</em></li>
#  <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
#  <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
#  <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>08:19</em></li>
#  <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>08:38</em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>08:50</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>
#  </tr>
#  <tr>
#  <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0805">0805</a></td>
#  <td class="column3">07:00</td>
#  <td class="column4">09:25</td>
#  <td class="column2">02:25</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0805 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>07:00</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>07:11</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>07:19</em></li>
#  <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>07:34</em></li>
#  <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>07:47</em></li>
#  <li class="station30 current"><a href="javascript:;" title="苗栗站">苗栗站</a><em>07:58</em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>08:17</em></li>
#  <li class="station45 current"><a href="javascript:;" title="彰化站">彰化站</a><em>08:30</em></li>
#  <li class="station50 current"><a href="javascript:;" title="雲林站">雲林站</a><em>08:41</em></li>
#  <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>08:55</em></li>
#  <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>09:13</em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>09:25</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>
#  </tr>
#  <tr>
#  <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0109">0109</a></td>
#  <td class="column3">07:20</td>
#  <td class="column4">09:05</td>
#  <td class="column2">01:45</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0109 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>07:20</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>07:31</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>07:39</em></li>
#  <li class="station20 "><a href="javascript:;" title="桃園站">桃園站</a><em></em></li>
#  <li class="station25 "><a href="javascript:;" title="新竹站">新竹站</a><em></em></li>
#  <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>08:20</em></li>
#  <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
#  <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
#  <li class="station55 "><a href="javascript:;" title="嘉義站">嘉義站</a><em></em></li>
#  <li class="station65 "><a href="javascript:;" title="台南站">台南站</a><em></em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>09:05</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>
#  </tr>
#  <tr>
#  <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0609">0609</a></td>
#  <td class="column3">07:35</td>
#  <td class="column4">09:45</td>
#  <td class="column2">02:10</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0609 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>07:35</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>07:46</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>07:55</em></li>
#  <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>08:10</em></li>
#  <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>08:22</em></li>
#  <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>08:48</em></li>
#  <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
#  <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
#  <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>09:14</em></li>
#  <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>09:33</em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>09:45</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>
#  </tr>
#  <tr>
#  <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0205">0205</a></td>
#  <td class="column3">07:40</td>
#  <td class="column4">09:30</td>
#  <td class="column2">01:50</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0205 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>07:40</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>07:51</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>07:59</em></li>
#  <li class="station20 "><a href="javascript:;" title="桃園站">桃園站</a><em></em></li>
#  <li class="station25 "><a href="javascript:;" title="新竹站">新竹站</a><em></em></li>
#  <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>08:40</em></li>
#  <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
#  <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
#  <li class="station55 "><a href="javascript:;" title="嘉義站">嘉義站</a><em></em></li>
#  <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>09:18</em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>09:30</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>
#  </tr>
#  <tr>
#  <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0809">0809</a></td>
#  <td class="column3">08:00</td>
#  <td class="column4">10:25</td>
#  <td class="column2">02:25</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0809 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>08:00</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>08:11</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>08:19</em></li>
#  <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>08:34</em></li>
#  <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>08:47</em></li>
#  <li class="station30 current"><a href="javascript:;" title="苗栗站">苗栗站</a><em>08:58</em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>09:17</em></li>
#  <li class="station45 current"><a href="javascript:;" title="彰化站">彰化站</a><em>09:30</em></li>
#  <li class="station50 current"><a href="javascript:;" title="雲林站">雲林站</a><em>09:41</em></li>
#  <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>09:55</em></li>
#  <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>10:13</em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>10:25</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>
#  </tr>
#  <tr>
#  <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0613">0613</a></td>
#  <td class="column3">08:10</td>
#  <td class="column4">10:20</td>
#  <td class="column2">02:10</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0613 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>08:10</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>08:21</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>08:29</em></li>
#  <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>08:43</em></li>
#  <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>08:56</em></li>
#  <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>09:25</em></li>
#  <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
#  <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
#  <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>09:50</em></li>
#  <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>10:07</em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>10:20</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>
#  </tr>
#  <tr>
#  <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0113">0113</a></td>
#  <td class="column3">08:20</td>
#  <td class="column4">10:05</td>
#  <td class="column2">01:45</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0113 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>08:20</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>08:31</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>08:39</em></li>
#  <li class="station20 "><a href="javascript:;" title="桃園站">桃園站</a><em></em></li>
#  <li class="station25 "><a href="javascript:;" title="新竹站">新竹站</a><em></em></li>
#  <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>09:20</em></li>
#  <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
#  <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
#  <li class="station55 "><a href="javascript:;" title="嘉義站">嘉義站</a><em></em></li>
#  <li class="station65 "><a href="javascript:;" title="台南站">台南站</a><em></em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>10:05</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>
#  </tr>
#  <tr>
#  <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0615">0615</a></td>
#  <td class="column3">08:35</td>
#  <td class="column4">10:45</td>
#  <td class="column2">02:10</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0615 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>08:35</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>08:46</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>08:55</em></li>
#  <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>09:10</em></li>
#  <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>09:22</em></li>
#  <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>09:48</em></li>
#  <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
#  <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
#  <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>10:14</em></li>
#  <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>10:33</em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>10:45</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>
#  </tr>
#  </table>, <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0803">0803</a></td>
#  <td class="column3">06:15</td>
#  <td class="column4">08:40</td>
#  <td class="column2">02:25</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>, <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0603">0603</a></td>
#  <td class="column3">06:40</td>
#  <td class="column4">08:50</td>
#  <td class="column2">02:10</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>, <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0805">0805</a></td>
#  <td class="column3">07:00</td>
#  <td class="column4">09:25</td>
#  <td class="column2">02:25</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>, <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0109">0109</a></td>
#  <td class="column3">07:20</td>
#  <td class="column4">09:05</td>
#  <td class="column2">01:45</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>, <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0609">0609</a></td>
#  <td class="column3">07:35</td>
#  <td class="column4">09:45</td>
#  <td class="column2">02:10</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>, <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0205">0205</a></td>
#  <td class="column3">07:40</td>
#  <td class="column4">09:30</td>
#  <td class="column2">01:50</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>, <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0809">0809</a></td>
#  <td class="column3">08:00</td>
#  <td class="column4">10:25</td>
#  <td class="column2">02:25</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>, <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0613">0613</a></td>
#  <td class="column3">08:10</td>
#  <td class="column4">10:20</td>
#  <td class="column2">02:10</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>, <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0113">0113</a></td>
#  <td class="column3">08:20</td>
#  <td class="column4">10:05</td>
#  <td class="column2">01:45</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>, <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0615">0615</a></td>
#  <td class="column3">08:35</td>
#  <td class="column4">10:45</td>
#  <td class="column2">02:10</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>, <table class="word_size" style="table-layout:fixed">
#  <tr><th class="c1" scope="col"> </th><th scope="row">全票</th><th scope="row" style="width: 130px; white-space: nowrap;">孩童票  敬老票愛心票價</th><th scope="row">團體票</th><th scope="col">9折</th><th scope="col">8折</th><th scope="col">65折</th></tr><tr><th class="c2" scope="col">標準車廂</th><td>$1530</td><td>$765</td><td>$1450</td><td>$1375</td><td>$1220</td><td>$990</td></tr><tr><th class="c3" scope="col">商務車廂</th><td>$2000</td><td>$1250</td><td>$1900</td><td>-</td><td>-</td><td>-</td></tr><tr><th class="c4" scope="col">自由座車廂</th><td>$1480</td><td>$740</td><td>-</td><td>-</td><td>-</td><td>-</td></tr>
#  </table>]

# %%
soup.select(" table > tr > td")
# Out:
# [<td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0803">0803</a></td>
#  <td class="column3">06:15</td>
#  <td class="column4">08:40</td>
#  <td class="column2">02:25</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0803 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>06:15</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>06:26</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>06:34</em></li>
#  <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>06:49</em></li>
#  <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>07:02</em></li>
#  <li class="station30 current"><a href="javascript:;" title="苗栗站">苗栗站</a><em>07:13</em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>07:32</em></li>
#  <li class="station45 current"><a href="javascript:;" title="彰化站">彰化站</a><em>07:45</em></li>
#  <li class="station50 current"><a href="javascript:;" title="雲林站">雲林站</a><em>07:56</em></li>
#  <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>08:10</em></li>
#  <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>08:28</em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>08:40</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>, <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0603">0603</a></td>
#  <td class="column3">06:40</td>
#  <td class="column4">08:50</td>
#  <td class="column2">02:10</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0603 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>06:40</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>06:51</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>07:00</em></li>
#  <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>07:15</em></li>
#  <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>07:27</em></li>
#  <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>07:53</em></li>
#  <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
#  <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
#  <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>08:19</em></li>
#  <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>08:38</em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>08:50</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>, <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0805">0805</a></td>
#  <td class="column3">07:00</td>
#  <td class="column4">09:25</td>
#  <td class="column2">02:25</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0805 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>07:00</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>07:11</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>07:19</em></li>
#  <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>07:34</em></li>
#  <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>07:47</em></li>
#  <li class="station30 current"><a href="javascript:;" title="苗栗站">苗栗站</a><em>07:58</em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>08:17</em></li>
#  <li class="station45 current"><a href="javascript:;" title="彰化站">彰化站</a><em>08:30</em></li>
#  <li class="station50 current"><a href="javascript:;" title="雲林站">雲林站</a><em>08:41</em></li>
#  <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>08:55</em></li>
#  <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>09:13</em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>09:25</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>, <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0109">0109</a></td>
#  <td class="column3">07:20</td>
#  <td class="column4">09:05</td>
#  <td class="column2">01:45</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0109 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>07:20</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>07:31</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>07:39</em></li>
#  <li class="station20 "><a href="javascript:;" title="桃園站">桃園站</a><em></em></li>
#  <li class="station25 "><a href="javascript:;" title="新竹站">新竹站</a><em></em></li>
#  <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>08:20</em></li>
#  <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
#  <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
#  <li class="station55 "><a href="javascript:;" title="嘉義站">嘉義站</a><em></em></li>
#  <li class="station65 "><a href="javascript:;" title="台南站">台南站</a><em></em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>09:05</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>, <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0609">0609</a></td>
#  <td class="column3">07:35</td>
#  <td class="column4">09:45</td>
#  <td class="column2">02:10</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0609 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>07:35</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>07:46</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>07:55</em></li>
#  <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>08:10</em></li>
#  <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>08:22</em></li>
#  <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>08:48</em></li>
#  <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
#  <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
#  <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>09:14</em></li>
#  <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>09:33</em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>09:45</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>, <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0205">0205</a></td>
#  <td class="column3">07:40</td>
#  <td class="column4">09:30</td>
#  <td class="column2">01:50</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0205 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>07:40</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>07:51</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>07:59</em></li>
#  <li class="station20 "><a href="javascript:;" title="桃園站">桃園站</a><em></em></li>
#  <li class="station25 "><a href="javascript:;" title="新竹站">新竹站</a><em></em></li>
#  <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>08:40</em></li>
#  <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
#  <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
#  <li class="station55 "><a href="javascript:;" title="嘉義站">嘉義站</a><em></em></li>
#  <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>09:18</em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>09:30</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>, <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0809">0809</a></td>
#  <td class="column3">08:00</td>
#  <td class="column4">10:25</td>
#  <td class="column2">02:25</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0809 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>08:00</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>08:11</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>08:19</em></li>
#  <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>08:34</em></li>
#  <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>08:47</em></li>
#  <li class="station30 current"><a href="javascript:;" title="苗栗站">苗栗站</a><em>08:58</em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>09:17</em></li>
#  <li class="station45 current"><a href="javascript:;" title="彰化站">彰化站</a><em>09:30</em></li>
#  <li class="station50 current"><a href="javascript:;" title="雲林站">雲林站</a><em>09:41</em></li>
#  <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>09:55</em></li>
#  <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>10:13</em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>10:25</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>, <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0613">0613</a></td>
#  <td class="column3">08:10</td>
#  <td class="column4">10:20</td>
#  <td class="column2">02:10</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0613 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>08:10</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>08:21</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>08:29</em></li>
#  <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>08:43</em></li>
#  <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>08:56</em></li>
#  <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>09:25</em></li>
#  <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
#  <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
#  <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>09:50</em></li>
#  <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>10:07</em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>10:20</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>, <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0113">0113</a></td>
#  <td class="column3">08:20</td>
#  <td class="column4">10:05</td>
#  <td class="column2">01:45</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0113 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>08:20</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>08:31</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>08:39</em></li>
#  <li class="station20 "><a href="javascript:;" title="桃園站">桃園站</a><em></em></li>
#  <li class="station25 "><a href="javascript:;" title="新竹站">新竹站</a><em></em></li>
#  <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>09:20</em></li>
#  <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
#  <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
#  <li class="station55 "><a href="javascript:;" title="嘉義站">嘉義站</a><em></em></li>
#  <li class="station65 "><a href="javascript:;" title="台南站">台南站</a><em></em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>10:05</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>, <td class="toTouch" colspan="7">
#  <table class="touch_table"><tr>
#  <td class="column1"><a href="?ID=" title="0615">0615</a></td>
#  <td class="column3">08:35</td>
#  <td class="column4">10:45</td>
#  <td class="column2">02:10</td>
#  <td class="Width1"> </td>
#  <td> </td>
#  </tr>
#  </table>
#  <div class="touch_show">
#  <section class="touch_table_info touch_table_info_tw">
#  <a class="touch_close" href="?ID=" title="close">close</a>
#  <h3><strong>0615 列車 </strong>停靠說明 </h3>
#  <ul>
#  <li class="station05 current"><a href="javascript:;" title="南港站">南港站</a><em>08:35</em></li>
#  <li class="station10 current"><a href="javascript:;" title="台北站">台北站</a><em>08:46</em></li>
#  <li class="station15 current"><a href="javascript:;" title="板橋站">板橋站</a><em>08:55</em></li>
#  <li class="station20 current"><a href="javascript:;" title="桃園站">桃園站</a><em>09:10</em></li>
#  <li class="station25 current"><a href="javascript:;" title="新竹站">新竹站</a><em>09:22</em></li>
#  <li class="station30 "><a href="javascript:;" title="苗栗站">苗栗站</a><em></em></li>
#  <li class="station40 current"><a href="javascript:;" title="台中站">台中站</a><em>09:48</em></li>
#  <li class="station45 "><a href="javascript:;" title="彰化站">彰化站</a><em></em></li>
#  <li class="station50 "><a href="javascript:;" title="雲林站">雲林站</a><em></em></li>
#  <li class="station55 current"><a href="javascript:;" title="嘉義站">嘉義站</a><em>10:14</em></li>
#  <li class="station65 current"><a href="javascript:;" title="台南站">台南站</a><em>10:33</em></li>
#  <li class="station75 current"><a href="javascript:;" title="左營站">左營站</a><em>10:45</em></li>
#  </ul>
#  <h4> </h4>
#  </section>
#  </div>
#  </td>, <td class="column1"><a href="?ID=" title="0803">0803</a></td>, <td class="column3">06:15</td>, <td class="column4">08:40</td>, <td class="column2">02:25</td>, <td class="Width1"> </td>, <td> </td>, <td class="column1"><a href="?ID=" title="0603">0603</a></td>, <td class="column3">06:40</td>, <td class="column4">08:50</td>, <td class="column2">02:10</td>, <td class="Width1"> </td>, <td> </td>, <td class="column1"><a href="?ID=" title="0805">0805</a></td>, <td class="column3">07:00</td>, <td class="column4">09:25</td>, <td class="column2">02:25</td>, <td class="Width1"> </td>, <td> </td>, <td class="column1"><a href="?ID=" title="0109">0109</a></td>, <td class="column3">07:20</td>, <td class="column4">09:05</td>, <td class="column2">01:45</td>, <td class="Width1"> </td>, <td> </td>, <td class="column1"><a href="?ID=" title="0609">0609</a></td>, <td class="column3">07:35</td>, <td class="column4">09:45</td>, <td class="column2">02:10</td>, <td class="Width1"> </td>, <td> </td>, <td class="column1"><a href="?ID=" title="0205">0205</a></td>, <td class="column3">07:40</td>, <td class="column4">09:30</td>, <td class="column2">01:50</td>, <td class="Width1"> </td>, <td> </td>, <td class="column1"><a href="?ID=" title="0809">0809</a></td>, <td class="column3">08:00</td>, <td class="column4">10:25</td>, <td class="column2">02:25</td>, <td class="Width1"> </td>, <td> </td>, <td class="column1"><a href="?ID=" title="0613">0613</a></td>, <td class="column3">08:10</td>, <td class="column4">10:20</td>, <td class="column2">02:10</td>, <td class="Width1"> </td>, <td> </td>, <td class="column1"><a href="?ID=U3RhcnRTdGF0aW9uPTJmOTQwODM2LWNlZGMtNDFlZi04ZTI4LWMyMzM2YWM4ZmU2OCZFbmRTdGF0aW9uPWYyNTE5NjI5LTU5NzMtNGQ ...

# %%
for tr in soup.select("table > tr "):
    print(tr.text.strip())
# Out:
# 車次資訊
# 適用優惠
# 備註
# 車次
# 出發時間
# 抵達時間
# 行車時間
# 早鳥
# 0803
# 06:15
# 08:40
# 02:25
#
#
#
#
#
#
# close
# 0803 列車 停靠說明
#
# 南港站06:15
# 台北站06:26
# 板橋站06:34
# 桃園站06:49
# 新竹站07:02
# 苗栗站07:13
# 台中站07:32
# 彰化站07:45
# 雲林站07:56
# 嘉義站08:10
# 台南站08:28
# 左營站08:40
# 0603
# 06:40
# 08:50
# 02:10
#
#
#
#
#
#
# close
# 0603 列車 停靠說明
#
# 南港站06:40
# 台北站06:51
# 板橋站07:00
# 桃園站07:15
# 新竹站07:27
# 苗栗站
# 台中站07:53
# 彰化站
# 雲林站
# 嘉義站08:19
# 台南站08:38
# 左營站08:50
# 0805
# 07:00
# 09:25
# 02:25
#
#
#
#
#
#
# close
# 0805 列車 停靠說明
#
# 南港站07:00
# 台北站07:11
# 板橋站07:19
# 桃園站07:34
# 新竹站07:47
# 苗栗站07:58
# 台中站08:17
# 彰化站08:30
# 雲林站08:41
# 嘉義站08:55
# 台南站09:13
# 左營站09:25
# 0109
# 07:20
# 09:05
# 01:45
#
#
#
#
#
#
# close
# 0109 列車 停靠說明
#
# 南港站07:20
# 台北站07:31
# 板橋站07:39
# 桃園站
# 新竹站
# 苗栗站
# 台中站08:20
# 彰化站
# 雲林站
# 嘉義站
# 台南站
# 左營站09:05
# 0609
# 07:35
# 09:45
# 02:10
#
#
#
#
#
#
# close
# 0609 列車 停靠說明
#
# 南港站07:35
# 台北站07:46
# 板橋站07:55
# 桃園站08:10
# 新竹站08:22
# 苗栗站
# 台中站08:48
# 彰化站
# 雲林站
# 嘉義站09:14
# 台南站09:33
# 左營站09:45
# 0205
# 07:40
# 09:30
# 01:50
#
#
#
#
#
#
# close
# 0205 列車 停靠說明
#
# 南港站07:40
# 台北站07:51
# 板橋站07:59
# 桃園站
# 新竹站
# 苗栗站
# 台中站08:40
# 彰化站
# 雲林站
# 嘉義站
# 台南站09:18
# 左營站09:30
# 0809
# 08:00
# 10:25
# 02:25
#
#
#
#
#
#
# close
# 0809 列車 停靠說明
#
# 南港站08:00
# 台北站08:11
# 板橋站08:19
# 桃園站08:34
# 新竹站08:47
# 苗栗站08:58
# 台中站09:17
# 彰化站09:30
# 雲林站09:41
# 嘉義站09:55
# 台南站10:13
# 左營站10:25
# 0613
# 08:10
# 10:20
# 02:10
#
#
#
#
#
#
# close
# 0613 列車 停靠說明
#
# 南港站08:10
# 台北站08:21
# 板橋站08:29
# 桃園站08:43
# 新竹站08:56
# 苗栗站
# 台中站09:25
# 彰化站
# 雲林站
# 嘉義站09:50
# 台南站10:07
# 左營站10:20
# 0113
# 08:20
# 10:05
# 01:45
#
#
#
#
#
#
# close
# 0113 列車 停靠說明
#
# 南港站08:20
# 台北站08:31
# 板橋站08:39
# 桃園站
# 新竹站
# 苗栗站
# 台中站09:20
# 彰化站
# 雲林站
# 嘉義站
# 台南站
# 左營站10:05
# 0615
# 08:35
# 10:45
# 02:10
#
#
#
#
#
#
# close
# 0615 列車 停靠說明
#
# 南港站08:35
# 台北站08:46
# 板橋站08:55
# 桃園站09:10
# 新竹站09:22
# 苗栗站
# 台中站09:48
# 彰化站
# 雲林站
# 嘉義站10:14
# 台南站10:33
# 左營站10:45
# 0803
# 06:15
# 08:40
# 02:25
# 0603
# 06:40
# 08:50
# 02:10
# 0805
# 07:00
# 09:25
# 02:25
# 0109
# 07:20
# 09:05
# 01:45
# 0609
# 07:35
# 09:45
# 02:10
# 0205
# 07:40
# 09:30
# 01:50
# 0809
# 08:00
# 10:25
# 02:25
# 0613
# 08:10
# 10:20
# 02:10
# 0113
# 08:20
# 10:05
# 01:45
# 0615
# 08:35
# 10:45
# 02:10
# 全票孩童票  敬老票愛心票價團體票9折8折65折
# 標準車廂$1530$765$1450$1375$1220$990
# 商務車廂$2000$1250$1900---
# 自由座車廂$1480$740----

# %%
for td in soup.select(" table > tr"):
    for field in td.select('td'):
        print(" ".join(field.text.strip().split()))
    print("=="*50)
# Out:
# ====================================================================================================
# ====================================================================================================
# 0803 06:15 08:40 02:25 close 0803 列車 停靠說明 南港站06:15 台北站06:26 板橋站06:34 桃園站06:49 新竹站07:02 苗栗站07:13 台中站07:32 彰化站07:45 雲林站07:56 嘉義站08:10 台南站08:28 左營站08:40
# 0803
# 06:15
# 08:40
# 02:25
#
#
# ====================================================================================================
# 0603 06:40 08:50 02:10 close 0603 列車 停靠說明 南港站06:40 台北站06:51 板橋站07:00 桃園站07:15 新竹站07:27 苗栗站 台中站07:53 彰化站 雲林站 嘉義站08:19 台南站08:38 左營站08:50
# 0603
# 06:40
# 08:50
# 02:10
#
#
# ====================================================================================================
# 0805 07:00 09:25 02:25 close 0805 列車 停靠說明 南港站07:00 台北站07:11 板橋站07:19 桃園站07:34 新竹站07:47 苗栗站07:58 台中站08:17 彰化站08:30 雲林站08:41 嘉義站08:55 台南站09:13 左營站09:25
# 0805
# 07:00
# 09:25
# 02:25
#
#
# ====================================================================================================
# 0109 07:20 09:05 01:45 close 0109 列車 停靠說明 南港站07:20 台北站07:31 板橋站07:39 桃園站 新竹站 苗栗站 台中站08:20 彰化站 雲林站 嘉義站 台南站 左營站09:05
# 0109
# 07:20
# 09:05
# 01:45
#
#
# ====================================================================================================
# 0609 07:35 09:45 02:10 close 0609 列車 停靠說明 南港站07:35 台北站07:46 板橋站07:55 桃園站08:10 新竹站08:22 苗栗站 台中站08:48 彰化站 雲林站 嘉義站09:14 台南站09:33 左營站09:45
# 0609
# 07:35
# 09:45
# 02:10
#
#
# ====================================================================================================
# 0205 07:40 09:30 01:50 close 0205 列車 停靠說明 南港站07:40 台北站07:51 板橋站07:59 桃園站 新竹站 苗栗站 台中站08:40 彰化站 雲林站 嘉義站 台南站09:18 左營站09:30
# 0205
# 07:40
# 09:30
# 01:50
#
#
# ====================================================================================================
# 0809 08:00 10:25 02:25 close 0809 列車 停靠說明 南港站08:00 台北站08:11 板橋站08:19 桃園站08:34 新竹站08:47 苗栗站08:58 台中站09:17 彰化站09:30 雲林站09:41 嘉義站09:55 台南站10:13 左營站10:25
# 0809
# 08:00
# 10:25
# 02:25
#
#
# ====================================================================================================
# 0613 08:10 10:20 02:10 close 0613 列車 停靠說明 南港站08:10 台北站08:21 板橋站08:29 桃園站08:43 新竹站08:56 苗栗站 台中站09:25 彰化站 雲林站 嘉義站09:50 台南站10:07 左營站10:20
# 0613
# 08:10
# 10:20
# 02:10
#
#
# ====================================================================================================
# 0113 08:20 10:05 01:45 close 0113 列車 停靠說明 南港站08:20 台北站08:31 板橋站08:39 桃園站 新竹站 苗栗站 台中站09:20 彰化站 雲林站 嘉義站 台南站 左營站10:05
# 0113
# 08:20
# 10:05
# 01:45
#
#
# ====================================================================================================
# 0615 08:35 10:45 02:10 close 0615 列車 停靠說明 南港站08:35 台北站08:46 板橋站08:55 桃園站09:10 新竹站09:22 苗栗站 台中站09:48 彰化站 雲林站 嘉義站10:14 台南站10:33 左營站10:45
# 0615
# 08:35
# 10:45
# 02:10
#
#
# ====================================================================================================
# 0803
# 06:15
# 08:40
# 02:25
#
#
# ====================================================================================================
# 0603
# 06:40
# 08:50
# 02:10
#
#
# ====================================================================================================
# 0805
# 07:00
# 09:25
# 02:25
#
#
# ====================================================================================================
# 0109
# 07:20
# 09:05
# 01:45
#
#
# ====================================================================================================
# 0609
# 07:35
# 09:45
# 02:10
#
#
# ====================================================================================================
# 0205
# 07:40
# 09:30
# 01:50
#
#
# ====================================================================================================
# 0809
# 08:00
# 10:25
# 02:25
#
#
# ====================================================================================================
# 0613
# 08:10
# 10:20
# 02:10
#
#
# ====================================================================================================
# 0113
# 08:20
# 10:05
# 01:45
#
#
# ====================================================================================================
# 0615
# 08:35
# 10:45
# 02:10
#
#
# ====================================================================================================
# ====================================================================================================
# $1530
# $765
# $1450
# $1375
# $1220
# $990
# ====================================================================================================
# $2000
# $1250
# $1900
# -
# -
# -
# ====================================================================================================
# $1480
# $740
# -
# -
# -
# -
# ====================================================================================================

# %% [markdown]
# ## FB API

# %%
import requests

res = requests.get("https://graph.facebook.com/v2.9/941148115898954/feed", params={
    "access_token": "EAACEdEose0cBAM0PxJIjVqymUKu8m6SYjRdFGCBZCV9ZBOLBUwLIt5six3qqUsPScKFZCrYfpCzDPgHurErIS4y0wH7bquOGn4V584J7fKJcMsW9KqIz6yQIjXsZAUmiiBb6ZBxS16HR6ZB8H3h9lV9ZBh0XNDkGdpnBTnlZCvt0C6LuNsw9KKauAL57Mvv6DAoZD",
    "fields": "message,comments.limit(500).sort(reverse_chronological),attachments",
    "limit": 20
})

# %%
res.status_code
# Out:
# 400

# %%
res.json().keys()
# Out:
# dict_keys(['error'])

# %%
res.json()['error']
# Out:
# {'code': 190,
#  'error_subcode': 463,
#  'fbtrace_id': 'EooJnUjWqrI',
#  'message': 'Error validating access token: Session has expired on Tuesday, 04-Jul-17 21:00:00 PDT. The current time is Wednesday, 05-Jul-17 04:24:27 PDT.',
#  'type': 'OAuthException'}

# %%
while True:
    next_url = res.json()['error']['next']
    print("[INFO] crawling %s"%next_url)
    res = requests.get(next_url)
    print("[INFO] %s finished"%next_url)
    with open('fb_%s.json'%(res.json()['error']['next'].split('until=')[1].split('&__pag')[0]), 'w') as f:
        f.write(res.text)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-d57bb5f8dff3> in <module>()
#       1 while True:
# ----> 2     next_url = res.json()['error']['next']
#       3     print("[INFO] crawling %s"%next_url)
#       4     res = requests.get(next_url)
#       5     print("[INFO] %s finished"%next_url)
#
# KeyError: 'next'

# %% [markdown]
# ## HTTP State management

# %%
# PTT
import requests

URL = "https://www.ptt.cc/bbs/Beauty"
res = requests.get(URL)

# %%
print(res.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Beauty 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Beauty/index.html"><span class="board-label">看板 </span>Beauty</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Beauty/index.html">看板</a>
# 				<a class="btn" href="/man/Beauty/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Beauty/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Beauty/index2212.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Beauty/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Beauty/M.1499231911.A.466.html">[神人] 剛剛從我朋友手機看到的</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">Aachoco</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">32</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Beauty/M.1499232651.A.D31.html">[正妹] 奶特</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">William0703</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f0">X3</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				(GM:X3 7days) &lt;xxxgg5566&gt;
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">-</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				(本文已被刪除) [johnchu33005]
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">-</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				(本文已被刪除) [kazekaze]
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">-</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f0">X1</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				(GM:X1 7days) &lt;culminate&gt;
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">-</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Beauty/M.1499247162.A.F18.html">[正妹] 請推薦合法蘿莉ig</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">fawangching</div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">35</span></div>
# 			<div class="mark">M</div>
# 			<div class="title">
#
# 				<a href="/bbs/Beauty/M.1443906121.A.65B.html">[公告] 不願上表特 ＆ 優文推薦 ＆ 檢舉建議專區</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">10/04</div>
# 				<div class="author">ffwind</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark">!</div>
# 			<div class="title">
#
# 				<a href="/bbs/Beauty/M.1423752558.A.849.html">[公告] 表特板板規 (2015.2.12)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 2/12</div>
# 				<div class="author">GeminiMan</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f1">爆</span></div>
# 			<div class="mark">M</div>
# 			<div class="title">
#
# 				<a href="/bbs/Beauty/M.1430099938.A.3B7.html">[公告] 對於謾罵，希望大家將心比心</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 4/27</div>
# 				<div class="author">ffwind</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">10</span></div>
# 			<div class="mark">M</div>
# 			<div class="title">
#
# 				<a href="/bbs/Beauty/M.1476111251.A.C20.html">[公告] 偷拍相關板規修訂</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date">10/10</div>
# 				<div class="author">GeminiMan</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.22/bbs.js"></script>
#
#     </body>
# </html>

# %%
res.request.headers
# Out:
# {'User-Agent': 'python-requests/2.18.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': '__cfduid=dbe624e7e7646ef28f14cd097629f1c181499254432'}

# %%
# PTT
import requests

URL = "https://www.ptt.cc/bbs/Gossiping"
res = requests.get(URL, headers={"cookie": "over18=1;"})
print(res.text)
res.request.headers
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div class="bbs-screen bbs-content">
#     <div class="over18-notice">
#         <p>本網站已依網站內容分級規定處理</p>
#
#         <p>警告︰您即將進入之看板內容需滿十八歲方可瀏覽。</p>
#
#         <p>若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。</p>
#     </div>
# </div>
#
# <div class="bbs-screen bbs-content center clear">
#     <form action="/ask/over18" method="post">
#         <input type="hidden" name="from" value="/bbs/Gossiping/index.html">
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="yes" value="yes">我同意，我已年滿十八歲<br><small>進入</small></button>
#         </div>
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="no" value="no">未滿十八歲或不同意本條款<br><small>離開</small></button>
#         </div>
#     </form>
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.22/bbs.js"></script>
#
#     </body>
# </html>
# {'User-Agent': 'python-requests/2.18.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': '__cfduid=d0f6ecc42b87cec3c901e03547a69be0d1499254478'}

# %%
# PTT
import requests

URL = "https://www.ptt.cc/bbs/Gossiping"
res = requests.get(URL, cookies={"over18": "1"})
print(res.text)
res.request.headers
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index25381.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">13</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499253998.A.54B.html">[新聞] 日月光環保體驗營 見識全台最大中水處理</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">sofc</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499254043.A.A0E.html">[問卦] 長江大水 為何包子卻出國趴趴走</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">Rattlesnake</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499254191.A.9D5.html">[問卦] 可樂會不會酸掉？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">momoispig</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499254293.A.479.html">Re: [問卦] 北美四大職業賽會不會剩NBA一家獨大？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">cena0605</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499254302.A.5FF.html">[問卦] 會很佩服國家文字有一堆毛毛蟲的嗎?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">mnhyuiop</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499254322.A.FCF.html">[問卦] 有沒有飛天少母豬－寶妮的八卦？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">DanGong5566</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499254323.A.135.html">Re: [新聞] 親人下手？15年前少女遭殺　託夢男大生</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">IronCube</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499254332.A.D40.html">[問卦] 少尉女軍官有沒有什麼潛規則？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">redwing119</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499254360.A.902.html">Re: [問卦] 是不是人死了一切都會被洗白？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">MoronJJ</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499254374.A.852.html">[新聞] 男大生遊澎湖雙載逆向　遭輾車底1死1重傷</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">gensokyo</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499254394.A.71C.html">[問卦] 幸福來了哪時會開始出現爭產的劇情？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">mobley2005</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499254461.A.B06.html">[問卦] 在區間車被不明男士性騷騷</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">steven141412</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499254464.A.119.html">[新聞] 加泰隆尼亞又想獨立　西國總理批獨裁幻</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">wahaha23</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499254469.A.5CF.html">[新聞] 【有片】日網路票選最美女運動員 誰贏福</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">Ironstick</div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">21</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1498033253.A.548.html">[協尋]市民大道五段 7:30 車禍</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 6/21</div>
# 				<div class="author">Kimg</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f1">爆</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1498120174.A.818.html">[協尋]6/5宜蘭往礁溪林美一帶走失</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 6/22</div>
# 				<div class="author">lemondrink46</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">24</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1498656193.A.C9B.html">[協尋]6/28傍晚17:30左右辛亥路木柵路口行車影像</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 6/28</div>
# 				<div class="author">jessicaY</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark">!</div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1497542802.A.EC6.html">[公告] 八卦板板規(2017.06.16)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 6/16</div>
# 				<div class="author">Mews</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">99</span></div>
# 			<div class="mark">M</div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1498840923.A.DB6.html">[公告] 七月份置底閒聊區</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/01</div>
# 				<div class="author">Mews</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.22/bbs.js"></script>
#
#     </body>
# </html>
# {'User-Agent': 'python-requests/2.18.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': 'over18=1; __cfduid=de300a2c0f3775f4c4a3f3dc97065d59e1499254489'}

# %%
# PTT
import requests

URL = "https://www.ptt.cc/bbs/Gossiping"
res = requests.get(URL, headers={"cookie": "over18=1"}, allow_redirects=False)
print(res.text)
res.request.headers
# Out:
# {'User-Agent': 'python-requests/2.18.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'cookie': 'over18=1'}

# %%
# PTT 
import requests

URL = "https://www.ptt.cc/bbs/Gossiping"
res = requests.get(URL, headers={"cookie": "over18=1"})
print(res.text)

# res.history -> list of Response objects created during this request(兩次302)只會帶cookie其他都不會帶
print("Num of responses: %s"%(len(res.history)))
print(res.history)
res.history[0].request.headers
#res.history[1].request.headers
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div class="bbs-screen bbs-content">
#     <div class="over18-notice">
#         <p>本網站已依網站內容分級規定處理</p>
#
#         <p>警告︰您即將進入之看板內容需滿十八歲方可瀏覽。</p>
#
#         <p>若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。</p>
#     </div>
# </div>
#
# <div class="bbs-screen bbs-content center clear">
#     <form action="/ask/over18" method="post">
#         <input type="hidden" name="from" value="/bbs/Gossiping/index.html">
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="yes" value="yes">我同意，我已年滿十八歲<br><small>進入</small></button>
#         </div>
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="no" value="no">未滿十八歲或不同意本條款<br><small>離開</small></button>
#         </div>
#     </form>
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.22/bbs.js"></script>
#
#     </body>
# </html>
#
# Num of responses: 2
# [<Response [302]>, <Response [302]>]
# {'User-Agent': 'python-requests/2.18.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'cookie': 'over18=1'}

# %%
import requests

requests.get("https://google.com")
requests.get("https://google.com")
# Out:
# <Response [200]>

# %%
# 兩個視為同一個session
from requests import Session

rs = Session()
rs.get("https://google.com")
rs.get("https://google.com")
# Out:
# <Response [200]>
